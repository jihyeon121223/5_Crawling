# %%
# !pip install wordcloud-1.8.1-cp39-cp39-win_amd64.whl
# Out:
# Processing c:\pythondata\wordcloud-1.8.1-cp39-cp39-win_amd64.whl
# ...

# %%
f = open('[박경리]_토지1.txt','r')
story = f.read()
f.close()

# %%
type(story)
# Out:
# str

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
stopword = ['그','안']
cloud = WordCloud(background_color='white',font_path='NanumBarunGothic.ttf',stopwords=stopword).generate(story)
plt.figure(figsize=(15,10))
plt.imshow(cloud)
plt.show()

# %%
cloud.words_
# Out:
# {'있었다': 1.0,
#  '다': 0.8083623693379791,
#  '이': 0.6759581881533101,
#  '한': 0.6550522648083623,
#  '못': 0.6236933797909407,
#  '것이다': 0.5993031358885017,
#  '용이는': 0.5853658536585366,
#  '하고': 0.5818815331010453,
#  '와': 0.49477351916376305,
#  '내가': 0.47735191637630664,
#  '내': 0.4634146341463415,
#  '평산은': 0.45993031358885017,
#  '있는': 0.445993031358885,
#  '그는': 0.42160278745644597,
#  '같은': 0.4146341463414634,
#  '했다': 0.4146341463414634,
#  '그러나': 0.40069686411149824,
#  '없는': 0.3902439024390244,
#  '다시': 0.3797909407665505,
#  '하는': 0.37282229965156793,
#  '말을': 0.3693379790940767,
#  '어디': 0.3588850174216028,
#  '것을': 0.34843205574912894,
#  '그런': 0.3344947735191638,
#  '용이': 0.3310104529616725,
#  '좀': 0.32752613240418116,
#  '가서': 0.3205574912891986,
#  '제': 0.3170731707317073,
#  '것도': 0.313588850174216,
#  '하며': 0.31010452961672474,
#  '더': 0.2961672473867596,
#  '그래': 0.2961672473867596,
#  '또': 0.2961672473867596,
#  '강청댁은': 0.2961672473867596,
# ...

# %%
# !pip install soynlp

# %%
# from soynlp.noun import LRNounExtractor
# noun_extractor = LRNounExtractor()
# nouns = noun_extractor.train_extract([story]) # list of str like

# from soynlp.noun import NewsNounExtractor
# noun_extractor = NewsNounExtractor()
# nouns = noun_extractor.train_extract([story]) # list of str like

from soynlp.word import WordExtractor

word_extractor = WordExtractor(min_frequency=100,
    min_cohesion_forward=0.05, 
    min_right_branching_entropy=0.0
)
word_extractor.train([story]) # list of str or like
words = word_extractor.extract()
# Out:
# training was done. used memory 0.253 Gb0.264 Gb
# all cohesion probabilities was computed. # words = 156
# all branching entropies was computed # words = 13262
# all accessor variety was computed # words = 13262

# %%
cloud = WordCloud(background_color='white',font_path='NanumBarunGothic.ttf').generate(' '.join(words))
plt.figure(figsize=(15,10))
plt.imshow(cloud)
plt.show()
