# %%
import folium
import pandas as pd
import requests
import json

# %%
#csv파일에서 랜덤으로 정보 들고오기
filename='jeju.csv'
df=pd.read_csv(filename,encoding='cp949')
df.sample(2)
# Out:
#      지역  읍면동          전화번호                        주소  \
# 19  제주시  한림읍  064-728-7628          제주시 한림읍 한림상로 132
# 14  제주시   연동  064-728-4836  제주특별자치도 제주시 신대로 101 (연동)
#
#                                          일반현황                      청사현황  \
# 19  인구 19925명 / 면적91.99㎢ / 21개리 56개자연마을 350개반      지상 2층 / 연면적 1066.33㎡
# 14               인구 39897 / 면적12.4㎢ / 41통268반  지하 1층·지상3층 / 연면적 945.61㎡
#
#                             자치센터현황     데이터기준일자  Unnamed: 8
# 19  총면적 1066.33㎡ /  개소일 2007-07-19  2019-06-20         NaN
# 14                  개소일 2001. 9. 5  2019-06-20         NaN

# %%
def get_geo_code(address):
    REST_API_KEY=''
    url=f'
