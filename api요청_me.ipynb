# %%
#네이버
id='OqE42jl1AbLEJ5j1Ek18'
key='N8lmsYAvvx'

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = id
client_secret = key
keyword=input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')) #json: dump수정, load읽기
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어>>>dkssud
# {
# "lastBuildDate": "Mon, 14 Mar 2022 12:09:57 +0900",
# "total": 87837301,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "마산 앞바다 오션뷰 오토캠핑장에서 1박2일 @<b>안녕</b>오토캠핑장",
# "link": "https:\/\/blog.naver.com\/klove9209?Redirect=Log&logNo=222672025318",
# "description": "지난 대선 때맞춰 방문한 #<b>안녕</b>오토캠핑장 미리 사전투표를 한 덕분에 여유롭게 챙겨서 캠핑장을 올 수... <b>안녕</b>오토캠핑장 방문하기 전 후기를 보니, 작은 방파제가 있어서 낚시를 하는 분들이 많은 듯하여... ",
# "bloggername": "보통의 존재",
# "bloggerlink": "https://blog.naver.com/klove9209",
# "postdate": "20220314"
#
# },
# {
# "title": "결국...  <b>안녕</b>...",
# "link": "https:\/\/blog.naver.com\/bangul4?Redirect=Log&logNo=222664719586",
# "description": "이곳에 약을 넣고 물을 섞어 엄청 뿌려줬는데.... 이제 저 분무기는 쓸일이 없을 것 같다. <b>안녕</b>.... 나무들..... 깍지벌레 니가 이겼다... 우리 이제는 만나지 말자. 나무들아 잘가.... <b>안녕</b>.",
# "bloggername": "인생은 내 마음대로",
# "bloggerlink": "https://blog.naver.com/bangul4",
# "postdate": "20220305"
#
# },
# {
# "title": "쪽쪽이 <b>안녕</b> -",
# "link": "https:\/\/blog.naver.com\/totolodang?Redirect=Log&logNo=222662108637",
# "description": "딱 365일 되는 날이었다.(소오오오오오름....) 정확히 1년간 물고 <b>안녕</b>이구나. 산다는게 원래 B(birth)와 D... <b>안녕</b>하고 보내주자&quot; 했는데 정말 입에 물고있던 쪽쪽이를 빼서 나에게 쥐어주고 <b>안녕</b>-하고 손... ",
# "bloggername": "빛나는 청춘이잖아 ♪",
# "bloggerlink": "https://blog.naver.com/totolodang",
# "postdate": "20220302"
#
# },
# {
# "title": "고잔동네일 <b>안녕</b> 루미에서 미리 3월네일 받기, 하늘하늘네일",
# "link": "https:\/\/blog.naver.com\/90jine?Redirect=Log&logNo=222664580590",
# "description": "고잔동네일 <b>안녕</b>루미 젤네일을 제거하고 2주가 지나고 날이 좀 풀리기 시작하니 어김없이 젤네일을... 고잔동네일 <b>안녕</b> 루미를 방문했다. #단원구네일 #고잔동네일 #중앙동네일 #초지동네일 고잔동네일 <b>안녕</b>... ",
# "bloggername": "나만의 속도로 사는 삶",
# "bloggerlink": "https://blog.naver.com/90jine",
# "postdate": "20220305"
#
# },
# {
# "title": "퇴행성 턱 관절염 치료 2년 6개월 스플린트 <b>안녕</b>",
# "link": "https:\/\/blog.naver.com\/yourisol?Redirect=Log&logNo=222666893968",
# "description": "퇴행성 턱 관절염 치료 2년 6개월 스플린트 <b>안녕</b> 2월에 치과 예약이 되어있었는데, 상태도 괜찮았고, 애... Thanks God! #건강하자 #퇴행성턱관절염 #청춘치과 #턱치료 #스플린트<b>안녕</b> #다신하지말자",
# "bloggername": "리솔의 일상다반사",
# "bloggerlink": "https://blog.naver.com/yourisol",
# "postdate": "20220308"
#
# },
# {
# "title": "아이폰 13프로 초기화 방법! <b>안녕</b>~ 잘가!",
# "link": "https:\/\/blog.naver.com\/egmenti?Redirect=Log&logNo=222671692934",
# "description": "<b>안녕</b>하세요. 오늘은 아이폰 초기화 방법에 대해 리뷰를 하려고 합니다. 지난 9일이였죠. 대략 5개월 못... 아이폰 <b>안녕</b>!~ 잘가 ~ 지금은 다시 갤럭시 S22 울트라를 일주일째 사용 중인데, 기기 자체의 성능은... ",
# "bloggername": "에그먼티 IT 일상다반사",
# "bloggerlink": "https://blog.naver.com/egmenti",
# "postdate": "20220313"
#
# },
# {
# "title": "&lt;<b>안녕</b>, 간호사&gt; 류민지 작가님의 '간호사 타임즈' 인터뷰",
# "link": "https:\/\/blog.naver.com\/prunbook?Redirect=Log&logNo=222663501887",
# "description": "&lt;<b>안녕</b>, 간호사&gt; 류민지 작가님의 '간호사 타임즈' 인터뷰를 만나보세요! 간호사를 위한 그림! 간호사 선생님들과의 공감을 나누는 현직 간호사의 좌충우돌 병원 일상 공감툰 &lt;<b>안녕</b>, 간호사&gt; 류민지 작가님은... ",
# "bloggername": "도서출판 푸른향기",
# "bloggerlink": "https://blog.naver.com/prunbook",
# "postdate": "20220304"
#
# },
# {
# "title": "내돈내산, 일산애견용품점 &lt;<b>안녕</b> 모모&gt; 후기",
# "link": "https:\/\/blog.naver.com\/yokil?Redirect=Log&logNo=222667666838",
# "description": "<b>안녕</b>, 모모의 사장님이모를 고발합니다. ⠀ 인스타그램 @yokil  난 초코 밥이 떨어져 사료를... &lt;인스타그램 @himomo.7&gt; 강아지 오마카세 맛집, #<b>안녕</b>모모 &quot;엄마, 모모네 사장님이모 망하는거 아냐? 주의 좀... ",
# "bloggername": "새로운 매일 #셀프힐링",
# "bloggerlink": "https://blog.naver.com/yokil",
# "postdate": "20220309"
#
# },
# {
# "title": "수건에서 냄새 이젠 <b>안녕</b> 셀프빨래방 세제",
# "link": "https:\/\/blog.naver.com\/katie85?Redirect=Log&logNo=222665285441",
# "description": "수건에서 냄새 이젠 <b>안녕</b> 셀프빨래방 세제 <b>안녕</b>하세요~ 오늘은 살림백서 빨래세제를 리뷰해보려고하는데요. 요즘 셀프빨래방 이용하는분들이 정말 많은데요 설마.. 집에있는 무거운 세제를 같이 들고가는 분은... ",
# "bloggername": "오늘도 여행",
# "bloggerlink": "https://blog.naver.com/katie85",
# "postdate": "20220314"
#
# },
# {
# "title": "<b>안녕</b>오늘 :) 일상. 이사. 이천동 메리다방.추억.<b>안녕</b>",
# "link": "https:\/\/blog.naver.com\/starshop79?Redirect=Log&logNo=222657621029",
# "description": "이날의 선택은 벨지안카푸치노 ♡ 조용히 한 잔 하고 <b>안녕</b>~^^ 멋지고 맛있고 편한 다른 카페도 많고... 아무튼 <b>안녕</b>, <b>안녕</b> 또 갈 거지만, 유난스럽게 <b>안녕</b>~~ ㅋㅋㅋㅋㅋ 짐싸기 중... 돈 팡팡 쓰고 즐거웠던 흔적!!!... ",
# "bloggername": ":D merry daegu",
# "bloggerlink": "https://blog.naver.com/starshop79",
# "postdate": "20220225"
#
# }
# ]
# }

# %%
type(response_body)
# Out:
# bytes

# %%
response_body["lastBuildDate"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_364/1576984888.py in <module>
# ----> 1 response_body["lastBuildDate"]
#
# TypeError: byte indices must be integers or slices, not str

# %%
import json
data=json.loads(response_body)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_364/3223292315.py in <module>
#       1 import json
# ----> 2 data=json.loads(response_body)
#
# NameError: name 'response_body' is not defined

# %%
data

# %%
type(data)

# %%
data['lastBuildDate']

# %%
#개인실습시간

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json

client_id = id
client_secret = key
keyword=input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data=[]
for i in range(1,1001,100):
    url = f"https://openapi.naver.com/v1/search/blog?display=100&start={i}&query=" + encText # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        #print(response_body.decode('utf-8')) 
        d=json.loads(response_body)
        d['items']
        data.extend(d['items'])
    else:
        print("Error Code:" + rescode)
# Out:
# 검색할 단어>>>봄

# %%
data
# Out:
# [{'title': '<b>봄</b>기운이 느껴졌던 제주 유채꽃',
#   'link': 'https://blog.naver.com/ph_factory?Redirect=Log&logNo=222667371223',
#   'description': '2월 말이라 아직 완전히 <b>봄</b> 같은 분위기를 느끼기엔 좀 일렀지만 제주도는 언제 와도 좋은 곳이잖아요.... 따뜻한 <b>봄</b>이 가득했던 날이었답니다. 여러 꽃밭들 중에서도 단연코 1등을 차지한 곳은 성산일출봉 배경이... ',
#   'bloggername': '쭈니야, 은밀하게 움직이자!',
#   'bloggerlink': 'https://blog.naver.com/ph_factory',
#   'postdate': '20220308'},
#  {'title': '취나물 무침 삶기 향긋함이 최고 <b>봄</b>나물 종류 비빔밥재료',
#   'link': 'https://blog.naver.com/baby0817?Redirect=Log&logNo=222668497513',
#   'description': '취나물 무침 삶기 향긋함이 최고 <b>봄</b>나물 종류 비빔밥재료 <b>봄</b>은 <b>봄</b>인가봅니다. 오랜만에 근처 동네 마트에 가보니 글쎄 다양한 #<b>봄</b>나물종류 천지더라구요. 어찌나 행복하던지요. 산나물도 많이 보이고 말이죠.... ',
#   'bloggername': '축복받은 유전자 완소남매의 엄마표 먹거리',
#   'bloggerlink': 'https://blog.naver.com/baby0817',
#   'postdate': '20220310'},
#  {'title': '<b>봄</b> 배추김치 담그기',
#   'link': 'https://blog.naver.com/dlscjf517?Redirect=Log&logNo=222666478776',
#   'description': '두 번째 <b>봄</b>김치 돼지감자가루 풀을 쑤어 담근 반 포기김치 안녕하세요~ 뜨랑이랑입니다 <b>봄</b>이 시작도 되기 전에 <b>봄</b> 김치라며 막김치를 담고 한 달도 채 안 되었는데 또 김치를 담갔어요 찌개 한번 안 끓이고... ',
#   'bloggername': '뜨랑이랑',
#   'bloggerlink': 'https://blog.naver.com/dlscjf517',
#   'postdate': '20220307'},
#  {'title': '<b>봄</b> 정원',
#   'link': 'https://blog.naver.com/dlatn963?Redirect=Log&logNo=222671936618',
#   'description': '‘<b>봄</b>의 도래와 시작’을 알리는 꽃이라 새로운 10년의 시작을 기념하기 위해 부부의 결혼11주년 꽃으로... 지난 <b>봄</b>에 아주 짧게 피고 진, 어여뻤던 분홍빛의 튤립들~ 다섯 개의 구근을 노지와 화분에 나누어... ',
#   'bloggername': '흐르는 맑은 물처럼',
#   'bloggerlink': 'https://blog.naver.com/dlatn963',
#   'postdate': '20220314'},
#  {'title': '쑥된장국 끓이는법, 들깨쑥국~<b>봄</b>내음 물씬나요.',
#   'link': 'https://blog.naver.com/hyleeyan?Redirect=Log&logNo=222671182860',
#   'description': '<b>봄</b>만되면 주변 어디서나 쑥쑥 흙을 밀고 올라오는 쑥을 발견할 수 있지요. 동네공원을 가거나... 일년중 새<b>봄</b>. 이맘때만 맛볼수 있는 쑥을 시기를 놓치지말고 쑥된장국이나 쑥부침개를 해먹으면 아주 입맛이... ',
#   'bloggername': '요안나의 행복이팍팍',
#   'bloggerlink': 'https://blog.naver.com/hyleeyan',
#   'postdate': '20220314'},
#  {'title': '월인정원, 어린 <b>봄</b>의 빵과 케이크',
#   'link': 'https://blog.naver.com/web_mov?Redirect=Log&logNo=222671868827',
#   'description': '*.* 참으로 고대하던, <b>봄</b>비예요. 겨우내 얼마나 가물었던지,, 지난 2월 28일, 대문 앞 밀들. 오늘 3월 13일, 간밤의 단비를 흠뻑 마시곤 얍 얍! ^^ 이제 키가 손 한뼘 정도예요~ 이야, 반갑고 귀하다! <b>봄</b>! <b>봄</b>비!... ',
#   'bloggername': '월인정원,밀밭의 식탁',
#   'bloggerlink': 'https://blog.naver.com/web_mov',
#   'postdate': '20220314'},
#  {'title': '<b>봄</b>기운을 느끼러 광주시 문형산을 오르다!',
#   'link': 'https://blog.naver.com/gjcityi?Redirect=Log&logNo=222669987074',
#   'description': '광주시에 <b>봄</b>이 찾아왔습니다 <b>봄</b>이 왔습니다. 낮에는 한낮 기온이 15도를 넘죠. 주변을 보니 목련 꽃이 꽃망울을 터뜨리려 하네요. 이제 두꺼운 외투를 벗을 때입니다. 코로나19로 안전하게 등산할 수 있는 산을... ',
#   'bloggername': '너른고을 광주시 공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/gjcityi',
#   'postdate': '20220311'},
#  {'title': '농부시장에 <b>봄</b>이 왔네요',
#   'link': 'https://blog.naver.com/sjs_gem?Redirect=Log&logNo=222671462026',
#   'description': '가보자~ <b>봄</b>이 오는 길목이다. 농부시장의 씨앗과 먹거리들을 구경이라도 해보자는 마음으로 집을 나섰다. 혜화역 부근에 있는 마로니에 공원 마르쉐@혜화&lt;씨앗&gt; 다른 때와는 달리 <b>봄</b>은 파종의 시기, 그래서인지... ',
#   'bloggername': '보배 이야기',
#   'bloggerlink': 'https://blog.naver.com/sjs_gem',
#   'postdate': '20220313'},
#  {'title': '구례 여행 가볼만한 곳  - 쌍산재 <b>봄</b>의 기록',
#   'link': 'https://blog.naver.com/l_b_v?Redirect=Log&logNo=222671641507',
#   'description': '구례 여행 가볼만한 곳 <b>봄</b>날의 쌍산재 작년 2021년 3월 중순에 다녀온 기록을 이제서야 남겨본다. 그동안 바빠서 정리도 못했고 올해 이제 여유가 생기니 앞으로 찾아올 <b>봄</b>날에 꽃구경을 어디를 갈까 고민하던 중... ',
#   'bloggername': 'Letter From Leely',
#   'bloggerlink': 'https://blog.naver.com/l_b_v',
#   'postdate': '20220313'},
#  {'title': '[일상에 꿀 한 스푼] <b>봄</b>에 쑥쑥 자라는 제철음식 <b>봄</b>나물 모음.ZIP',
#   'link': 'https://blog.naver.com/krcpolicy?Redirect=Log&logNo=222665898239',
#   'description': '<b>봄</b>에 쑥쑥 자라는 제철음식 <b>봄</b>나물 모음.ZIP 점점 따뜻해지는 날씨! <b>봄</b>이 오고 있어요! 푸릇푸릇한 <b>봄</b>에 먹으면 더욱 맛있는 생기 넘치는 <b>봄</b>나물! <b>봄</b> 하면 나물이 떠오르는 건 어떻게 보면 당연한데요. 여러분은... ',
#   'bloggername': '농이터',
#   'bloggerlink': 'https://blog.naver.com/krcpolicy',
#   'postdate': '20220308'},
#  {'title': '[여행+<b>봄</b>] <b>봄</b>만 되면 통영, 통영하는 진짜 이유',
#   'link': 'https://blog.naver.com/the_trip?Redirect=Log&logNo=222669503021',
#   'description': '[여행+<b>봄</b>] <b>봄</b>만 되면 통영, 통영하는 진짜 이유 통영 바다 / 사진 = 픽사베이 노랑, 빨강, 분홍, 주홍. 화려한 색의 4대천왕 쯤 될 테다. 추운 겨울이 하양으로 독주를 할 때만 빼고, 이 4색은 세 계절 내내 ‘전국... ',
#   'bloggername': '네이버 여행+',
#   'bloggerlink': 'https://blog.naver.com/the_trip',
#   'postdate': '20220311'},
#  {'title': '여자 로퍼 브랜드 러프넥 여성 청키로퍼 3가지로 코디 해<b>봄</b>!',
#   'link': 'https://blog.naver.com/bushcherry1?Redirect=Log&logNo=222671470719',
#   'description': '벌써 <b>봄</b>이 성큼하고 다가왔네요. 슈즈부터 다양한 패션아이템들까지 좀 더 가벼운 차림으로... 곧 대신입어드립니다 컨텐츠로 업로드할 셋업인데 <b>봄</b>느낌으로 민트컬러의 셋업이랑 함께 스타일링해주었더니... ',
#   'bloggername': '유니스의 뷰티,패션,인테리어,플레이팅 공간',
#   'bloggerlink': 'https://blog.naver.com/bushcherry1',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>, <b>봄</b>, <b>봄</b>...',
#   'link': 'https://blog.naver.com/janggias?Redirect=Log&logNo=222671365316',
#   'description': '<b>봄</b>은 이렇게 온다. 남편은 베란다를 정리하고 길다랗게 늘어서 있던 조각품을 한 곳으로 모았다. 예쁜 꽃 화분을 두어개 들여 놓으면 훨씬 더 보기 좋은 공간이 될 것 같다. 넓어진 공간으로 의자를 옮기고 <b>봄</b>... ',
#   'bloggername': '마법의 설탕 두 조각',
#   'bloggerlink': 'https://blog.naver.com/janggias',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>의 향연이 펼쳐지는 거제 고현시장',
#   'link': 'https://blog.naver.com/geojecity?Redirect=Log&logNo=222671376459',
#   'description': '거제시 소셜미디어 시민홍보단 신선화 거제 대표 종합시장 고현시장 삼월의 전통시장은 <b>봄</b>향기가 짙습니다. 좌판마다 가득한 초록 <b>봄</b>나물과 탱탱하게 살이 오른 <b>봄</b>철 수산물, 꽃집 앞을 가득 메운 <b>봄</b>꽃... ',
#   'bloggername': '거제시 공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/geojecity',
#   'postdate': '20220313'},
#  {'title': '3월 꽃구경 서울 봉은사 홍매화 <b>봄</b>꽃구경 나들이',
#   'link': 'https://blog.naver.com/overroad89?Redirect=Log&logNo=222671385105',
#   'description': '3월 꽃구경 서울 봉은사 홍매화 <b>봄</b>꽃구경 나들이 날씨가 따뜻한 남쪽부터 시작해서 어느덧 <b>봄</b>꽃 소식이 들려오고 있습니다. 보통 <b>봄</b>꽃 구경 하면 생각나는 것이 벚꽃이지만 벚꽃은 보통 3월 말~4월 초중순에... ',
#   'bloggername': '역쟁이',
#   'bloggerlink': 'https://blog.naver.com/overroad89',
#   'postdate': '20220313'},
#  {'title': '세발나물무침 요리 겉절이 만들기 <b>봄</b>나물 반찬 종류',
#   'link': 'https://blog.naver.com/pyoun0181?Redirect=Log&logNo=222670180860',
#   'description': '세발나물무침 겉절이 <b>봄</b>나물 반찬 글, 사진, 요리, by _ 배화 하루가 다르게 <b>봄</b>이 오는 것을 느낄 수 있었던 오늘 같은 날씨 낮에는 덥다는 느낌까지 들었던 이런 날씨는 춘곤증도 함께 오는 것 같다 .. 파릇파릇한... ',
#   'bloggername': '배화의맛있는집밥',
#   'bloggerlink': 'https://blog.naver.com/pyoun0181',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>꽃이 올라오는 광덕산',
#   'link': 'https://blog.naver.com/sek2633?Redirect=Log&logNo=222670996272',
#   'description': '12(토) 포근한 날씨 속의 광덕산 산행 하늘에 구름이 가득하고, 미세먼지도 나쁨ㅠㅠ 고맙고 반가운 <b>봄</b>비... <b>봄</b>기운이 몰려오고 있음을 실감하게 된다. 강당골 등산로 아직 아침이어 그런가? 해가 안떠서 그런가?... ',
#   'bloggername': '날마다 좋은 날',
#   'bloggerlink': 'https://blog.naver.com/sek2633',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>꽃구경 양산 통도사 홍매화 광양 매화축제 구례 산수유마을... ',
#   'link': 'https://blog.naver.com/bb00dd?Redirect=Log&logNo=222669961092',
#   'description': '<b>봄</b>꽃구경 양산 통도사 홍매화 광양 매화축제 구례 산수유마을 원동 매화축제 글, 사진 : 순수시대... 3월 중순이면 전국적으로 <b>봄</b>꽃이 피기 시작하면서 산과 들에는 울긋불긋한 색으로 가득한 풍경을... ',
#   'bloggername': '순수시대 주세환의 여행 사진 갤러리',
#   'bloggerlink': 'https://blog.naver.com/bb00dd',
#   'postdate': '20220311'},
#  {'title': '제주 노리매공원 매화 축제 제주도 <b>봄</b>축제 <b>봄</b>꽃축제 구경 2022... ',
#   'link': 'https://blog.naver.com/hloveh01?Redirect=Log&logNo=222669222954',
#   'description': '제주 노리매공원 매화 축제 제주도 <b>봄</b>꽃축제 구경 2022년 매화 개화시기 글, 사진 : 그루터기 코로나로 인해 대부분의 <b>봄</b> 축제는 취소되었지만 아랑곳하지 않고 2022년 매화 개화시기는 어김없이 돌아왔다. 특히... ',
#   'bloggername': '♣️행복 가득한 그루터기 발자취♣️',
#   'bloggerlink': 'https://blog.naver.com/hloveh01',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b> 향기 가득! 정원같은 우리집, 플랜테리어',
#   'link': 'https://blog.naver.com/hansolhomedeco?Redirect=Log&logNo=222670561439',
#   'description': '<b>봄</b> 향기 가득한 우리집 올 <b>봄</b>엔 플랜테리어! <b>봄</b><b>봄</b><b>봄</b> <b>봄</b>이왔어요~! 이번주말 날씨가 확 따뜻해서 <b>봄</b>날씨 제대로 느껴지죠? <b>봄</b>의 설레임과 싱그러움이 흠뻑 담긴 노래들도 연상되고, 따뜻한 <b>봄</b>날이 되면 나도... ',
#   'bloggername': '한솔홈데코',
#   'bloggerlink': 'https://blog.naver.com/hansolhomedeco',
#   'postdate': '20220312'},
#  {'title': 'KF94키즈마스크 새부리형 웰커버아이<b>봄</b>마스크로 해결',
#   'link': 'https://blog.naver.com/dufrhd369?Redirect=Log&logNo=222667544993',
#   'description': '웰커버아이<b>봄</b>마스크도 따라서 구매하게 되었는데, 결과적으론 만족한 소비가 아니었나 싶어요^^ 이... 웰커버아이<b>봄</b>마스크는 국내에서 인증 받은 3중 구조의 mb필터 시스템을 사용했다고 해요. 세균 여과효율이... ',
#   'bloggername': 'Only You',
#   'bloggerlink': 'https://blog.naver.com/dufrhd369',
#   'postdate': '20220309'},
#  {'title': '새싹 듬뿍 ♡ 제주 <b>봄</b> 시작 (22/03/14)',
#   'link': 'https://blog.naver.com/pdypink?Redirect=Log&logNo=222671944792',
#   'description': '<b>봄</b>비가 내리고 본격적 폭풍 새싹 비 온 후 기분이 참 시원하다 어떻게 <b>봄</b>을 알고 열심히 새싹들을 피우는지 기특하고 이쁘다.. 수국 수국 직접 삽목해서 기른 아이들 이렇게 잘 커주고 있다! 이른감이 있지만 ! 2일... ',
#   'bloggername': '제주도돌스냅 / 제주가족사진 다미사진관 블로그',
#   'bloggerlink': 'https://blog.naver.com/pdypink',
#   'postdate': '20220314'},
#  {'title': '발걸음 멈추게 하는, 싱그러운 <b>봄</b> 향수 추천',
#   'link': 'https://blog.naver.com/the_shoppers?Redirect=Log&logNo=222667329633',
#   'description': '잔뜩 움츠렸던 겨울에서 따듯한 <b>봄</b>으로 계절이 바뀌면서 생기 넘치는 컬러에 자꾸 시선이 가고 싱그러운 향에 가던 발길을 멈추게 되죠. 그렇다면 지금이 향수를 바꾸기 제격인 타이밍! <b>봄</b>의 한 장면을... ',
#   'bloggername': '롯데백화점 공식블로그',
#   'bloggerlink': 'https://blog.naver.com/the_shoppers',
#   'postdate': '20220308'},
#  {'title': '<b>봄</b> 제철음식 추천 대전맛집 7',
#   'link': 'https://blog.naver.com/newosilent?Redirect=Log&logNo=222664775406',
#   'description': '<b>봄</b> <b>봄</b> <b>봄</b> <b>봄</b>이 왔어요... ♬♬ 파릇파릇 새싹이 돋아나는 싱그러운 <b>봄</b>입니다. 올<b>봄</b>엔 우울하고 슬픈 일은 사라지고 웃을 일이 가득한 모두가 행복한 <b>봄</b>이 되었으면 좋겠네요. 오늘은 싱그러운 <b>봄</b>과 잘... ',
#   'bloggername': '칼군도마양의 맛있는 상상',
#   'bloggerlink': 'https://blog.naver.com/newosilent',
#   'postdate': '20220312'},
#  {'title': '[<b>봄</b>이 왔나 <b>봄</b>] 순천 <b>봄</b>꽃 여행지 ‘와온해변’',
#   'link': 'https://blog.naver.com/hongane2013?Redirect=Log&logNo=222666042124',
#   'description': '꽃 피는 <b>봄</b>이 왔어요 이맘때 <b>봄</b>꽃 구경 계획하고 계신 분들 많으실 텐데요. 따뜻한 <b>봄</b>날에 소중한 사람과 함께 가면 좋을 것 같은~ 와온해변을 소개합니다. 순천만의 동쪽 끄트머리에 위치한 와온해변에 왔어요... ',
#   'bloggername': '순천시 공식블로그',
#   'bloggerlink': 'https://blog.naver.com/hongane2013',
#   'postdate': '20220307'},
#  {'title': '<b>봄</b> 제주관광 10선',
#   'link': 'https://blog.naver.com/jtowelcome?Redirect=Log&logNo=222665877241',
#   'description': '어서 오세요, 제주의 <b>봄</b>입니다! 이제 제주는 완연한 <b>봄</b>입니다. 제주관광공사에서는 올 <b>봄</b>, 놓치지 말아야 할 제주관광 10선을 발표했습니다. 메모와 저장은 필수! 우리 모두 가벼운 마음으로 따뜻한 2022년 <b>봄</b>을... ',
#   'bloggername': 'VISITJEJU 블로그',
#   'bloggerlink': 'https://blog.naver.com/jtowelcome',
#   'postdate': '20220307'},
#  {'title': '냉이무침 입맛 돋워주는 냉이된장무침 만드는법 냉이손질 <b>봄</b>나... ',
#   'link': 'https://blog.naver.com/pingu528?Redirect=Log&logNo=222664814596',
#   'description': '3월 제철음식 <b>봄</b>나물 종류 냉이요리 향긋한 냉이무침 만드는법 주말 잘 쉬시고 계시나요? 날씨는 살짝... 3월이 되니 향긋한 <b>봄</b>나물이 한창이에요. 마트에도 다양한 종류의 <b>봄</b>나물이 보이니 장바구니에 절로... ',
#   'bloggername': '웅이맘의 달콤키친',
#   'bloggerlink': 'https://blog.naver.com/pingu528',
#   'postdate': '20220305'},
#  {'title': '<b>봄</b>비 / <b>봄</b>의 시작',
#   'link': 'https://blog.naver.com/lysook7?Redirect=Log&logNo=222671149679',
#   'description': '<b>봄</b>비가 내린다. 며칠 전 화단을 정리하면서 너무 바싹 마른 화단을 보고 올 들어 처음으로 물을 줬었다. 작년 <b>봄</b>과는 사뭇 다른 화단의 모습에 행여 나무들이 바싹 말라죽지 않았나 걱정이 되었기 때문이다. 겨울... ',
#   'bloggername': '가야의 소소한 이야기',
#   'bloggerlink': 'https://blog.naver.com/lysook7',
#   'postdate': '20220313'},
#  {'title': '제주 유채꽃 명소 : 꽃 피는 <b>봄</b> 여행, 중문 엉덩물계곡',
#   'link': 'https://blog.naver.com/mina860527?Redirect=Log&logNo=222669785346',
#   'description': '제주 유채꽃 명소 : 꽃 피는 <b>봄</b> 여행, 중문 엉덩물계곡 2017년 <b>봄</b> 이후, 거의 5년 만에 다시 가 본 엉덩물계곡. 며칠 전 서귀포에서 2박 3일간 놀다 왔는데, 중문 가는 길에 보니까 유채꽃이 여기저기... ',
#   'bloggername': '메밀꽃부부의 세계일주프로젝트',
#   'bloggerlink': 'https://blog.naver.com/mina860527',
#   'postdate': '20220312'},
#  {'title': '미래화훼공원에서 <b>봄</b>을 담아왔어요',
#   'link': 'https://blog.naver.com/bskijang?Redirect=Log&logNo=222666382030',
#   'description': '바람이 차긴 하지만 <b>봄</b>이 묻어오는 것 같습니다. <b>봄</b>바람으로 괜히 마음이 설레는 이즈음이면 한 가지 하는 일이 있습니다. 화원에 가서 화분을 몇 개씩 사오면서 저는 우리 집에 <b>봄</b>을 들여옵니다. 올해는... ',
#   'bloggername': '부산 기장군 대표블로그',
#   'bloggerlink': 'https://blog.naver.com/bskijang',
#   'postdate': '20220307'},
#  {'title': '<b>봄</b>이 오는 중, 텃밭의 어제와 오늘',
#   'link': 'https://blog.naver.com/poutian?Redirect=Log&logNo=222671406745',
#   'description': '우리 동네 어르신들도 <b>봄</b>비가 와야 농사를 시작하는데 비가 너무 안 온다면 걱정이 많으셨는데 부족하나마 <b>봄</b>비가 걱정거리가 좀 해소되었으면 좋겠네요. 어제까지 건조함 속에 텃밭에... ',
#   'bloggername': '이미경의 자연밥',
#   'bloggerlink': 'https://blog.naver.com/poutian',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b> <b>봄</b> <b>봄</b>, <b>봄</b>이 왔어요! 대구에 활짝 핀 홍매화',
#   'link': 'https://blog.naver.com/daegu_news?Redirect=Log&logNo=222669497524',
#   'description': '이제 <b>봄</b>이 오는 소리를 우리 주변에서도 들을 수 있는데요. 그중에서도 <b>봄</b>을 알리는 꽃이 있어서 소개 드려볼까 합니다. 매화나무와 매실나무는 같은 나무라는 거 아시죠? 꽃을 강조한 이름은 매화이고 열매를... ',
#   'bloggername': '대구광역시 공식 블로그, 컬러풀 대구!',
#   'bloggerlink': 'https://blog.naver.com/daegu_news',
#   'postdate': '20220311'},
#  {'title': '시골의 <b>봄</b>, 웨건타고 즐기는 마당 피크닉',
#   'link': 'https://blog.naver.com/alswldi57?Redirect=Log&logNo=222671354655',
#   'description': '<b>봄</b>, 마당 피크닉 @고구밍지 작년 여름에 이사 와서 여름, 가을, 겨울 3계절을 보내고 <b>봄</b>이 찾아왔다. 처음 맞는 <b>봄</b>이라 설레기도 하지만 날씨가 따뜻해지니 슬슬 벌레들이 보이기 시작해서 벌써부터 걱정이 되기도... ',
#   'bloggername': '밍지로그',
#   'bloggerlink': 'https://blog.naver.com/alswldi57',
#   'postdate': '20220313'},
#  {'title': '세발나물무침 입맛 돋우는 <b>봄</b>나물 반찬 제철 세발나물요리',
#   'link': 'https://blog.naver.com/witchyoli?Redirect=Log&logNo=222670464621',
#   'description': '이른 <b>봄</b>에만 잠시 만날 수 있는 나물이라 이 시기를 놓칠 수 없어 눈에 띄길래 얼른 챙겨왔거든요. <b>봄</b>나물 반찬 세발나물무침 recipe 갯벌의 해풍을 맞고 자라 자체로 약간의 짠맛을 가진 세발나물. 오돌오돌... ',
#   'bloggername': '욜리홈쿡',
#   'bloggerlink': 'https://blog.naver.com/witchyoli',
#   'postdate': '20220312'},
#  {'title': '여자 <b>봄</b> 코디 17166 블랙 셔츠 원피스 신발 스타일링까지!',
#   'link': 'https://blog.naver.com/bushcherry1?Redirect=Log&logNo=222669789957',
#   'description': '17166 블랙 셔츠 원피스 아이템으로 여자 <b>봄</b> 코디 해본 솔직후기를 준비해보았습니다! 안녕하세요!... 그리하여 오늘은 제가 17166 블랙 셔츠 원피스로 여자 <b>봄</b> 코디 해본 솔직후기를 준비해보았고요. 지금부터... ',
#   'bloggername': '유니스의 뷰티,패션,인테리어,플레이팅 공간',
#   'bloggerlink': 'https://blog.naver.com/bushcherry1',
#   'postdate': '20220311'},
#  {'title': '복숭아나무야 이제 <b>봄</b>이 시작될거야~~^^',
#   'link': 'https://blog.naver.com/jouin001?Redirect=Log&logNo=222671123673',
#   'description': '복숭아나무야 이제 <b>봄</b>이 시작될거야~~^^ 겨울잠자던 개구리가 깨어난다는 경칩이 지났습니다~^^ 즐거운농원에도 <b>봄</b>이 슬슬 꿈틀대고 있는 중이고요~ 며칠전 대통령선거일에 투표를 마치고 두 딸래미들 반강제(?)... ',
#   'bloggername': '춘천즐거운농원 농촌교육농장',
#   'bloggerlink': 'https://blog.naver.com/jouin001',
#   'postdate': '20220313'},
#  {'title': '보리새우 <b>봄</b>동된장국 끓이는법, <b>봄</b> 제철음식 <b>봄</b>동요리',
#   'link': 'https://blog.naver.com/loveis8199?Redirect=Log&logNo=222671516605',
#   'description': '보리새우 <b>봄</b>동된장국 <b>봄</b> 기운 듬뿍 담은 제철음식 동네 친구가 조그맣게 텃밭을 하고 있는데 <b>봄</b>동을 수확했다며 가져왔더라구요. 가운데 속잎이 노란색이여야하는데 초보농부라 잘 안되었다며 부끄러워하는데... ',
#   'bloggername': '언니소의 건강한 푸드스토리',
#   'bloggerlink': 'https://blog.naver.com/loveis8199',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b> 향기 가득 품은 창원 천주산 미나리 맛보세요~',
#   'link': 'https://blog.naver.com/cwopenspace?Redirect=Log&logNo=222667103957',
#   'description': '아삭한 식감과 뛰어난 향이 <b>봄</b> 입맛까지 돋워줘... 창원 천주산 미나리를 수확해 선별하고 있다. 날씨가... 포근한 <b>봄</b>이 성큼 다가온 느낌인데요. 올해는 다소 수확이 늦은 감이 있는 천주산 미나리 수확 현장을... ',
#   'bloggername': '창원시 공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/cwopenspace',
#   'postdate': '20220308'},
#  {'title': "<b>봄</b>을 기다리는 '장월평천'",
#   'link': 'https://blog.naver.com/letsgoyang?Redirect=Log&logNo=222656869790',
#   'description': '<b>봄</b>이 오고 있음을 알려준다. Previous image Next image #3. 가화1교에서 가화교가 보인다. 이곳으로는 걸어서... <b>봄</b>을 대비해서 퇴비를 가져왔나 보다 아직 따뜻한 기운이 스멀스멀 올라온다. 하천 양쪽에 이런 고랑이... ',
#   'bloggername': '고양시청 블로그',
#   'bloggerlink': 'https://blog.naver.com/letsgoyang',
#   'postdate': '20220311'},
#  {'title': '화사한 <b>봄</b>꽃) 히아신스 꽃향기 &amp; 꽃말 너무 좋네요.~',
#   'link': 'https://blog.naver.com/banyson?Redirect=Log&logNo=222670908486',
#   'description': '<b>봄</b>되면서 화사한 <b>봄</b>꽃 찾는 분들 많으시죠? 2월에는 천리향 향기에 쓰러졌다면 3월부터는 꽃집마다 가득한 히아신스 향기에 다들 행복해 하시는것 같아요. 히아신스 키우기 는 방법도 쉽고, 가격도 적당하고... ',
#   'bloggername': '★ 알뜰한 젤리맘의 세상을 행복하게 사는 이야기 ★',
#   'bloggerlink': 'https://blog.naver.com/banyson',
#   'postdate': '20220313'},
#  {'title': '[개인구조] <b>봄</b>이의 가족을 찾습니다.',
#   'link': 'https://blog.naver.com/animalkara?Redirect=Log&logNo=222669593476',
#   'description': '7 / 청주 문의면 동물 정보 : 개 / 암컷 / 5살 작년 <b>봄</b>에 극적으로 구조했던 <b>봄</b>이(누)의 가족을 찾습니다. 건물 뒷구석에 갇혀서 4년을 음식물 쓰레기로 연명하며 살았고 함께 있던 오빠개는 많이 짖는다는 이유로... ',
#   'bloggername': '동물권행동 카라, 인권을 넘어 생명권으로!',
#   'bloggerlink': 'https://blog.naver.com/animalkara',
#   'postdate': '20220312'},
#  {'title': '대구에 <b>봄</b><b>봄</b><b>봄</b> <b>봄</b>이 왔네요 (인흥마을, 신천, 아양교)',
#   'link': 'https://blog.naver.com/daeguvisit?Redirect=Log&logNo=222662700647',
#   'description': '제멋대로 대구로드는 새로운 시작이자 활기찬 <b>봄</b>이 가장 기대됩니다! 이번 시간에는 대구에 <b>봄</b>이 찾아왔다는 소식을 알려주는 꽃과, 꽃을 보며 산책하기 좋은 곳을 소개해 드릴게요. 대구관광과 함께 따스한... ',
#   'bloggername': "'제멋대로대구로드' 대구관광공식블로그",
#   'bloggerlink': 'https://blog.naver.com/daeguvisit',
#   'postdate': '20220307'},
#  {'title': '<b>봄</b>향기를 품고 있는 거창꽃시장----배인주기자',
#   'link': 'https://blog.naver.com/geochanggun?Redirect=Log&logNo=222670655007',
#   'description': '<b>봄</b>향기를 품고 있는 거창꽃시장 지난해 시월 이후 빗방울 소리도 듣기 힘들고 겨울철에 볼 수 있는 함박눈조차 구경하기 힘들다보니 겨울가뭄이 극심한 가운데 <b>봄</b>을 맞이하게 되었습니다 그러다보니 삭막한... ',
#   'bloggername': '거창한거창',
#   'bloggerlink': 'https://blog.naver.com/geochanggun',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b>가볼만한곳  진주매화숲의 매화꽃이 지금 절정 #페이지',
#   'link': 'https://blog.naver.com/shbae3521?Redirect=Log&logNo=222670774949',
#   'description': '<b>봄</b>가볼만한곳 진주매화숲의 매화꽃이 지금 절정 ♡진주 매화숲 ♡ 경남 진주시 내동면 산유로 362 #<b>봄</b>에가볼만한곳 진주 매화숲이 최근 많은 사람들의 블로그를 장식하고 있어, 부산여행을 다녀오면서 잠시... ',
#   'bloggername': '페이지의세상만사 체험여행',
#   'bloggerlink': 'https://blog.naver.com/shbae3521',
#   'postdate': '20220312'},
#  {'title': '달래오이무침 레시피, <b>봄</b>맛 달래 요리 오이달래무침 만드는 법!',
#   'link': 'https://blog.naver.com/jiwon_n37?Redirect=Log&logNo=222669786300',
#   'description': '달래오이무침 레시피, <b>봄</b>맛 달래 요리 오이달래무침 만드는 법! 요즘 아침에 나래 등교시키고 운동... ^^ 오이무침에 부추를 넣고 만들 때가 가장 많지만 <b>봄</b>철에는 달래를 넣고 오이달래무침으로 만들곤... ',
#   'bloggername': '아무튼 봄.',
#   'bloggerlink': 'https://blog.naver.com/jiwon_n37',
#   'postdate': '20220311'},
#  {'title': '국내 <b>봄</b>꽃축제 가볼만한곳 <b>봄</b>여행지 꽃구경 경남 전남 베스트 10',
#   'link': 'https://blog.naver.com/unyoung3155?Redirect=Log&logNo=222669298622',
#   'description': '<b>봄</b>꽃축제 가볼만한곳 <b>봄</b>여행지 경남 전남 베스트10 글,사진 ㅣ 백자매 찍기만 하면 인생샷 되는 국내 <b>봄</b>꽃축제 가볼만한곳을 백자매가 야심차게 꼽아봤는데요. 3월부터 4월까지 이어지는 꽃놀이 장소를... ',
#   'bloggername': '백자매가 사는 세상',
#   'bloggerlink': 'https://blog.naver.com/unyoung3155',
#   'postdate': '20220311'},
#  {'title': '차분한 <b>봄</b> 인테리어 예쁜집 원형식탁 포인트',
#   'link': 'https://blog.naver.com/meekcho?Redirect=Log&logNo=222667004328',
#   'description': '차분한 <b>봄</b> 인테리어 예쁜집 화이트 원형식탁 포인트 <b>봄</b>이네요. 아직은 꽃샘추위가 머물러 있기는 하지만 햇볕이나 바람은 <b>봄</b>이 다가온 것을 느끼게 해주네요. 오늘은 차분하면서 가벼운 느낌이 드는... ',
#   'bloggername': '13월의블루 집스토리',
#   'bloggerlink': 'https://blog.naver.com/meekcho',
#   'postdate': '20220308'},
#  {'title': '<b>봄</b>데일리룩 소장욕구 자극하는 볼리오핸드백 찜하기',
#   'link': 'https://blog.naver.com/ejoe1974?Redirect=Log&logNo=222671405886',
#   'description': '이런 느낌 ^^ 볼리오체인백과 함께 본격적인 <b>봄</b> 데일리룩에 대해 언.급.해봅니다 여자라면, 한번쯤... 디자인이라, <b>봄</b>시즌 가장 많이 손이 가는 트렌치코트와 궁합 좋습니다 실상, 어떤 스타일링과도 궁합 좋은... ',
#   'bloggername': '제이테조로103_공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/ejoe1974',
#   'postdate': '20220313'},
#  {'title': "<b>봄</b>과 함께 돌아온 '두바이 아트 시즌'",
#   'link': 'https://blog.naver.com/dubaitourism?Redirect=Log&logNo=222668651083',
#   'description': '<b>봄</b>이 오고 있나 봐요 :) 여러분은 <b>봄</b>이 되면 무엇을 하시나요? 학창시절엔 녹음이 푸르른 곳으로 <b>봄</b>소풍을 가서 그림도 그리고 시도 끄적이고 했던 것 같아요! 대충 써서 제출하고 친구들하고 놀기... ',
#   'bloggername': '두바이관광청 블로그',
#   'bloggerlink': 'https://blog.naver.com/dubaitourism',
#   'postdate': '20220310'},
#  {'title': '2022.3.11 <b>봄</b> 날의 출근',
#   'link': 'https://blog.naver.com/tnsdhring?Redirect=Log&logNo=222670022651',
#   'description': '<b>봄</b> <b>봄</b> 이 가까이 와 있음을 확연히 느껴지는 아침 이다. 날씨가 너무 좋다. 그리고 마을 버스에서 내리자마자 검단산 아래의 <b>봄</b>을 느끼게 한다. 부추농사 시작하는 밭에서 풍겨오는 거름냄새로 이곳의 <b>봄</b>은... ',
#   'bloggername': '순간의 행복 피오나의 사진일기.^^',
#   'bloggerlink': 'https://blog.naver.com/tnsdhring',
#   'postdate': '20220311'},
#  {'title': '남자 <b>봄</b> 코트 브랜드 믿고 입는 라퍼지스토어',
#   'link': 'https://blog.naver.com/darigile?Redirect=Log&logNo=222670720703',
#   'description': '남자 <b>봄</b> 코트 브랜드 믿고 입는 라퍼지스토어 진짜 포근한 주말에 다리기리 인사드립니다!! 날씨는 좋은데 미세먼지가 너무 심하긴 하네요;; 내일부터 비가 온다고 하니깐 빨리 없어졌으면 좋겠습니다. <b>봄</b>... ',
#   'bloggername': '다리길이SEASON2',
#   'bloggerlink': 'https://blog.naver.com/darigile',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b>이오는 양평 용문산 자연휴양림 :: 용문사 은행나무 산책',
#   'link': 'https://blog.naver.com/neoicon?Redirect=Log&logNo=222670400182',
#   'description': '따뜻해서 <b>봄</b>이 오는게 피부로 느껴지는 날이었어요 겨우내 얼었던 계곡물도 녹아서 흐르고 있었습니다... 용문사 대웅전 아직은 따뜻한 <b>봄</b>이 오지 않아 푸르름이 없지만 <b>봄</b>여름가을 경치가 정말 멋있는... ',
#   'bloggername': '맛있는 음식 이야기',
#   'bloggerlink': 'https://blog.naver.com/neoicon',
#   'postdate': '20220312'},
#  {'title': '‘<b>봄</b> 타나 <b>봄</b>’ <b>봄</b>에 찾아오는 우울한 이 기분, 어떻게 극복할까?',
#   'link': 'https://blog.naver.com/nuacmail?Redirect=Log&logNo=222666103969',
#   'description': '포근해진 날씨 덕분에 한결 가벼워진 옷차림과 이른 개화 소식을 들으며 <b>봄</b>이 성큼 다가왔음을 실감하는 요즘입니다. <b>봄</b>은 아름다운 꽃과 함께하는 <b>봄</b> 축제, 추위로 미뤄뒀던 연인과의 야외 데이트 등... ',
#   'bloggername': '민주평화통일자문회의 블로그',
#   'bloggerlink': 'https://blog.naver.com/nuacmail',
#   'postdate': '20220307'},
#  {'title': 'PLACE _ 덕수궁 _ <b>봄</b> 산책 명소',
#   'link': 'https://blog.naver.com/jsuk1920?Redirect=Log&logNo=222671445898',
#   'description': '3월이 되니 완젼히 <b>봄</b>이 오는가보다. 오래간만의 나들이에 <b>봄</b>바람을 느끼고자 친구와 덕수궁안을 산책했다. 시청역에서 바로 만날 수 있는 덕수궁은 내가 서울에서 애정하는 장소중에 하나이다. 서울의 중심에... ',
#   'bloggername': 'SUMMERBAMBAM',
#   'bloggerlink': 'https://blog.naver.com/jsuk1920',
#   'postdate': '20220313'},
#  {'title': '여성 모자 볼캡 MLB 라이크 여자맨투맨 핫플레이스 <b>봄</b> 코디!',
#   'link': 'https://blog.naver.com/hanbitnuri?Redirect=Log&logNo=222670077505',
#   'description': '다행히 운좋게도 날씨가 갑자기 따뜻해진 완연한 <b>봄</b>날씨여서 아우터없이 차려입은 여자 <b>봄</b> 코디였는데 춥지 않게 잘 다녀왔어요! 어차피 월차내고 평일에 다녀온 여행이라서 전주 한옥마을 핫플레이스임에도... ',
#   'bloggername': '멜로래빗의 홈뷰티',
#   'bloggerlink': 'https://blog.naver.com/hanbitnuri',
#   'postdate': '20220311'},
#  {'title': '향긋한 <b>봄</b>나물요리 취나물 솥밥~☆',
#   'link': 'https://blog.naver.com/aristata73?Redirect=Log&logNo=222668528268',
#   'description': '향긋한 <b>봄</b>나물요리 취나물 솥밥 요즘 <b>봄</b>나물들이 많이 나오고 있지요? 이른<b>봄</b> 나오는 <b>봄</b>나물 중 하나가 취나물일텐데요. 향긋한 취나물로 영양만점 <b>봄</b>나물 솥밥 해먹었어요. 취나물 듬뿍 넣어 만드는... ',
#   'bloggername': '알콩달콩향이네~맛있는이야기!',
#   'bloggerlink': 'https://blog.naver.com/aristata73',
#   'postdate': '20220310'},
#  {'title': '원팬파스타 만들기 <b>봄</b>내음 듬뿍 참나물 오일파스타 요리',
#   'link': 'https://blog.naver.com/love20021102?Redirect=Log&logNo=222666289551',
#   'description': '쉽고 간단하게 만드는 #원팬파스타 만들기 #참나물 #오일파스타 <b>봄</b>내음 가득한 #파스타요리 깔끔하면서 담백한 맛의 오일파스타 중에서 마늘을 넣은 알리오올리오나 조개류를 넣은 봉골레를 종종 만드는데 <b>봄</b>... ',
#   'bloggername': '아토피집밥, 휴식여행일기 by 사랑해김수미',
#   'bloggerlink': 'https://blog.naver.com/love20021102',
#   'postdate': '20220308'},
#  {'title': '만드는법 <b>봄</b>나물무침 돌나물 요리 새콤달콤 매콤 초고추장 <b>봄</b>반... ',
#   'link': 'https://blog.naver.com/jh2y3?Redirect=Log&logNo=222670003060',
#   'description': '#돌나물무침 #<b>봄</b>나물무침 #초고추장만들기 #<b>봄</b>반찬 #<b>봄</b>나물 돌나물무침 <b>봄</b>나물무침 새콤달콤 매콤 초고추장 <b>봄</b>반찬 만들기 안녕하세요. 팬이맘입니다. 입맛 돋우어 주는 #돌나물무침 #<b>봄</b>나물무침... ',
#   'bloggername': '팬이맘의cook',
#   'bloggerlink': 'https://blog.naver.com/jh2y3',
#   'postdate': '20220311'},
#  {'title': '맥 와일드체리컬렉션 <b>봄</b> 벚꽃메이크업',
#   'link': 'https://blog.naver.com/sh_theme?Redirect=Log&logNo=222671706744',
#   'description': '발빠르게 <b>봄</b> 벚꽃메이크업템 준비하자구요~ 오늘 제가 소개할 아이템은 맥 와일드체리컬렉션이에요 <b>봄</b>을 상징하는 꽃 중 하나인 벚꽃, 체리 블라썸에서 영감받은 컬렉션으로, 에너제틱한 핑크 패키지에... ',
#   'bloggername': '쎌리의 시간',
#   'bloggerlink': 'https://blog.naver.com/sh_theme',
#   'postdate': '20220313'},
#  {'title': '㈜와이넬, 싱그러운 <b>봄</b>을 담은 깔라렌따 2종 출시',
#   'link': 'https://blog.naver.com/wine21com?Redirect=Log&logNo=222669934141',
#   'description': "프리미엄 와인수입사 ㈜와이넬(www.winell.co.kr)은 살랑살랑 <b>봄</b>바람 불어오는 사랑의 계절 '<b>봄</b>'을 맞아, 판티니 그룹의 깔라렌따 2종을 출시했다. 화이트데이, 로즈데이 등 연인들이 서로의... ",
#   'bloggername': '와인21닷컴 공식블로그',
#   'bloggerlink': 'https://blog.naver.com/wine21com',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>을 알리는 홍매화가 활짝! 홍매화의 섬 임자도 조희룡적거지',
#   'link': 'https://blog.naver.com/1004_shinan?Redirect=Log&logNo=222665874105',
#   'description': '홍매화의 섬 임자도 조희룡적거지 임자도에 홍매화가 활짝 피어나고 있어요:) 살랑 찾아온 <b>봄</b>기운을... 피어나며 <b>봄</b>의 시작을 알리고 있어요! 홍매화 향기 가득한 조희룡 적거지로 함께 떠나보아요! 우봉... ',
#   'bloggername': '천사섬! 신안군 공식블로그',
#   'bloggerlink': 'https://blog.naver.com/1004_shinan',
#   'postdate': '20220307'},
#  {'title': '3월 12일 봉은사 매화 빼앗긴 들에도 <b>봄</b>은 오는가… [서울 강남... ',
#   'link': 'https://blog.naver.com/bluedaisy706?Redirect=Log&logNo=222670423526',
#   'description': '영각으로 향하는 계단을 올라가며 작년 <b>봄</b>과 사뭇 다름을 몸소 느낄 수 있었다. 이것은 작년 3월 6일에... 그래도 <b>봄</b>이 왔다고 피어난 매화. 전체적으로 10% 정도 개화를 한 상태였다. 피자마자 바닥에 떨어진... ',
#   'bloggername': '구르메 달 가드시',
#   'bloggerlink': 'https://blog.naver.com/bluedaisy706',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b>들이와 자동차, 완벽한 일요일 (23개월)',
#   'link': 'https://blog.naver.com/maargot?Redirect=Log&logNo=222671347049',
#   'description': '오늘도 인스턴트 커피로 하루 시작 세식구 공원 출동 날씨가 <b>봄</b>이야 원래 커피 못마시는 타입인데 아들이 21개월 되자마자 매일  달려라 하니 아니 달려라 <b>봄</b>들 때문에 짐 리어카가 되어버린 유아차 예쁜 돗자리... ',
#   'bloggername': '너훌너훌 날아올라',
#   'bloggerlink': 'https://blog.naver.com/maargot',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>, 여름, 가을... 주택마당 루틴의 시작 ~',
#   'link': 'https://blog.naver.com/j492400?Redirect=Log&logNo=222670652597',
#   'description': '만들어 <b>봄</b>을 준비해보겠다고 다짐을 했건만 정작 EM발효액을 넣고 거름이 될 수 있게 준비하는 시간을... 그리고 본격적인 <b>봄</b>을 맞이 하기 위해 말라진 가지를 정리하고 덩쿨장미의 가지를 정리해주고 마당 곳곳... ',
#   'bloggername': '스윗홈오븐',
#   'bloggerlink': 'https://blog.naver.com/j492400',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b> 도다리, 간단하고 맛있게 회덮밥만들기',
#   'link': 'https://blog.naver.com/sy3015?Redirect=Log&logNo=222668640144',
#   'description': '<b>봄</b><b>봄</b><b>봄</b> <b>봄</b>이왔어요~♬ 날씨가 너무도 따땃해졌다. 진정 <b>봄</b>이 온듯. 어제, 아가들 낮잠시간이여서 드라이브 갔다가 들른 오이도에서 <b>봄</b>도다리 회를 사왔다. #<b>봄</b>도다리 #도다리회 #회덥밥만들기 #새콤달콤회덮밥... ',
#   'bloggername': '깡양의_시시콜콜이야기:D',
#   'bloggerlink': 'https://blog.naver.com/sy3015',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>나들이 전시장:Teresa Freitas 전시장',
#   'link': 'https://blog.naver.com/imga114?Redirect=Log&logNo=222671369533',
#   'description': 'Springtime Delight <b>봄</b>날의 나들이길은 복장부터가 참 어설프다 <b>봄</b>바람이 차가워도 한겨울 두터운 패딩을 걸치자니 투박하고 거북스럽고, 스웨터에 홑겹 점퍼만 걸치면 사정없이 겨울 닮은 냉기가 파고들어... ',
#   'bloggername': '여행과 이야기',
#   'bloggerlink': 'https://blog.naver.com/imga114',
#   'postdate': '20220314'},
#  {'title': '3월 국내 여행지 추천 <b>봄</b>꽃축제:: 3월, 4월 가볼만한곳',
#   'link': 'https://blog.naver.com/jamjma98?Redirect=Log&logNo=222669505381',
#   'description': '3월 국내 여행지 추천 <b>봄</b>꽃축제:: 3월, 4월 가볼만한곳 남쪽 지방을 시작으로 <b>봄</b>꽃이 피고 있습니다. 매화, 개나리, 유채꽃, 그리고 벚꽃까지 각 지방에서는 매년 3월 중순을 시작으로 <b>봄</b>꽃축제를 열었는데요.... ',
#   'bloggername': '너구리 가족의 땅굴 밖 여행',
#   'bloggerlink': 'https://blog.naver.com/jamjma98',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>이 내려앉은 집',
#   'link': 'https://blog.naver.com/babpoolk?Redirect=Log&logNo=222671912051',
#   'description': '결국 이번 <b>봄</b> 들어서 약 십 이년 만에 드디어 새 커튼을 달았다. 색은 여전히 차분하면서 다른 색들을... 조금은 가을빛 같았던 거실이 <b>봄</b>이 오면서 <b>봄</b>볕으로 변한 느낌이다. 뜨개니트로 만들어졌던 쿠션도 <b>봄</b>을... ',
#   'bloggername': '본 질 찾 기',
#   'bloggerlink': 'https://blog.naver.com/babpoolk',
#   'postdate': '20220314'},
#  {'title': '타이음식/동면안하는곰/오지않는<b>봄</b>/아직도겨울',
#   'link': 'https://blog.naver.com/neidin80?Redirect=Log&logNo=222670973405',
#   'description': '그치만 오지도 않은 <b>봄</b>방학 일주일. 이번달은 감기로 한주 빠지고 <b>봄</b>방학으로 한주 빠지고 한달에 4번가고 몇백불;;; 속아프다….. 학교 끝나고 신나게 달리기하고 고드름 가지고 놀기. 엘사랍니다. 집에와서... ',
#   'bloggername': '바위처럼 굳건하게![Bella.K]',
#   'bloggerlink': 'https://blog.naver.com/neidin80',
#   'postdate': '20220312'},
#  {'title': '냉이튀김 만들기 3월제철음식 <b>봄</b>나물 튀김요리',
#   'link': 'https://blog.naver.com/pingu528?Redirect=Log&logNo=222666779546',
#   'description': '향긋한 <b>봄</b>나물 튀김요리 냉이튀김 만들기 맛보면 반하실걸요~! 지난번에 냉이무침 만들고 #냉이튀김 만들어 먹으려고 냉이 두어줌 남겨두었어요. #3월제철음식 #<b>봄</b>나물 로 대표적인 #냉이 는 쌉싸름하면서도... ',
#   'bloggername': '웅이맘의 달콤키친',
#   'bloggerlink': 'https://blog.naver.com/pingu528',
#   'postdate': '20220308'},
#  {'title': '이상면 작가가 참여한 &lt;미세한 <b>봄</b>&gt; 전시',
#   'link': 'https://blog.naver.com/captainrock1?Redirect=Log&logNo=222670152227',
#   'description': '크라잉넛 기타리스트이자 멋쟁이 화백인 이상면 작가가 참여한 &lt;미세한 <b>봄</b>&gt; 전시에 다녀왔습니다. 을지로에 위치한 대림상가 3층, 유서깊은 역사와 추억들이 현재까지 이어지고, <b>봄</b>을 기다리는... ',
#   'bloggername': '캡틴락 월드',
#   'bloggerlink': 'https://blog.naver.com/captainrock1',
#   'postdate': '20220311'},
#  {'title': '해르만 헤세,<b>봄</b>',
#   'link': 'https://blog.naver.com/icde119?Redirect=Log&logNo=222671428686',
#   'description': '이거 했더니 손톱밑이 까맣다 ㅜ 겨울 책 읽기도 전에 <b>봄</b>이 왔다. 집주인이 벽걸이티비 놓던 자리에 딱 맞는 가리개를 찾았다. 예술의 전당에서, 책갈피끈도 <b>봄</b>, 겨울 책은 제주에서, <b>봄</b> 책은 이태원에서... ',
#   'bloggername': '식육식탁,퇴근후집밥',
#   'bloggerlink': 'https://blog.naver.com/icde119',
#   'postdate': '20220313'},
#  {'title': '소문난 <b>봄</b> 코디 장인 브랜드 zip - 데일리룩 ver',
#   'link': 'https://blog.naver.com/jayuyu?Redirect=Log&logNo=222669863637',
#   'description': '(좌)EN OR (우)brenda brenden 기다리고 기다리던 <b>봄</b>. 아침 저녁으론 아직 춥지만, 낮엔 제대로 <b>봄</b> 기운이 느껴지더라구요. 계절이 바뀌면서 가장 고민되는 것이 스타일링이죠. 사실 옷장에 옷은... ',
#   'bloggername': '제인 블로그',
#   'bloggerlink': 'https://blog.naver.com/jayuyu',
#   'postdate': '20220311'},
#  {'title': '상동호수공원에 찾아온 <b>봄</b> 꽃 소식',
#   'link': 'https://blog.naver.com/r9600495?Redirect=Log&logNo=222669947279',
#   'description': '상동호수공원에서 만난 <b>봄</b> 꽃 소식을 남깁니다. 겨우내 누렇게 메말라 있던 공원에 파란 새싹들이... 그래도 산책로를 따라 남아있는 몇몇 매화나무에서 <b>봄</b> 소식을 만날 수 있어 다행입니다.  이번 주말 <b>봄</b>을... ',
#   'bloggername': '달빛나그네 등산, 여행, 일상 이야기',
#   'bloggerlink': 'https://blog.naver.com/r9600495',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>꽃',
#   'link': 'https://blog.naver.com/kongirang02?Redirect=Log&logNo=222671081524',
#   'description': '<b>봄</b>꽃 <b>봄</b>이되면 빈화단에 꽃을심고싶어 땅을파면 매번 지나친 욕심이란걸 느끼게됩니다 땅밑에 이미 겨울을 이긴알뿌리들이 내가 신나서 했던 호미질에 반조각나고 얼어죽은 빈화분에 빨리꽃을 심고싶어 <b>봄</b>꽃... ',
#   'bloggername': '콩이랑농원 콩이랑된장학교',
#   'bloggerlink': 'https://blog.naver.com/kongirang02',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>이 성큼',
#   'link': 'https://blog.naver.com/punkwitch?Redirect=Log&logNo=222670846286',
#   'description': '<b>봄</b>이 와서 <b>봄</b>느낌으로 냉이 된장국 정식을 시켜보았습니다. 처음 봤을 때 두부를 너무 닮아서 홀린 듯이 쳐다봤던 동물병원 고양이. 쁘띠두부라고 부르며 퇴근길이면 오늘도 만날 수 있으려나, 보러 간다. 이렇게... ',
#   'bloggername': '세상의 끝',
#   'bloggerlink': 'https://blog.naver.com/punkwitch',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b> 냄새 맡아보기',
#   'link': 'https://blog.naver.com/seel48?Redirect=Log&logNo=222671367765',
#   'description': '이른 아침에는 <b>봄</b>비가 내려 촉촉해진 공원으로 들어갔다. <b>봄</b>을 영어로는 Spring이라 하는데 용수철처럼 톡 튀어 오르는 계절이라는 뜻일까 생각하게 하는 <b>봄</b>의 모습들이 여기저기서 눈에 뜨인다. 언제 이렇게... ',
#   'bloggername': '커피를 사랑하는 빈 님의 블로그',
#   'bloggerlink': 'https://blog.naver.com/seel48',
#   'postdate': '20220313'},
#  {'title': '3월 카페제라 <b>봄</b> 풍경',
#   'link': 'https://blog.naver.com/crystal2443?Redirect=Log&logNo=222669646413',
#   'description': '<b>봄</b>맞이 풍경 앙상한 밤나무에 생기가 느껴져요. 저기 아래 가지에 앉아있는 맷비둘기 보이시나요? 아침에 구구~하고 우는데, 반갑고 기분이 좋았습니다. 요즘 짝을 찾나봐요. 우리 동네는 맷비둘기가 울면 <b>봄</b>이... ',
#   'bloggername': '정원제라',
#   'bloggerlink': 'https://blog.naver.com/crystal2443',
#   'postdate': '20220311'},
#  {'title': "대덕문화원 '두근두근 설레<b>봄</b> 행사'",
#   'link': 'https://blog.naver.com/daedeokgu?Redirect=Log&logNo=222669364648',
#   'description': "대덕문화원 '두근두근 설레<b>봄</b> 행사' 어느새 3월도 중순을 향해 가고 있는데요, 3월이 되면 <b>봄</b>이라는 단어가 어울리게 되며 새 학기 시작과 함께 두근두근 조금은 설레는 마음으로 보내는 것 같습니다.... ",
#   'bloggername': '주민행복 대덕 이야기',
#   'bloggerlink': 'https://blog.naver.com/daedeokgu',
#   'postdate': '20220311'},
#  {'title': '눈부시게 아름다웠던 나의 <b>봄</b>에게 /한섬 시집/인생에세이에... ',
#   'link': 'https://blog.naver.com/milk916?Redirect=Log&logNo=222670140567',
#   'description': '나의 <b>봄</b>에게] / 한섬 시인 주변 지인들에게 선물로 드리면 좋을 거 같아서 여러 권 구입했습니다 2권이상... 나의 <b>봄</b>에게/ 는 인생의 희로애락을 사계에 녹여낸... 인생에세이에 감성을 더한 시집입니다... ',
#   'bloggername': '도시다람쥐의 소꿉놀이',
#   'bloggerlink': 'https://blog.naver.com/milk916',
#   'postdate': '20220311'},
#  {'title': '야드로 - 상쾌한 <b>봄</b> 바람의 여인 벼룩',
#   'link': 'https://blog.naver.com/kenilworth08?Redirect=Log&logNo=222671409403',
#   'description': '제품설명 : 사이즈는 34X15Cm의 향긋한 <b>봄</b> 바람을 맞이하는 레이디 피겨린입니다. <b>봄</b> 바람의 여인 입니다. 눈부시게 아름다운 <b>봄</b>의 그녀... 찬란한 <b>봄</b>의 여신같은 자태를 뽐내며 상쾌한 <b>봄</b> 바람을... ',
#   'bloggername': '런던퀸 앤틱샵',
#   'bloggerlink': 'https://blog.naver.com/kenilworth08',
#   'postdate': '20220314'},
#  {'title': '숲길정원에서 힐링도 하고, <b>봄</b>도 느껴요!',
#   'link': 'https://blog.naver.com/yangju619?Redirect=Log&logNo=222671425090',
#   'description': '한 낮에 기온이 20도 가까이 올라가는 것을 보니 정말 따뜻한 <b>봄</b>이 온 것이 느껴집니다. 아직은 <b>봄</b> 꽃을 기대할 수는 없지만 가벼운 옷차림으로 <b>봄</b>나들이 가기 좋은 숲길정원을 소개합니다. 숲길 정원은 양주시... ',
#   'bloggername': '양주시 공식블로그 [클릭양주]',
#   'bloggerlink': 'https://blog.naver.com/yangju619',
#   'postdate': '20220313'},
#  {'title': '미니백 추천 엘레강스파리 러셀러 산뜻한 <b>봄</b>코디!',
#   'link': 'https://blog.naver.com/hug387?Redirect=Log&logNo=222670984099',
#   'description': '헬로우 유지니에요 :3 오늘은 얇은 핸드메이드 코트도 살짝 덥게 느껴질만큼 포근한 날씨였던거 같아요~ 다음주부터는 청자켓, 얇은 니트등으로 <b>봄</b> 코디를 시작하려고 가방도 산뜻한 <b>봄</b> 느낌으로 새로... ',
#   'bloggername': '어여쁜 유지니아',
#   'bloggerlink': 'https://blog.naver.com/hug387',
#   'postdate': '20220313'},
#  {'title': '[예약] 카렐 2022 <b>봄</b> 신상품 ②',
#   'link': 'https://blog.naver.com/dalkis0908?Redirect=Log&logNo=222670905052',
#   'description': '어제, 오늘은 기온이 부쩍 올라서 <b>봄</b>을 느낄 수 있었어요...^^ 오늘은 3월 초에 발매된 몇 가지... 가든 파티 티백 5p / 10p 세트 오랜만에 돌아온 가든 파티 티백이에요~^^ <b>봄</b>이 오면 자주 등장했던 티였는데, 몇... ',
#   'bloggername': '쿠 나 ♥ Tea is fun !',
#   'bloggerlink': 'https://blog.naver.com/dalkis0908',
#   'postdate': '20220312'},
#  {'title': '나에게 <b>봄</b>을 선사하다',
#   'link': 'https://blog.naver.com/korea_beauty?Redirect=Log&logNo=222670728146',
#   'description': '취향의 <b>봄</b>화초들로만 가득했다. 마음 같아서는 장바구니 가득 들이고 싶었지만 전차를 타고 집까지 모시고 가야하는 어여뿐 화초들이기에 딱 3가지만 골랐다. 나에게 선사하는 <b>봄</b> 화초들 겹꽃 마가렛 モリンバ... ',
#   'bloggername': ':: 이즈의 사계절 이야기 ::',
#   'bloggerlink': 'https://blog.naver.com/korea_beauty',
#   'postdate': '20220312'},
#  {'title': '[<b>봄</b>.그리고.겨울보내기]',
#   'link': 'https://blog.naver.com/phk4982?Redirect=Log&logNo=222669675118',
#   'description': '부끄러운듯 꽃몽우리속 움뜨린 빼꼼이도 <b>봄</b>이 왔다~~~꺄 얼굴 내민 빼꼼이들이 서로 공존하는 <b>봄</b><b>봄</b><b>봄</b> <b>봄</b>이 왔어요~♡ 블로그 쥔장의 계절 흐헝 좋다~ 언제부터인가 <b>봄</b>이 엄청 짧아졌어요 <b>봄</b>이다~샤랄라~ 하는데... ',
#   'bloggername': '해강 입니다.',
#   'bloggerlink': 'https://blog.naver.com/phk4982',
#   'postdate': '20220311'},
#  {'title': '여성 바람막이 <b>봄</b>자켓 점퍼 아우터 마음에 쏙 드는 이유',
#   'link': 'https://blog.naver.com/mamastable9?Redirect=Log&logNo=222667247938',
#   'description': '여성 바람막이는 <b>봄</b>, 여름, 가을 모든 계절에 필수 아이템이죠. 가방에 하나씩 꼭 가지고 다녀야 하는... 입었을 때 착용감부터가 다르게 느껴지거든요~ 모든 비와 바람도 잘 막아줄 것 같아서 여성 <b>봄</b>자켓으로... ',
#   'bloggername': 'ellin.kr - 엘린',
#   'bloggerlink': 'https://blog.naver.com/mamastable9',
#   'postdate': '20220308'},
#  {'title': '[포항수제도시락] <b>봄</b> 나들이 DIY 도시락',
#   'link': 'https://blog.naver.com/ingan3?Redirect=Log&logNo=222671359798',
#   'description': "날씨도 정말 많이 풀린것 같습니다 : ) <b>봄</b>냄새도 살짝 나구요! <b>봄</b>이 이렇게 오고있는 소식을 전하고 있습니다♥ '포항 <b>봄</b> 나들이 DIY 도시락' 팝만두, 월남쌈, 샌드위치, 곰돌이유부초밥, 잎쌈밥 이제 <b>봄</b> 나들이... ",
#   'bloggername': '스윗파르페',
#   'bloggerlink': 'https://blog.naver.com/ingan3',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>을그리며놀다',
#   'link': 'https://blog.naver.com/zevang?Redirect=Log&logNo=222671118330',
#   'description': '<b>봄</b> 너는 자꾸만 나에게 엉덩이를 번쩍 쳐들고 코를 땅에 박고 들여다 보길 바라는구나 작년<b>봄</b> 이었음 벌써 나왔을 아이들이 보이지 않아 조바심에 자꾸만 흙을 들쳐보게된다. 물망초를 심을려고... ',
#   'bloggername': '한옥스몰정원',
#   'bloggerlink': 'https://blog.naver.com/zevang',
#   'postdate': '20220313'},
#  {'title': '■ <b>봄</b>, 코로나 그리고 태극권 수련. ♬',
#   'link': 'https://blog.naver.com/taij1429?Redirect=Log&logNo=222671141698',
#   'description': '■ <b>봄</b>, 코로나 그리고 태극권 수련. ♬ 어제 관악산에 오르니 바람이 정말 비단처럼 부드럽습니다. 게다가 <b>봄</b>을 재촉하는 <b>봄</b>비 또한 저녁 무렵 하늘에서 내립니다. 충분히 내려서 산불 진화에 도움이 되었으면... ',
#   'bloggername': '서명원의 태극권이야기',
#   'bloggerlink': 'https://blog.naver.com/taij1429',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>. <b>봄</b>. <b>봄</b>. <b>봄</b>이 왔네요',
#   'link': 'https://blog.naver.com/osirokhern?Redirect=Log&logNo=222670146661',
#   'description': '03.10(목) <b>봄</b>을 맞이하러 서귀포로 나갔어요. 서귀포시 색달동 3384-4 엉덩물 계곡 아직은 조금 이른 듯... 2020.03.11(금) #<b>봄</b>이오는소리 를 들으러 #오시록헌앞바다 로 나갔어요. 제주시 한림읍 금능리... ',
#   'bloggername': '제주도 프라이빗펜션, 오시록헌(Osirokhern)',
#   'bloggerlink': 'https://blog.naver.com/osirokhern',
#   'postdate': '20220311'},
#  {'title': "<b>봄</b>을 준비하는 당신을 위한 '창비 시크릿 서평단' 모집 안내",
#   'link': 'https://blog.naver.com/changbi_book?Redirect=Log&logNo=222669203482',
#   'description': '#창비세계문학 #시크릿서평단 #모집 차가운 바람이 조금씩 물러나고 어느새 <b>봄</b>이 다가오고 있는 것이... 함께 계절과 감상을 나누어요! #세계문학 #이벤트 #<b>봄</b> #서평단 #창비 #시크릿 #비밀 #소설 #시',
#   'bloggername': '창비 블로그',
#   'bloggerlink': 'https://blog.naver.com/changbi_book',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>냄새가 보인다',
#   'link': 'https://blog.naver.com/sl8157?Redirect=Log&logNo=222669688965',
#   'description': '너무 예쁜 <b>봄</b>날 하교 후 꼬맹이와 놀이터 사진 찍고 보니 하늘이 너무 예쁘네 파란 캔버스에 흰색 물감 번진 것처럼 너무 예뻐서 하늘만 다시 한번 찰칵 찰칵 올해는 또 이 예쁜 <b>봄</b>이 얼마나 빨리 지나가려나... ',
#   'bloggername': '보관함',
#   'bloggerlink': 'https://blog.naver.com/sl8157',
#   'postdate': '20220311'},
#  {'title': '이벤트] &quot;우연히 만났으면 하는 순간이 있으신가요?&quot; &lt;우연히, <b>봄</b>&gt;',
#   'link': 'https://blog.naver.com/tomntoms01?Redirect=Log&logNo=222666897934',
#   'description': '다시 <b>봄</b>이 찾아왔습니다. 탐앤탐스 &lt;Run into Cherry Blossom&gt; 벚꽃 음료처럼, 여러분의 마음 속에도 또 포근한 <b>봄</b> 계절의 바람마저도 달콤하고 보드라운 핑크빛 설렘이 가득합니다. 혹시 여러분도, 우연히... ',
#   'bloggername': '탐앤탐스 커피 공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/tomntoms01',
#   'postdate': '20220310'},
#  {'title': '응답하라 인천시! <b>봄</b>이 되면 떠오르는  추억 공유 EVENT',
#   'link': 'https://blog.naver.com/incheontogi?Redirect=Log&logNo=222669818389',
#   'description': '<b>봄</b>이 되면 떠오르는 추억 공유 EVENT 이벤트 안녕하세요. 인천시입니다. <b>봄</b>을 맞이해, 따끈따끈한 <b>봄</b>맞이 이벤트를 진행합니다! 어떤 이벤트냐고요? 바로바로!! 응답하라 인천시! <b>봄</b>이 되면 떠오르는... ',
#   'bloggername': '인천광역시 공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/incheontogi',
#   'postdate': '20220314'},
#  {'title': '<b>봄</b>신상 프리오더 이벤트',
#   'link': 'https://blog.naver.com/boabox?Redirect=Log&logNo=222663738464',
#   'description': '22SS 더케이가 추천해 드리는 <b>봄</b>룩! 요 아이템만 있으면 올 <b>봄</b> 스타일링 문제없다. 간절기 제품은 선오더 이 후 빠른품절 예상되오니 고민하지마시고 프리오더이벤트 기간 중 합리적인 가격으로... ',
#   'bloggername': 'cuteworld',
#   'bloggerlink': 'https://blog.naver.com/boabox',
#   'postdate': '20220304'},
#  {'title': '<b>봄</b> 전갱이 회는 맛있다',
#   'link': 'https://blog.naver.com/pmhswat?Redirect=Log&logNo=222669908418',
#   'description': '올려지며 <b>봄</b> 시즌 지금부터 여름~가을~겨울까지 어찌 보면 연중 만나볼 수 있는 물고기인데 수온이... 올려지는 <b>봄</b> 시즌이다 중치급의 전갱이들~~♡ 오늘 저녁 찬거리로 당첨~~^^ 횟감은 차지고 고소하다 차가운... ',
#   'bloggername': '<거제도선상낚시>노인과바다이야기',
#   'bloggerlink': 'https://blog.naver.com/pmhswat',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>멀미',
#   'link': 'https://blog.naver.com/namooga?Redirect=Log&logNo=222670785603',
#   'description': '아직 꽃사태도 아닌데 벌써 멀미라니 이 <b>봄</b>이 나를 가두려는겐가. 소중한 내 <b>봄</b>날을 앗아가지는 않을까 살짝 걱정이다. 걱정일랑 뚝, 아무리 어지러워도 아파트 화단의 매화꽃은 희게 빛나고 벚나무 가지마다... ',
#   'bloggername': '소요유',
#   'bloggerlink': 'https://blog.naver.com/namooga',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b>꽃 사진 소니 접사 렌즈 매화 홍매화 냉이꽃 산수유 봉우리',
#   'link': 'https://blog.naver.com/kisss1970?Redirect=Log&logNo=222670457174',
#   'description': '코로나 인지 아닌지 모르겠지만 열감과 몸살이 겹쳐 있어도 꽃을 보니 기분좋네요 <b>봄</b>이 저만치... 속상할듯요 ㅎ 이웃님 주말 잘 지내세요. 하루가 겁나 길어요.ㅎ #<b>봄</b>사진#<b>봄</b>꽃사진#매화#홍매화#코로나키트음성',
#   'bloggername': '빠끔살이',
#   'bloggerlink': 'https://blog.naver.com/kisss1970',
#   'postdate': '20220312'},
#  {'title': '커버낫 남자 옥스포드 셔츠를 활용한 <b>봄</b> 코디 추천!',
#   'link': 'https://blog.naver.com/bj0203?Redirect=Log&logNo=222670685839',
#   'description': '[유뱅의 데일리룩 블로그] 커버낫 남자 옥스포드 셔츠를 활용한 <b>봄</b> 코디 추천! 커버낫에서 <b>봄</b> 신상으로 나온 남자 옥스포드 셔츠를 활용하여 <b>봄</b> 코디를 해봤다. 커버낫 C로고 오버핏셔츠로 베이직한 남자... ',
#   'bloggername': '유뱅의 데일리룩 블로그/리뷰',
#   'bloggerlink': 'https://blog.naver.com/bj0203',
#   'postdate': '20220312'},
#  {'title': '[비바+1911::초코+1134] <b>봄</b>이다!',
#   'link': 'https://blog.naver.com/twinvely?Redirect=Log&logNo=222670294216',
#   'description': '아이들과 앉아서 잎들 주우며 놀고있는데 등이 따스함을 더워 타는 듯이 뜨거웠다. 이제 증말 <b>봄</b>인가봐. 하는 생각에 콧노래가 나왔다. 간만에 느끼는 따뜻한 날씨❤️ 이제 정말 <b>봄</b>이 왔나보다.',
#   'bloggername': '트윈블리의 Real_log',
#   'bloggerlink': 'https://blog.naver.com/twinvely',
#   'postdate': '20220312'},
#  {'title': '/shopping list/ <b>봄</b>이 오니까 물욕이 터지고..',
#   'link': 'https://blog.naver.com/dmsqls1010?Redirect=Log&logNo=222670902065',
#   'description': '확실히 날씨가 따뜻해지니까 <b>봄</b>옷이 사고싶고.. 뭘 막 사고싶어지네.. matin kim 마뗑킴 178,000 matin kim... <b>봄</b>맞이 오지게 해본다.. 상큼하게.. 타입서비스웹 국민 볼캡 된 거 같은 타입서비웹 <b>봄</b>엔 볼캡이지..... ',
#   'bloggername': 'my name is Elodie',
#   'bloggerlink': 'https://blog.naver.com/dmsqls1010',
#   'postdate': '20220312'},
#  {'title': '[최현진 기자] 제철 <b>봄</b>나물에는 무엇이 있을까요?',
#   'link': 'https://blog.naver.com/kfripr?Redirect=Log&logNo=222669778473',
#   'description': '오늘은 제철 <b>봄</b>나물의 종류와 효능, 고르는 방법 등을 알아보려고 합니다! 어느덧 겨울이 지나고 <b>봄</b>이 한 발짝 다가왔습니다 :) <b>봄</b> 하면 또 제철 나물들을 빼놓을 수 없지요~ <b>봄</b>나물에는 무엇이 있고 어떠한... ',
#   'bloggername': '좋은세상을 만드는 사람들, 한국식품연구원',
#   'bloggerlink': 'https://blog.naver.com/kfripr',
#   'postdate': '20220311'},
#  {'title': '[일본일상] 평일도 주말도 불태우는 <b>봄</b> 일상',
#   'link': 'https://blog.naver.com/tkznfkdlty05?Redirect=Log&logNo=222670759047',
#   'description': '<b>봄</b> 오는 소리가 들려서 요즘 넘 좋다❤️ 진짜 <b>봄</b>이댜 #우에시마커피 에서 코울슬로계란샐러드샌드위치 먹었는데 데워서 줘서 그런지 맛있어서 기절할뻔ㅠㅠ 친구가 카페 요리를 왜그렇게 맛있게... ',
#   'bloggername': '보예의 Library in Wonderland',
#   'bloggerlink': 'https://blog.naver.com/tkznfkdlty05',
#   'postdate': '20220312'},
#  {'title': '오늘의 일기: 22년의 <b>봄</b>',
#   'link': 'https://blog.naver.com/happyhyojin7?Redirect=Log&logNo=222670877156',
#   'description': '창문 쪼꼼 야밤의 도담 <b>봄</b>이 왔다고 미처 생각도 못했는데 <b>봄</b>이다. 매일 아직은 춥고 아직은 조금 어두운 이른 아침에 일어나 회사를 간다. 하루종일 사무실에서 일만 하다 해가 진 까만 밤이 되어 집에... ',
#   'bloggername': '손붕의 다이어리',
#   'bloggerlink': 'https://blog.naver.com/happyhyojin7',
#   'postdate': '20220312'},
#  {'title': '세발나물무침 세발나물 요리 <b>봄</b>나물 종류',
#   'link': 'https://blog.naver.com/kimhy004?Redirect=Log&logNo=222661807646',
#   'description': '추워서 <b>봄</b>이 오지 않을 것 같았는데 벌써 3월이 되었어요. 오늘부터 개학도 하고 새학기의 출발이라 아침이 많이 분주하셨죠? 점심시간이 지났는데 점심은 드셨는지요... 이번에 보여드릴 #레시피 는 #<b>봄</b>나물... ',
#   'bloggername': '들꽃향기 건강 밥상',
#   'bloggerlink': 'https://blog.naver.com/kimhy004',
#   'postdate': '20220302'},
#  {'title': '런던 일상 - <b>봄</b>이 오고 있다',
#   'link': 'https://blog.naver.com/qkr90000?Redirect=Log&logNo=222670159887',
#   'description': '와서 <b>봄</b>옷부터 가방, 신발까지 우리 둘 다 열심히 무언가를 사재기 시작했다. 미니멀리즘 되기는 글렀다고 생각했던 2월. 그래도 오랜만에 쇼핑하니까 나한테 선물해주는 기분이 나고 좋더라. 예쁜 <b>봄</b>옷입고... ',
#   'bloggername': 'Boram in London',
#   'bloggerlink': 'https://blog.naver.com/qkr90000',
#   'postdate': '20220311'},
#  {'title': '남자 <b>봄</b> 점퍼 이렇게 코디해 보는 건 어때요?',
#   'link': 'https://blog.naver.com/dbsqhr223?Redirect=Log&logNo=222670042359',
#   'description': '안녕하세요 여러분~윌스토어입니다 :) 이제 겨울이 지나고 정말 <b>봄</b>이 오긴 하려나 봐요 아침에... 대신 저는 오늘 <b>봄</b> 데일리 저격 상품인 남자 <b>봄</b> 점퍼를 추천하고 코디도 같이 추천드릴게요! 자~ 그럼 각 잡고... ',
#   'bloggername': 'willstore / ladywill',
#   'bloggerlink': 'https://blog.naver.com/dbsqhr223',
#   'postdate': '20220311'},
#  {'title': '토너추천 <b>봄</b>이니까 산뜻하게!',
#   'link': 'https://blog.naver.com/lgy0209?Redirect=Log&logNo=222667259336',
#   'description': '안녕하세요 여러분~ 저는 <b>봄</b>이 올 때쯤이면 왜이렇게 마음이 간질거리는지요. 때문인지 뭔가 예뻐지고 싶고, 겨울 동안 불려놓은 살들도 빼야겠단 생각이 드는데요. 역시나 이번에도 솟구쳐서 다이어트도... ',
#   'bloggername': '이또의 일상/리뷰 이야기 :)',
#   'bloggerlink': 'https://blog.naver.com/lgy0209',
#   'postdate': '20220309'},
#  {'title': '<b>봄</b> 가방 추천, 디자이너 브랜드 오아즈 네스트백.',
#   'link': 'https://blog.naver.com/sxxhx?Redirect=Log&logNo=222671796449',
#   'description': "브랜드 오아즈(oaz)의 철학 오늘은 오랜만에 <b>봄</b> 가방 추천 포스팅을 준비했습니다. 다름 아니라 제가... 2022 <b>봄</b> 가방 추천, 오아즈의 '네스트백' 디자이너 가방 브랜드 오아즈 3월 4일 네스트백을 오픈 한 이후... ",
#   'bloggername': '감성적인 창조자',
#   'bloggerlink': 'https://blog.naver.com/sxxhx',
#   'postdate': '20220314'},
#  {'title': '하남스타필드 신혼부부 <b>봄</b>준비 커피쿠폰팁까지',
#   'link': 'https://blog.naver.com/daheeprint?Redirect=Log&logNo=222670157051',
#   'description': '일상 공유하는게 취미가 되버렸지 머예요 오늘은 정확히 3/11일 날씨가 <b>봄</b>이 되었어요 그래서 <b>봄</b>나들이 겸 하남스타필드 실내데이트 다녀왔습니다:) 오늘 딱 시작한 커피쿠폰 팁도 드릴게요 사진 한장에 인스타... ',
#   'bloggername': '고디공간만의 트랜디함을 담아, 고디자인스튜디오',
#   'bloggerlink': 'https://blog.naver.com/daheeprint',
#   'postdate': '20220311'},
#  {'title': '<b>봄</b>~여름 거제도 저구항 ~ 소매물도 갈매기 사진',
#   'link': 'https://blog.naver.com/corps69?Redirect=Log&logNo=222670098464',
#   'description': '오래전에 다녀왔던 거제 여행 사진을 정리하던 중 <b>봄</b> 거제도 여행 사진에서 소매물도로 가는 배편에서... 추운 겨울이 가고 이제 완연한 <b>봄</b>기운을 느낄 수 있는데 바다 또한 영등철이 막바지에 접어들어서 수온도... ',
#   'bloggername': '내가 꿈꾸는 인테리어',
#   'bloggerlink': 'https://blog.naver.com/corps69',
#   'postdate': '20220311'},
#  {'title': '국내 <b>봄</b> 여행지 진주 매화숲 3월 꽃구경 진주 여행',
#   'link': 'https://blog.naver.com/tcacyc?Redirect=Log&logNo=222670976693',
#   'description': '국내 <b>봄</b> 여행지 진주 여행 3월 꽃구경 진주 매화숲 3월의 꽃 매화를 보러 남쪽으로 다니며 <b>봄</b>맞이 여행을 하고 왔습니다. 유명한 곳부터 새로운 곳까지 다니며 매화 향기를 가득 맡고 상쾌한 기분을 가득 품고... ',
#   'bloggername': '일상탈출',
#   'bloggerlink': 'https://blog.naver.com/tcacyc',
#   'postdate': '20220313'},
#  {'title': "[웹툰] 3월의 미식일기_'<b>봄</b>나물'을 먹어보자(with 냉이·달래)",
#   'link': 'https://blog.naver.com/rda2448?Redirect=Log&logNo=222662499076',
#   'description': '3월의 미식일기_<b>봄</b>나물을 먹어보자 여러분은 나물을 생각하면 어떤 이미지가 떠오르시나요? 콩나물, 시금치 그리고 고사리와 같이 친숙한 나물들이 생각나실텐데요, 오늘은 <b>봄</b>의 시작을 알리는 <b>봄</b>나물 중... ',
#   'bloggername': "농촌진흥청 블로그 '농다락'",
#   'bloggerlink': 'https://blog.naver.com/rda2448',
#   'postdate': '20220303'},
#  {'title': '(<b>봄</b>나물)햇머위고추장무침  입맛 팍팍 살려요~~',
#   'link': 'https://blog.naver.com/007crr?Redirect=Log&logNo=222664106535',
#   'description': '<b>봄</b>나물의 대명사 햇머위가 나왔어요. 저는 하우스 안에 심기도 하였지만 그것은 나중에 먹기로 하고... 라고 하니 사장님도 어쩔 수 없심더 하면서 웃더군요 소고기 먹는 대신 <b>봄</b> 보약 햇머위 먹지요 하면서... ',
#   'bloggername': '비바리의 숨비소리(친환경밥상)',
#   'bloggerlink': 'https://blog.naver.com/007crr',
#   'postdate': '20220304'},
#  {'title': '경이로운 <b>봄</b>! 예쁨주의보 패션 트렌드 3',
#   'link': 'https://blog.naver.com/designpress2016?Redirect=Log&logNo=222663701142',
#   'description': '팬데믹에 얼어붙은 몸과 마음을 녹일 아름답고도 서정적인 트렌드가 <b>봄</b>으로 향한다. Spring Trend 1 밀레니얼 핑크 사진 출처 | 2022 SS 마이클 코어스 <b>봄</b>과 핑크라! 듣기만 해도 달콤한 조합이다. 핑크에 대한... ',
#   'bloggername': '네이버 디자인',
#   'bloggerlink': 'https://blog.naver.com/designpress2016',
#   'postdate': '20220304'},
#  {'title': '여자 수제화 브랜드 루시크루 포인트 토 펌프스 <b>봄</b> 코디',
#   'link': 'https://blog.naver.com/mhsi0501?Redirect=Log&logNo=222670411241',
#   'description': '드디어 제가 기다리고 기다린 <b>봄</b>이 왔습니다. 그럼에도 불구하고 찬 바람이 계속 불어와서 슬펐지만 며칠 전부터는 완연한 <b>봄</b> 날씨가 느껴졌어요. 이제는 제가 좋아하는 트위드, 트렌치, 레더 자켓을 마음껏... ',
#   'bloggername': '조아하늬 뷰티 in 패션',
#   'bloggerlink': 'https://blog.naver.com/mhsi0501',
#   'postdate': '20220312'},
#  {'title': '2022년 <b>봄</b>, 청산도  여행정보',
#   'link': 'https://blog.naver.com/md1020?Redirect=Log&logNo=222667831789',
#   'description': '대표적인 <b>봄</b> 풍경이 들어있다 하니 더욱 기대를 하며 여행을 위한 자료를 수집하였다 2. 최적 방문시기 - 3월말부터 5월초가 적합한 <b>봄</b>꽃 방문시기 -4월중순에 유채꽃 만개하여 이때가 최적의... ',
#   'bloggername': '은빛물결',
#   'bloggerlink': 'https://blog.naver.com/md1020',
#   'postdate': '20220309'},
#  {'title': '<b>봄</b>원단 질러보시지요~~ (모달, 스판 원단공구)',
#   'link': 'https://blog.naver.com/jinhi721?Redirect=Log&logNo=222662465551',
#   'description': '안녕하세요~ 슬슬 <b>봄</b>이 오는것 같습니다. 원단이라도 질러보자구요. 100%에코모달 40수 선염스트라이프... 이건 한정수량이니, 있을 때 쟁여두는게 좋을것 같아요~ 다음은 무난한 칼라의 <b>봄</b> 스판원단입니다.... ',
#   'bloggername': '코코지니의 재봉틀 놀이',
#   'bloggerlink': 'https://blog.naver.com/jinhi721',
#   'postdate': '20220303'},
#  {'title': '[전라도] 전라도의 <b>봄</b>은 홍매화로부터 시작된다, 전라도... ',
#   'link': 'https://blog.naver.com/twinkia?Redirect=Log&logNo=222666934598',
#   'description': '전라도의 <b>봄</b>은 홍매화로부터 시작된다 전라도 홍매화 추천 여행지 Best7 전국적으로 홍매화가 꽃망울을... 01_ 전주 경기전 전주한옥마을 경기전 내 홍매화는 전주에서 가장 이른 <b>봄</b>소식을 전해준다. 매년 이맘때... ',
#   'bloggername': '행복을 디자인하는 집',
#   'bloggerlink': 'https://blog.naver.com/twinkia',
#   'postdate': '20220308'},
#  {'title': '블랙야크 키즈, 초등학생 옷 신학기 코디 찰떡 <b>봄</b>자켓 추천',
#   'link': 'https://blog.naver.com/kkalgid1?Redirect=Log&logNo=222671699275',
#   'description': '어쩜 날씨도 이렇게 딱 맞춰서 따뜻해진건지~^^ 두꺼운 겨울옷들은 정리하고 초등학생 옷 <b>봄</b>자켓을 준비해줬습니다. 확실히 <b>봄</b>! 인 만큼 색도 밝아지고 얇아진 옷을 보니 기분도 산뜻해지네요 :) 이런... ',
#   'bloggername': '에이치라떼의 데일리로그 : D',
#   'bloggerlink': 'https://blog.naver.com/kkalgid1',
#   'postdate': '20220313'},
#  {'title': '[EVENT] 다가오는 <b>봄</b>, 백년동안 흑초로 나의 몸을 깨워보세요',
#   'link': 'https://blog.naver.com/sempiostory?Redirect=Log&logNo=222663966097',
#   'description': '<b>봄</b>이 깨어나는 경칩인 오늘! 건강한 백 년을 위한 한 잔 #흑초 로 나의 몸도 깨워보면 어떨까요?  건강 성분이 많고 다양해 식초의 왕으로 불리는 흑초와 함께 더 가볍고 건강하게 <b>봄</b>을 시작해보세요- 나의... ',
#   'bloggername': '샘표의 즐거운 요리혁명',
#   'bloggerlink': 'https://blog.naver.com/sempiostory',
#   'postdate': '20220305'},
# ...
#   'bloggername': '슬기로운 차박생활',
#   'bloggerlink': 'https://blog.naver.com/rianse',
#   'postdate': '20220309'},
#  {'title': '<b>봄</b> 다이어트 시작! 그리밀 단백질쉐이크 로~',
#   'link': 'https://blog.naver.com/pparksomin?Redirect=Log&logNo=222665002659',
#   'description': '뷰티유튜버, 블로거 썸블리 입니다 요즈음 날씨가 따뜻해지다 보니 <b>봄</b>옷을 정말 두둑히 구매했는데요.... 바틀도 작기 때문에 가방에 쏘옥- 들어가는데 점점 예쁜 <b>봄</b>옷은 많아지고 뱃살 때문에 옷 핏이 예쁘지... ',
#   'bloggername': '썸블리 뷰티시크릿',
#   'bloggerlink': 'https://blog.naver.com/pparksomin',
#   'postdate': '20220306'},
#  {'title': '<b>봄</b>이 오는 길목에서.',
#   'link': 'https://blog.naver.com/duckwoory?Redirect=Log&logNo=222670894254',
#   'description': '<b>봄</b>이 오는 길목에서. <b>봄</b>이 오는 길목에서. _ 詩. 이해인 _ 하얀 눈 밑에서도 푸른 보리가 자라듯 삶의 온갖 아픔 속에서도 내 마음엔 조금씩 푸른 보리가 자라고 있었구나 꽃을 피우고 싶어 온몸이 가려운 매화... ',
#   'bloggername': '사랑방길손',
#   'bloggerlink': 'https://blog.naver.com/duckwoory',
#   'postdate': '20220312'},
#  {'title': '{ <b>봄</b>이 오면 } 집에서 즐기는 도다리 쑥국과 쭈꾸미 샤부샤부',
#   'link': 'https://blog.naver.com/artofgolf?Redirect=Log&logNo=222668536074',
#   'description': '<b>봄</b>이 되면 #도다리쑥국 #쭈꾸미샤부샤부 정도는 꼭 먹어줘야 합니다. 나가서 사먹으면 좋지만 워낙... 정말 <b>봄</b>의 별미가 맞습니다. 도다리쑥국 도다리쑥국도 먹고나면 푹 끓인 쭈꾸미 머리도 건져 먹습니다. 아직... ',
#   'bloggername': '아마추어 골퍼의 변명',
#   'bloggerlink': 'https://blog.naver.com/artofgolf',
#   'postdate': '20220310'},
#  {'title': '전시리뷰 &lt;어느 <b>봄</b> 날, 테레사 프레이타스 사진전... ',
#   'link': 'https://blog.naver.com/aspirenova?Redirect=Log&logNo=222663549689',
#   'description': '어느 <b>봄</b>날, 테레사 프레이타스 사진전 Teresa Freitas, Spring TIme Delight 2022.01.29 ~ 2022.04.24... 분홍빛의 알렌테주 II, 2018 샬럿의 피크닉, 2020 바이올렛, 파란 옷의 마르타 로스코의 <b>봄</b>... ',
#   'bloggername': '예술감옥 : 전시 위주의 리뷰',
#   'bloggerlink': 'https://blog.naver.com/aspirenova',
#   'postdate': '20220308'},
#  {'title': '제주 아르떼뮤지엄 할인 맛집까지, 감성 <b>봄</b>여행지로 제격!',
#   'link': 'https://blog.naver.com/dlswlkr?Redirect=Log&logNo=222669114373',
#   'description': '이미 아시는 분들이 많아졌겠지만, <b>봄</b>이 되어 제주도 가시는 분들이 여럿 계셔서 올려보아요. 입장권 및 주차 제주 아르떼뮤지엄 할인 팁이 있어요. 성인 기준 17,000원의 전시티켓이지만, 미리... ',
#   'bloggername': '타샤의 트래블로그',
#   'bloggerlink': 'https://blog.naver.com/dlswlkr',
#   'postdate': '20220310'},
#  {'title': '[공유]1.<b>봄</b>꽃도안 놀이활동 <b>봄</b>놀이활동 놀이미술 방법과... ',
#   'link': 'https://blog.naver.com/kobabo2?Redirect=Log&logNo=222671522479',
#   'description': '<b>봄</b>꽃도안으로 놀이활동하기 <b>봄</b>놀이활동 놀이미술 활동으로 즐거운 <b>봄</b> 즐기기 1. <b>봄</b>동산 꾸미기-영아반 쉬운 활동이면서도 영아반의 처음하는 체험활동으로 무난한 활동입니다. 특별한 아이디어는 없지만... ',
#   'bloggername': 'E_nee Story',
#   'bloggerlink': 'https://blog.naver.com/kobabo2',
#   'postdate': '20220313'},
#  {'title': '<b>봄</b>과 관련된 영어표현 모음, 3월,4월,5월과 관련된 <b>봄</b>관련 필수... ',
#   'link': 'https://blog.naver.com/pp5452?Redirect=Log&logNo=222668547298',
#   'description': '3월달과 관련된 유용한 영어표현 3월,4월,5월과 관련된 <b>봄</b>관련 필수 영어표현! 3월달과... 3월,4월,5월과 관련된 <b>봄</b>관련 필수 영어표현 - 자세한 한글설명 및 영문설명 포함 1 Spring is in the... ',
#   'bloggername': 'Nari의 잉글리쉬 안내서',
#   'bloggerlink': 'https://blog.naver.com/pp5452',
#   'postdate': '20220310'},
#  {'title': '[환경구성/모빌] 어린이집 꽃모빌 만들기 - 펠트꽃모빌 / <b>봄</b>모빌',
#   'link': 'https://blog.naver.com/kjy2052?Redirect=Log&logNo=222654930908',
#   'description': '안녕하세요 바다양이예요 어린이집환경구성 중 모빌 시리즈를 열심히 올리고 있는데 그 중 두번째인 <b>봄</b>  느낌 물씬 풍기는 펠트 꽃 모빌 입니다 <b>봄</b> 느낌 물씬 풍기는 펠트 꽃모빌 한쪽 벽면이에요~ 원래는 저... ',
#   'bloggername': '"바다양"의 작은 방',
#   'bloggerlink': 'https://blog.naver.com/kjy2052',
#   'postdate': '20220222'},
#  {'title': '스타벅스신메뉴 핑크 매그놀리아 레몬에이드 먹어<b>봄</b>!',
#   'link': 'https://blog.naver.com/hyperealism?Redirect=Log&logNo=222661069815',
#   'description': '스타벅스 신메뉴 핑크매 그놀리아 레몬에이드 먹어<b>봄</b>! STARBUCKS 안녕하세요 ! 스타벅스 신메뉴를 매번... 스타벅스 <b>봄</b> 신메뉴 3종 음료 종류는? starbucks.co.kr 이번 <b>봄</b> 출시된 스타벅스 신메뉴는 총 세 가지인데요... ',
#   'bloggername': 'ᴱᵛᴵᴴᶜᴿᴬ',
#   'bloggerlink': 'https://blog.naver.com/hyperealism',
#   'postdate': '20220302'},
#  {'title': '레더 라이더자켓  <b>봄</b> 데일리룩에 딱 예쁜 여성가죽자켓❤︎',
#   'link': 'https://blog.naver.com/oldpopsong?Redirect=Log&logNo=222667895656',
#   'description': '셀럽플래닛 이탈리아브랜드 비콜로 VICOLO 비건 레더 라이더자켓 <b>봄</b> 데일리룩에 딱 예쁜 여성가죽자켓... 이탈리아브랜드 특유의 좋은 퀄리티로 소장가치 높은 비콜로 비건레더 라이더자켓으로 여자 <b>봄</b>코디... ',
#   'bloggername': 'D!BS magazine / 딥스매거진 / 패션,뷰티 블로그',
#   'bloggerlink': 'https://blog.naver.com/oldpopsong',
#   'postdate': '20220309'},
#  {'title': '<b>봄</b>나들이 가볼 만한 곳, <b>봄</b>꽃 축제 추천 :: 이월드 별빛벚꽃축제... ',
#   'link': 'https://blog.naver.com/korea_diary?Redirect=Log&logNo=222662624028',
#   'description': '사진제공 다님5기 이철현 이런 분들에게 추천해 드립니다  축제를 즐기고 싶은 분  꽃과 인생샷을 남기고 싶으신 분  <b>봄</b> 나들이 장소 찾으시는 분 요 며칠 부쩍 <b>봄</b>바람이 불었죠, 그래서인지 훈훈한... ',
#   'bloggername': '[한국관광공사] 국내여행 블로그',
#   'bloggerlink': 'https://blog.naver.com/korea_diary',
#   'postdate': '20220303'},
#  {'title': 'Special) <b>봄</b> 셔츠 롱원피스, 랩원피스 2가지 진행합니다.... ',
#   'link': 'https://blog.naver.com/wrusu?Redirect=Log&logNo=222671598915',
#   'description': ':) <b>봄</b>이 다가오니 이제 <b>봄</b>원피스를 찾으시는 언니들이 많으신거 같아요. 오늘은 셔츠원피스 2가지 마켓 진행해요. 1가지는 벨티드 형태의 디자인으로 랩원피스이구요. 또 다른 한가지는 제클 베스트상품!... ',
#   'bloggername': 'J-Classy',
#   'bloggerlink': 'https://blog.naver.com/wrusu',
#   'postdate': '20220313'},
#  {'title': '부산여행:) 부산은 벌써 <b>봄</b>! 매화 여행지 수영사적공원 등 3곳',
#   'link': 'https://blog.naver.com/korail77?Redirect=Log&logNo=222662482301',
#   'description': '올해 처음으로 소개드릴 곳은 매화향기 가득한 부산의 <b>봄</b>여행지입니다. 아직은 찬바람이 쌩쌩 부는 겨울이건만 계절은 이미 <b>봄</b>을 향해 달려가고 있습니다. 부산 곳곳에 매화가 활짝 피어 달콤한 <b>봄</b>향기를... ',
#   'bloggername': '행복한 해변무드역',
#   'bloggerlink': 'https://blog.naver.com/korail77',
#   'postdate': '20220303'},
#  {'title': '경기도 벚꽃드라이브 명소, 가평 북한강 <b>봄</b>나들이 드라이브코스',
#   'link': 'https://blog.naver.com/ecopiagp?Redirect=Log&logNo=222663726028',
#   'description': '이름만 들어도 설렘을 자극하는 <b>봄</b>을 기다리며 준비한 가평관내 벚꽃종합안내 시리즈, 지금 바로... 벚꽃보다 진한 분홍빛의 도화부터 연둣빛으로 물드는 버드나무까지, <b>봄</b>의 빛깔이 최고조에 달하는 이 시기에... ',
#   'bloggername': '가평군 공식블로그',
#   'bloggerlink': 'https://blog.naver.com/ecopiagp',
#   'postdate': '20220306'},
#  {'title': '[허니와 여행] 제주도 3월날씨, 제주여행 <b>봄</b>옷코디, 섭지코지... ',
#   'link': 'https://blog.naver.com/tlsqlalsdn?Redirect=Log&logNo=222664992545',
#   'description': '그러나 유채꽃이 만발하므로 안에는 <b>봄</b>옷을 장착할 것  패딩모자 찍찍이가 강제로 뜯길 정도의 강력한 바람이다 유채꽃 때문에 <b>봄</b>옷도 입었지만 패딩을 벗을 용기는 없었다 ^^ 3월 섭지코지는 관광객이... ',
#   'bloggername': '이미지|브랜딩|퍼스널컬러 허니의 블로그입니다',
#   'bloggerlink': 'https://blog.naver.com/tlsqlalsdn',
#   'postdate': '20220306'},
#  {'title': '생로랑 가방부터 막스마라 마담 <b>봄</b>신상 190만 이득... ',
#   'link': 'https://blog.naver.com/tatu_yulia?Redirect=Log&logNo=222670183507',
#   'description': '코트 (<b>봄</b> 버전/라이트 블루) 쇼핑하기 전 세계 유명한 여성들, 저명 인사들이 사랑하는 Max Mara의... 겨울부터 쭉 계속되는 럭셔리, 데님 컬러로 산뜻하고 영한 무드를 더해 고급스러운 마담 코트를 <b>봄</b>의... ',
#   'bloggername': '밍기뉴의 해외직구 블로그',
#   'bloggerlink': 'https://blog.naver.com/tatu_yulia',
#   'postdate': '20220311'},
#  {'title': '론트 블레이져 군더더기 없는 <b>봄</b> 자켓 아우터로 활용 중',
#   'link': 'https://blog.naver.com/gurrl15199?Redirect=Log&logNo=222661369364',
#   'description': '아무래도 3월이기 때문에 부산 같은 경우 <b>봄</b> 자켓과 같은 산뜻한 아우터를 착용하기 좋은 시기인데요.... 새로운 계절인 <b>봄</b>에 맞게 착용을 해본 이번 블레이져 같은 경우 남자 <b>봄</b> 코디로 활용하기 좋게... ',
#   'bloggername': 'Day Off',
#   'bloggerlink': 'https://blog.naver.com/gurrl15199',
#   'postdate': '20220302'},
#  {'title': '덕수궁/박수근/<b>봄</b>을 기다리는 나목 전시회',
#   'link': 'https://blog.naver.com/minghae00?Redirect=Log&logNo=222665252639',
#   'description': '제목은 박수근 <b>봄</b>을 기다리는 나목 박수근은 1914~1965년 양구 태생이다. 아래 글을 보면 박수근의 생애와 그림에 대해 알 수 있다. 1933년 철쭉. 1934년 겨울 풍경 수채화 밀레를 사랑한 소년 12세 때 밀레의 만종... ',
#   'bloggername': '하느리의 여행이야기',
#   'bloggerlink': 'https://blog.naver.com/minghae00',
#   'postdate': '20220306'},
#  {'title': '장철한 <b>봄</b>은 고양이로다',
#   'link': 'https://blog.naver.com/emotion0822?Redirect=Log&logNo=222670661054',
#   'description': '꽃가루와 같이 부드러운 고양이의 털에 고운 <b>봄</b>의 향기가 어리우도다 금방울과 같이 호동그란 고양이의 눈에 미친 <b>봄</b>의 불길이 흐르도다 고요히 다물은 고양이의 입술에 포근한 <b>봄</b> 졸음이 떠돌아라 날카롭게 쭉... ',
#   'bloggername': 'Sparkling Spirit',
#   'bloggerlink': 'https://blog.naver.com/emotion0822',
#   'postdate': '20220312'},
#  {'title': '<b>봄</b>을 맞이하기 위해-빅이슈 269호',
#   'link': 'https://blog.aladin.co.kr/774420113/13384398',
#   'description': '입춘이 지나고, 우수도 지나고, 이제는 <b>봄</b>이 다가와야 하건만, 계절은 어김없이 <b>봄</b>을 향해 가고 있단 믿음이 있는데, 그럼에도 순간 순간 닥쳐오는 추위에는 어쩔 수가 없다. 아직 완연한 <b>봄</b>은 아니구나. <b>봄</b>이... ',
#   'bloggername': '도담서림(道談書林) (kinye91 서재)',
#   'bloggerlink': 'https://blog.aladin.co.kr/774420113',
#   'postdate': '20220301'},
#  {'title': '경주서라벌cc 겨울과 <b>봄</b> 사이 라운드',
#   'link': 'https://blog.naver.com/napalclinic?Redirect=Log&logNo=222664188627',
#   'description': '마음은 <b>봄</b>이지만 밖에서 운동할 때면 추위를 못 견딜 때도 종종 있는 요즘입니다. 얼마 전 경주서라벌cc로 라운드를 다녀왔습니다. 맨날 새벽골프만 치다가 낮에 라운드하니 ㅎㅎ 따뜻하니 좋더만요. 2부... ',
#   'bloggername': '나팔꽃한의원',
#   'bloggerlink': 'https://blog.naver.com/napalclinic',
#   'postdate': '20220305'},
#  {'title': '유채 바람 / 랜선 음악회 / 신상 동요 / <b>봄</b> 노래 / 포근한 노래',
#   'link': 'https://blog.naver.com/shimji202?Redirect=Log&logNo=222663948959',
#   'description': '라니멜레의 랜선 음악회에 오신 것을 환영합니다 저는 아조이별입니다 <b>봄</b>의 노래 &lt;유채 바람... 평화로운 <b>봄</b> 맞이하세요 마할로!  #감사합니다 #랜선음악회 #<b>봄</b>음악회 #아조이별동요 #<b>봄</b>동요 #<b>봄</b>노래... ',
#   'bloggername': '아조이별★ 지구에 살다',
#   'bloggerlink': 'https://blog.naver.com/shimji202',
#   'postdate': '20220305'},
#  {'title': '2022년 <b>봄</b>꽃 개화시기! 벚꽃, 개나리, 진달래',
#   'link': 'https://blog.naver.com/dalseonggun?Redirect=Log&logNo=222657681884',
#   'description': '<b>봄</b>이 오고 있구나 하는 생각이 절로 드는데요~ <b>봄</b>하면 빼놓을 수 없는 것이 바로 다양한 <b>봄</b>꽃들!! 올해 벚꽃, 개나리, 진달래는 언제쯤 피어날지 달성군의 작년 <b>봄</b>꽃 명소들은 어떤 모습이었는지 지금... ',
#   'bloggername': '달성 꽃 피다',
#   'bloggerlink': 'https://blog.naver.com/dalseonggun',
#   'postdate': '20220228'},
#  {'title': '<b>봄</b>은 왔는데 세상은 너무나 어수선해',
#   'link': 'https://blog.naver.com/dkfnal2232?Redirect=Log&logNo=222661388166',
#   'description': '그사람입니다 모처럼 <b>봄</b>기운을 느껴보려고 집 앞 한강으로 나가봤습니다 지난 2월도 정신없이... 그래서 <b>봄</b> 분위기보다는 뭔가 많이 어수선한 거 같고요 그럼에도 불구하고 어쩌면 새로운 세상이 다가올 거라는... ',
#   'bloggername': '그사람의 운동을 좋아하는 블로그',
#   'bloggerlink': 'https://blog.naver.com/dkfnal2232',
#   'postdate': '20220302'},
#  {'title': '커플 바람막이 남자 <b>봄</b> 코디 빅로고 트랙자켓 추천',
#   'link': 'https://blog.naver.com/yszin?Redirect=Log&logNo=222647709214',
#   'description': '커버낫 커플 바람막이 추천 남자 <b>봄</b> 코디 위한 아이템 리뷰. 겨울의 마지막 추위가 지나가고 영상으로 오르는 기온이 온 만큼 얼른 <b>봄</b> 준비를 해보면 좋을 것 같습니다. 반가워요. 9년차 패션 리뷰어... ',
#   'bloggername': '윤힐링 패션뷰티 블로그',
#   'bloggerlink': 'https://blog.naver.com/yszin',
#   'postdate': '20220215'},
#  {'title': '<b>봄</b> 방학, 월평도서관에서 다양한 책들을 만나보아요!',
#   'link': 'https://blog.naver.com/first_seogu?Redirect=Log&logNo=222646830953',
#   'description': '<b>봄</b> 방학, 월평도서관에서 보내는 슬기로운 방학생활 안녕하세요 서구 기자단입니다. 추웠던 겨울이 지나가고, 낮 기온은 점점 따스한 <b>봄</b>날이 찾아오는 요즘입니다. 2월 초부터 3월 초까지는 #<b>봄</b>방학 기간이다... ',
#   'bloggername': '대전광역시 서구청 블로그입니다.',
#   'bloggerlink': 'https://blog.naver.com/first_seogu',
#   'postdate': '20220216'},
#  {'title': '나만,<b>봄</b> 블랭킷',
#   'link': 'https://blog.naver.com/bull67?Redirect=Log&logNo=222657368722',
#   'description': '<b>봄</b>이 지척에 와 있으니... 이미 갯수를 맞춰 색색이 떠 놓았던 모티브를 흰색으로 둘러 가며 연결했다.... 스팀을 쐬어가며 반듯하게 정리하니 와! <b>봄</b>이 온 듯 화사하구나~ 그래서 이 블랭킷 이름은 나만, <b>봄</b>',
#   'bloggername': '동갑내기 시골살이',
#   'bloggerlink': 'https://blog.naver.com/bull67',
#   'postdate': '20220225'},
#  {'title': '[날씨] 당분간 포근한 <b>봄</b>날씨..휴일 전국 곳곳 비',
#   'link': 'https://blog.naver.com/c1c1b1b1?Redirect=Log&logNo=222669814319',
#   'description': 'https://youtu.be/jkUTpfK-jWc 날이 갈수록 <b>봄</b>기운이 짙어지고 있습니다. 오늘은 아침에도 공기가 꽤나... 일교차 큰 <b>봄</b> 날씨가 이어지는 가운데, 미세먼지도 말썽이고 있습니다. 현재 중서부지역을 중심으로... ',
#   'bloggername': '천연피부약.눈물.식물성소금',
#   'bloggerlink': 'https://blog.naver.com/c1c1b1b1',
#   'postdate': '20220311'},
#  {'title': '거제<b>봄</b>꽃축제 난 선인의고장 거제, 제30회 거제난대전 성료... ',
#   'link': 'https://blog.naver.com/geojecity?Redirect=Log&logNo=222665865116',
#   'description': '난초를 사랑하시는 삼성난우회원님 완연한 <b>봄</b>날인것 같습니다. 이번 거제난대전에 총 40화분을... 춘란을 사랑하시는 애란인이시라면 꼭 한번 한국난대전 에서 <b>봄</b>의전령사 춘란들을 만나보시기 바라며... ',
#   'bloggername': '거제시 공식 블로그',
#   'bloggerlink': 'https://blog.naver.com/geojecity',
#   'postdate': '20220307'},
#  {'title': '<b>봄</b> 아우터 스타일링 with 커버낫 @MY CITY DIARY',
#   'link': 'https://blog.naver.com/atcovernat?Redirect=Log&logNo=222662982914',
#   'description': '햇살을 머금은 <b>봄</b>날, 모두 행복한 하루 보내고 계신가요? 오늘은 요즘같은 날씨에 함께하기 좋은 커버낫과 <b>봄</b> 아우터 스타일링을 소개해드리고자 합니다. 다 같이 한번 살펴보아요! 1. 리버시블 라이트 다운... ',
#   'bloggername': '커버낫',
#   'bloggerlink': 'https://blog.naver.com/atcovernat',
#   'postdate': '20220303'},
#  {'title': '상동호수공원<b>봄</b>건기!  22. 03.11.',
#   'link': 'https://blog.naver.com/choins47?Redirect=Log&logNo=222669974456',
#   'description': '3월도 중순으로 이젠 완연한 <b>봄</b>날씨로다! 관목류등 화목과 <b>봄</b>철나뭇잎 - 가지에 꽃봉우리가 맺어서요! 먼저 산수유다! 1주내외 꽃망울이 터질것 같군요! 따스한 <b>봄</b>햇살을 맞으며 피어날 <b>봄</b>꽃들 기대합니다.... ',
#   'bloggername': '자전거는내친구요..!',
#   'bloggerlink': 'https://blog.naver.com/choins47',
#   'postdate': '20220311'},
#  {'title': '트립닷컴 3월 할인코드 <b>봄</b>꽃여행 가실 때 사용하세요',
#   'link': 'https://blog.naver.com/mina860527?Redirect=Log&logNo=222663827607',
#   'description': '따뜻한 <b>봄</b>날 되시길 바랍니다 :-) 여행 준비의 시작은 숙소 예약이죠. 트립닷컴 3월 할인코드 정보 공유하오니 <b>봄</b>꽃여행 가실 때 사용하세요. 일단 트립닷컴은 쿠폰코드 입력 필요 없이 전용페이지 접속만으로... ',
#   'bloggername': '메밀꽃부부의 세계일주프로젝트',
#   'bloggerlink': 'https://blog.naver.com/mina860527',
#   'postdate': '20220307'},
#  {'title': '마른 풀잎 밑둥에서 <b>봄</b>이 올라오고 있다. 2022년 3월11일',
#   'link': 'https://blog.naver.com/hwanokim?Redirect=Log&logNo=222670153065',
#   'description': '양지바른 곳 ,마른 풀들 밑둥에서 <b>봄</b>이 올라오고 있는 것을 발견했다. 얼룩 나비 한 마리도 보았다.... 생각되었는데 오늘 답을 찾은 것 같다.’식물 스케치’ #그림일기 #드로잉 #김숙경 #한국화가#식물스케치#<b>봄</b>이옴',
#   'bloggername': '한국화가 김숙경 Oriental painting & drawing',
#   'bloggerlink': 'https://blog.naver.com/hwanokim',
#   'postdate': '20220311'},
#  {'title': '(<b>봄</b>반찬)달래더덕생채로 <b>봄</b>마중 미리 해봐요^^',
#   'link': 'https://blog.naver.com/007crr?Redirect=Log&logNo=222643900200',
#   'description': '불어오는 바람 속에 <b>봄</b>기운이 살포시 숨어 있음을 느낀다. 움~~~화`~~푸우~~ 크게 호흡을 해본다. 갑자기 애기시과나무 위로 박새 한 마리가 쪼르르 날아와 앉는다. 안녕 박새야`~ 너도 느끼지? <b>봄</b> 말이야~~ <b>봄</b>... ',
#   'bloggername': '비바리의 숨비소리(친환경밥상)',
#   'bloggerlink': 'https://blog.naver.com/007crr',
#   'postdate': '20220210'},
#  {'title': '<b>봄</b>의 전령사 정원의 복수초(福壽草)꽃이 몽실몽실 피었어요',
#   'link': 'https://blog.naver.com/besoban?Redirect=Log&logNo=222662502712',
#   'description': '<b>봄</b>의 전령사 정원의 복수초(福壽草)꽃이 몽실몽실 피었어요 정원 구석진 곳에서 관리도 받지 못한 상태에서 매년 <b>봄</b>을 알리기 위해 금년에도 예쁜 꽃을 피워주는 복수초 참 기특하기만 합니다 복수초는 가장... ',
#   'bloggername': '소나무맘은 소나무 수형 만드는 중',
#   'bloggerlink': 'https://blog.naver.com/besoban',
#   'postdate': '20220303'},
#  {'title': '<b>봄</b>은 또 오고야 맙니다',
#   'link': 'https://blog.daum.net/knpil/7278667',
#   'description': '<b>봄</b>은 또 오고야 맙니다 스물다섯, 스물 하나의 풋풋한 사랑처럼 <b>봄</b>이 또 오네요 저 먼 섬 낭도에는 흑매 청매 홍매가 피었다는 전갈입니다 제비꽃이 피구요 히야신스 꽃대도 올라온 답니다 <b>봄</b>소식이 바람 타고... ',
#   'bloggername': '마법에 걸린 오후 / 나의 감옥',
#   'bloggerlink': 'https://blog.daum.net/knpil',
#   'postdate': '20220227'},
#  {'title': '<b>봄</b>마중식탁 생콩가루냉이전과 삼채등갈비찜',
#   'link': 'https://blog.naver.com/hadbyh?Redirect=Log&logNo=222661216140',
#   'description': '시골살이의 가을은 도시보다 한뼘정도 더디 오고요 시갈살이의 <b>봄</b>은 도시보다 한뼘정도 더 빠르게 온답니다 그에 더불에 아직은 겨울이라고 하기도 <b>봄</b>이라고 하기도 참 어정쩡한 3월의 첫날 3/1절이라고 하죠... ',
#   'bloggername': 'The 숲 Design //지리산약초 지리산에숲',
#   'bloggerlink': 'https://blog.naver.com/hadbyh',
#   'postdate': '20220301'},
#  {'title': '사피아노 플랩체인백 누드컬러 세상 여성스러운 <b>봄</b>가방으로 딱',
#   'link': 'https://blog.naver.com/go2kangsik?Redirect=Log&logNo=222668212861',
#   'description': '요 백은 사피아노 재질의 튼튼한 가죽과 오알비 로고의 실버가 돋보이는 아이템인데요 누드 컬러로 우리들의 <b>봄</b>가방으로 딱 아니겟어요! 게다가 쉐입도너무 ㅇ|ㅖ|뻐서 일반 비비안... ',
#   'bloggername': '영국삼촌의 영국이야기',
#   'bloggerlink': 'https://blog.naver.com/go2kangsik',
#   'postdate': '20220309'},
#  {'title': '<b>봄</b>이 오는 길목에서 이해인 시인',
#   'link': 'https://blog.naver.com/bellina55?Redirect=Log&logNo=222659929416',
#   'description': '<b>봄</b>이 오는 길목에서 하얀 눈 밑에서도 푸른 보리가 자라듯 삶의 온갖 아픔 속에서도 내 마음엔 조금씩... 꼬리에도 <b>봄</b>이 움직이고 있구나 아직 잔설이 녹지 않은 내 마음의 바위 틈에 흐르는 물소리를 들으며... ',
#   'bloggername': '토마토별',
#   'bloggerlink': 'https://blog.naver.com/bellina55',
#   'postdate': '20220228'},
#  {'title': '#여행359] 김해가볼만한곳_<b>봄</b>꽃나들이_봉황대공원... ',
#   'link': 'https://blog.naver.com/pqdbwls?Redirect=Log&logNo=222665341182',
#   'description': '2022.03.06 김해 매화 개화 상황 <b>봄</b>꽃나들이하기 좋은 곳, 봉황대공원 지난 주 관동공원에 잠시 스치듯... <b>봄</b> 기운이 슬슬 스며드는 것 치곤 조금 추운 날씨였는데 그래서인지 미세먼지는 없고 쾌청했다. 몇바퀴... ',
#   'bloggername': '야호!',
#   'bloggerlink': 'https://blog.naver.com/pqdbwls',
#   'postdate': '20220306'}]

# %%
#뉴스호출

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 뉴스 검색
import urllib.request
import json

client_id = id
client_secret = key
keyword=input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data=[]
for i in range(1,1001,100):
    url = f"https://openapi.naver.com/v1/search/news?display=100&start={i}&query=" + encText # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        #print(response_body.decode('utf-8')) 
        d=json.loads(response_body)
        d['items']
        data.extend(d['items'])
    else:
        print("Error Code:" + rescode)
# Out:
# 검색할 단어>>>코로나

# %%
data
# Out:
# [{'title': '두 줄로 길게',
#   'originallink': 'http://yna.kr/PYH20220314045900013?did=1196m',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=001&aid=0013049036',
#   'description': '14일 서울역 광장에 마련된 <b>코로나</b>19 임시 선별검사소에 시민들이 PCR(왼쪽) 혹은 신속항원검사(오른쪽)를 받기 위해 줄을 서서 기다리고 있다. 2022.3.14',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '방탄소년단, 서울 콘서트 전 세계 246만 5천명 관람',
#   'originallink': 'http://news.heraldcorp.com/view.php?ud=20220314000247',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=016&aid=0001963273',
#   'description': "<b>코로나</b>19 팬데믹 상황 탓에 공연장 내 수용인원 제한이 불가피함에 따른 팬들의 아쉬움은 다양한... 'BTS PERMISSION TO DANCE ON STAGE - SEOUL'에서는 <b>코로나</b>19 확산 방지를 위해 함성 대신 클래퍼(응원용 소도구)와... ",
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '아산시, <b>코로나</b>19 소아특화 거점전담병원 2곳 확보',
#   'originallink': 'http://www.sisanews24.co.kr/7622',
#   'link': 'http://www.sisanews24.co.kr/7622',
#   'description': '© 시사뉴스24 충남 아산시(시장 오세현)가 <b>코로나</b>19 소아 확진자의 신속한 치료를 위해 소아특화... 건강보험심사평가원 누리집에서 확인할 수 있다. 한편, 14일 0시기준 아산시 <b>코로나</b>19 확진자는 40,759명이다. 시사뉴스24',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '두 줄로 길게',
#   'originallink': 'http://yna.kr/PYH20220314046100013?did=1196m',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=001&aid=0013049038',
#   'description': '14일 서울역 광장에 마련된 <b>코로나</b>19 임시 선별검사소에 시민들이 PCR(왼쪽) 혹은 신속항원검사(오른쪽)를 받기 위해 줄을 서서 기다리고 있다. 2022.3.14',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '5~11세 소아도 백신접종…신속검사 양성도 확진',
#   'originallink': 'http://www.smedaily.co.kr/news/articleView.html?idxno=226213',
#   'link': 'http://www.smedaily.co.kr/news/articleView.html?idxno=226213',
#   'description': "또한 동네병원이나 의원 등에서 신속항원검사 양성 판정 시 <b>코로나</b>19 확진자로 인정키로 했다. 14일\xa0전해철... 또 &quot;최근 <b>코로나</b>19 백신 안전성위원회는 엠-알엔에이(mRNA) 백신 접종과 '심근염' 발생 간 인과성을 인정하는... ",
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': "제주항공, 지상에서 맛보는 기내식 카페 '여행맛' 운영 종료",
#   'originallink': 'http://yna.kr/AKR20220314054100003?did=1195m',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=001&aid=0013049037',
#   'description': '하지만 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 사태로 비행기를 타고 여행을 가기 힘든 상황이 지속되면서 인기를 끌자 AK플라자 분당점과 롯데백화점 김포공항점에 2, 3호점을 연달아 오픈했다. 10개월간 이들 3개... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': "진매트릭스, <b>코로나</b>19 변이 바이러스에 범용적인 백신 후보물질 '특허 출원'",
#   'originallink': 'http://www.paxetv.com/news/articleView.html?idxno=139923',
#   'link': 'http://www.paxetv.com/news/articleView.html?idxno=139923',
#   'description': '진매트릭스(대표 김수옥)가 자체 개발한 백신 개발 원천플랫폼을 통해 <b>코로나</b>19 변이 바이러스에 범용적인 백신 후보물질을 개발하고 특허 출원을 완료했다고 14일 밝혔습니다. 해당 후보물질은 <b>코로나</b> 바이러스의... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '경남 총 확진자 60%가 보름만에 발생',
#   'originallink': 'http://www.newsfreezone.co.kr/news/articleView.html?idxno=367887',
#   'link': 'http://www.newsfreezone.co.kr/news/articleView.html?idxno=367887',
#   'description': '경남의 <b>코로나</b>19 누적 확진자가 14일 0시 기준으로 36만61명을 기록하면서 도민 10명당 1명 이상꼴로 <b>코로나</b> 확진자가 발생한 것으로 나타났다. 14일 0시 기준 경남의 신규 확진자는 2만6098명으로... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '오바마 전 美 대통령, <b>코로나</b>19 확진…&quot;증상은 경미&quot;',
#   'originallink': 'http://www.g-enews.com/ko-kr/news/article/news_all/202203141011408892658ae4d6a0_1/article.html',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202203141011408892658ae4d6a0_1/article.html',
#   'description': '버락 오바마 전 미국 대통령이 <b>코로나</b> 양성 판정을 받았다고 13일(현지 시간) 밝혔다. 오바마 전 대통령은 &quot;방금 <b>코로나</b> 양성 판정을 받았다. 며칠 동안 목이 따끔거렸지만 그 외에는 괜찮다. 미셸과 나는 백신과 추가 접종을... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '경남 2만3767명 확진·환자 20명 사망…나흘 연속 2만명대',
#   'originallink': 'http://yna.kr/AKR20220314051200052?did=1195m',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=001&aid=0013049040',
#   'description': '창원 8318명·김해 4189명…위중증 34명·재택치료 15만1003명 경남도는 13일 하루 도내에서 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19)에 2만3천767명이 확진됐다고 14일 밝혔다. 지난 10일부터 나흘 연속 2만명대... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '자동차세 할인받고 3월에 미리 납부하세요',
#   'originallink': 'http://www.headlinejeju.co.kr/news/articleView.html?idxno=478575',
#   'link': 'http://www.headlinejeju.co.kr/news/articleView.html?idxno=478575',
#   'description': '올해도 <b>코로나</b>19로 인하여 서민경제가 많이 위축되고 힘든상황 속이지만 조금 이나마 우리들에게 기쁨의 혜택을 주는 자동차세 연납신청이 있어 소개해 볼까 한다. 자동차세 연납신청이란 1년치의 자동차 세금을... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '방탄소년단, 3일간 4만 5,000명 아미 만났다…영화관 관람은 140만명',
#   'originallink': 'https://www.sedaily.com/NewsView/263EY1U7LI',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=011&aid=0004029141',
#   'description': '<b>코로나</b>19 확산 방지를 위해 함성 대신 클래퍼(응원용 소도구)와 응원봉(아미밤)만 허용됐다. 환호할 수 없는 콘서트가 방탄소년단은 물론 관객들에게도 낯설었지만, 공연장의 열기는 그 어느 때보다 뜨거웠다.... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '성남시 영세 음식점 주방 환경개선…최대 70만원 지원',
#   'originallink': 'http://www.bzeronews.com/news/articleView.html?idxno=508709',
#   'link': 'http://www.bzeronews.com/news/articleView.html?idxno=508709',
#   'description': '성남시 위생정책과 관계자는 &quot;노후한 주방 시설의 위생 수준을 높여 안전한 먹거리 제공 환경을 조성하고, <b>코로나</b>19 장기화로 침체한 지역경제를 활성화하려는 취지&quot;라고 말했다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '&quot;밥투정하던 아이도 한 그릇 뚝딱&quot;, 입학문의 줄잇는 학교',
#   'originallink': 'http://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0002817886&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=047&aid=0002345707',
#   'description': '<b>코로나</b>19가 기승을 부리는 과정에도 학생과 부모님들의 관심으로 성황리에 개학을 했다. ⓒ 아이-뷰 아이들이 학원이나 놀이동산이 아닌 자연에서, 들판에서 뛰고 땀 흘리면서 어린 시절을 보낼 수 있는 기회를 만들어주고... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': "전자랜드, 새 학기 IT가전 '태블릿 PC'.. 비중 증가 노트북 대용으로 사용",
#   'originallink': 'http://www.discoverynews.kr/news/articleView.html?idxno=758369',
#   'link': 'http://www.discoverynews.kr/news/articleView.html?idxno=758369',
#   'description': '먼저, 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19)의 발생 이후 재택근무나 비대면 수업을 하는 사람들이 늘어났고, 이에 따라 IT 가전제품의 전체적인 인기도 증가했었다. 이후 <b>코로나</b>19가 장기화되면서 대면 수업과... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '윤석열 당선인 경제 공약의 핵심 1)<b>코로나</b> 2)부동산 3)주식 가상자산...이상석...',
#   'originallink': 'https://news.bbsi.co.kr/news/articleView.html?idxno=3061830',
#   'link': 'https://news.bbsi.co.kr/news/articleView.html?idxno=3061830',
#   'description': '이상석 한양대 겸임교수 ■ 대담 : 이상석 한양대 경영대 겸임교수(경기도 경제과학진흥원 이사) ■ 방송 : BBS 라디오 &lt;박경수의 아침저널&gt; (07:20~09:00) ■ 진행 : BBS 보도국 박경수 앵커 아침저널',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '시화MTV 반달섬, 해양레저 메카 급부상',
#   'originallink': 'http://www.finomy.com/news/articleView.html?idxno=108216',
#   'link': 'http://www.finomy.com/news/articleView.html?idxno=108216',
#   'description': '반달섬에서 서쪽으로 5km거리인 같은 시화MTV 내 거북섬에는 지난해 길이 240m의 세계 최대 규모 인공 서핑장이 개장했으나 <b>코로나</b> 팬데믹 여파로 현재 휴장중이다. 시화호를 사이에 두고 반달섬 남쪽 건너편인... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '해외 갔던 국내기업 &quot;韓 오고 싶다&quot;…유턴 고려 2년 전보다 9배 이상 ↑',
#   'originallink': 'http://www.inews24.com/view/1459816',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000659122',
#   'description': '해외에 진출한 우리나라 기업 가운데 국내 유턴을 고려하는 기업이 <b>코로나</b>19 사태 이후 2년새 9배 이상... 전경련은 &quot;기업 10곳 중 6곳(57.0%)이 리쇼어링 추진이 가능하다는 의사를 보인 것&quot;이라라며 &quot;<b>코로나</b>19 기간... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '침례병원 공공병원화 시동 걸다&quot;목표는 보험자병원 설립&quot;',
#   'originallink': 'http://www.bzeronews.com/news/articleView.html?idxno=508706',
#   'link': 'http://www.bzeronews.com/news/articleView.html?idxno=508706',
#   'description': '침례병원 공공병원화는 동부산권의 의료서비스 제공은 물론, <b>코로나</b>19 등 신종감염병 대응을 위한 부산의 공공의료벨트 구축을 위한 핵심축의 하나이다. 부지 매매계약 체결로 공공병원화를 위한 기틀이 마련된 만큼... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '&quot;하고잡이 인재 뽑는다&quot;…CJ, 대규모 상반기 채용 시작',
#   'originallink': 'https://www.ceoscoredaily.com/page/view/2022031410095543484',
#   'link': 'https://www.ceoscoredaily.com/page/view/2022031410095543484',
#   'description': 'CJ그룹이 <b>코로나</b> 이후 최대 규모의 신입 사원 채용 절차에 돌입했다. CJ는 “14일부터 상반기 신입사원... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': "'북적북적' 1,200여 곳 참가한 KIMES 2022 성료\xa0",
#   'originallink': 'http://www.mkhealth.co.kr/news/articleView.html?idxno=56842',
#   'link': 'http://www.mkhealth.co.kr/news/articleView.html?idxno=56842',
#   'description': '특히 <b>코로나</b>19로 비대면 트렌드가 가속화되는 가운데 모바일과 키오스크를 통한 비대면 결제, 전화상담진료 체험 공간을 마련했다. KIMES에\xa0참가한 업체 관계자는\xa0&quot;서울에서 열린\xa0KIMES 참가는 이번이 처음인데, 확실히... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '<b>코로나</b>19 위중증 환자, 1158명 역대 최다…신규 확진 30만↑',
#   'originallink': 'http://www.slist.kr/news/articleView.html?idxno=338245',
#   'link': 'http://www.slist.kr/news/articleView.html?idxno=338245',
#   'description': '사진=연합뉴스 중앙방역대책본부에 따르면 14일 0시 기준 <b>코로나</b>19 위중증 환자 수는 1천158명으로 전날보다 84명 늘었다고 연합뉴스가 보도했다.\xa0 중증 병상 가동률은 66.8%(2천751개 중 1천839개 사용)다.... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '&quot;<b>코로나</b> 대유행 이번주 정점&quot;…이달 말부터 5∼11세 백신 접종',
#   'originallink': 'http://www.newsquest.co.kr/news/articleView.html?idxno=94290',
#   'link': 'http://www.newsquest.co.kr/news/articleView.html?idxno=94290',
#   'description': '14일 서울역 광장에 마련된 <b>코로나</b>19 임시 선별검사소에 시민들이 PCR(왼쪽) 혹은 신속항원검사(오른쪽)를 받기 위해 줄을 서서 기다리고 있다. [사진=연합뉴스] 국내 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 일일... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': "전자랜드, 새 학기 IT가전으로 '태블릿 PC' 인기 상승",
#   'originallink': 'http://www.dailysmart.co.kr/news/articleView.html?idxno=57057',
#   'link': 'http://www.dailysmart.co.kr/news/articleView.html?idxno=57057',
#   'description': '먼저 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19)의 발생 이후 재택근무나 비대면 수업을 하는 사람들이 늘어났고 이에 따라 IT 가전제품의 전체적인 인기도 증가했었다. 이후 <b>코로나</b>19가 장기화되면서 대면 수업과 비대면... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': "양천구, '안양천 명소화 기본계획' 수립… 오금교~신정교 구간",
#   'originallink': 'http://www.m-i.kr/news/articleView.html?idxno=903953',
#   'link': 'http://www.m-i.kr/news/articleView.html?idxno=903953',
#   'description': '특히 장기화된 <b>코로나</b>19로 안양천이 구민에게 최고의 방역 쉼터이자 힐링 공간으로 자리 잡은 현실을 반영해, 국회대로 상부 공원 등 관내 주요 공간과의 연결을 통한 안양천 접근성을 강화했다. 안양천 명소화 사업은... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '5~11세 <b>코로나</b>19 백신접종 시행…24일부터 사전예약',
#   'originallink': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0300&key=20220314.99099003265',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=658&aid=0000004285',
#   'description': '5~11세 소아에 대한 <b>코로나</b>19 백신 접종을 이달 말부터 시행한다. 전해철 중앙재난안전대책본부(중대본)... 최근 <b>코로나</b>19 백신 안전성위원회는 엠-알엔에이(mRNA) 백신 접종과 ‘심근염’ 발생 간 인과성을 인정하는... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:26:00 +0900'},
#  {'title': '학생·교직원, 오늘부터 가족 확진돼도 등교 가능',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722548',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620014',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': "해외진출 기업 10곳 중 6곳은 '리쇼어링' 고려…2년새 급증",
#   'originallink': 'https://news.imaeil.com/page/view/2022031410235850468',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=088&aid=0000749041',
#   'description': "해외에 진출한 우리나라 기업 중 국내 복귀를 의미하는 '리쇼어링'(reshoring)을 고려하는 기업이 <b>코로나</b>19... 이는 <b>코로나</b>19 기간 글로벌 공급망 불안 심화로 인한 생산 차질과 물류비 증가, 미·중 갈등 장기화 등이... ",
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': '오늘부터 가족 중 확진자 나와도 등교',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722547',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620018',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': '오늘부터 동거 가족 확진돼도 학생은 등교 가능',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722545',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620016',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': "[프로농구전망대] 1위 예약 SK·최하위 확정 삼성…'엇갈린 서울팀 희비'",
#   'originallink': 'http://yna.kr/AKR20220314055500007?did=1195m',
#   'link': 'https://sports.news.naver.com/news.nhn?oid=001&aid=0013049027',
#   'description': '시즌 개막을 앞두고 선수단 내 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 확진자 발생으로 컵 대회에 나오지 못하는 등 불안한 출발을 보인 삼성은 주전 외국인 선수 아이제아 힉스의 부상, 시즌 도중 불거진 천기범의... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': 'MZ 사원들이 면접…CJ그룹 파격 신입 공채',
#   'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02138566632263320',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=018&aid=0005166054',
#   'description': 'CJ(001040)가 14일부터 <b>코로나</b>19 이후 최대 규모 2022년 신입사원 공채를 접수받는다고 밝혔다. CJ제일제당(식품... CJ는 <b>코로나</b> 재확산 상황을 감안해 지원자들의 안전을 최우선으로 고려, 대부분의 전형을 비대면(온라인)... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': '가족 <b>코로나</b>19 확진돼도 등교 가능',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722549',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620015',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': '가족 확진돼도 등교',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722546',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620017',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:25:00 +0900'},
#  {'title': '동거인 확진돼도 등교',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722551',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620010',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '가족 확진돼도 등교 가능',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722552',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620011',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': "&quot;정점이냐 추가냐&quot;… <b>코로나</b>19 확산 이번주 '최대고비'",
#   'originallink': 'http://www.seoulwire.com/news/articleView.html?idxno=464492',
#   'link': 'http://www.seoulwire.com/news/articleView.html?idxno=464492',
#   'description': '서울역 광장에 설치된 <b>코로나</b>19 선별진료소를 찾은 시민들이 검사를 받기위해 대기하고 있다. 사진=서울와이어 DB \xa0신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 신규 확진자가 연일 30만명 안팎을 기록하는 가운데, 정부는... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '윤호중 &quot;교만함이 패배 불러, 분골쇄신할 것…대선 공약 이행 시작&quot;',
#   'originallink': 'https://www.news1.kr/articles/?4614413',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=421&aid=0005966837',
#   'description': '또한 윤 위원장은 &quot;선거 과정에서 국민께 드린 약속을 이행하는 것에서부터 시작하겠다&quot;면서 &quot;정치개혁 과제들의 조속한 추진, <b>코로나</b>19(신종 <b>코로나</b>바이러스 감염증) 피해 극복 등 주요 대선 공약들의 차질 없는 이행에... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '[카드뉴스] 경기 파주시 주요뉴스 (3월 14일)',
#   'originallink': 'http://www.weeklytoday.com/news/articleView.html?idxno=465552',
#   'link': 'http://www.weeklytoday.com/news/articleView.html?idxno=465552',
#   'description': '이 프로그램은 <b>코로나</b>19 사회적 거리두기로 장기간 휴관이였던 맘카페를 재개관하면서 맘카페 자유놀이실을 활성화하고 영유아가 가정에서 쉽게 접할 수 없는 체험놀이를 제공하기 위해 계획했다. 과정은 매월 넷째주... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '안철수 인수위원장 임명…관련주 일제히 급등, 안랩 장중 9% 급등',
#   'originallink': 'http://news.mk.co.kr/newsRead.php?no=233251&year=2022',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=009&aid=0004934068',
#   'description': '아울러 안 대표는 <b>코로나</b> 비상대응특위 위원장도 겸식한다. 윤 당선인은 인수위원장직을 맡게 된 안 대표에 대해 &quot;국정 운영 가치와 철학을 공유하고 선거 이후에도 제가 요청해서 먼저 자리를 가진 바 있다&quot;며 &quot;안... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '[속보] 아산 <b>코로나</b> 확진자 1998명 추가, 가족·지인·직장 등',
#   'originallink': 'http://www.sisamagazine.co.kr/news/articleView.html?idxno=433754',
#   'link': 'http://www.sisamagazine.co.kr/news/articleView.html?idxno=433754',
#   'description': '<b>코로나</b>19 방역, 예방접종 (시사매거진DB) 충남 아산시에서 <b>코로나</b>19 확진자 추가 소식이 전해졌다. 시에 따르면 14일 기준 신규확진자수는 1998명이다. 이로써 아산시 현재 누적 확진자수는 4만759명으로 집계됐다. 시는... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': 'NH농협은행, 인도 노이다지점 예비인가 획득…&quot;연내 본인가 획득 목표&quot;',
#   'originallink': 'http://www.4th.kr/news/articleView.html?idxno=2014897',
#   'link': 'http://www.4th.kr/news/articleView.html?idxno=2014897',
#   'description': '농협은행은 지난해 <b>코로나</b>19의 확산세가 특히 심했던 인도에 현지 적십자사를 통해 산소발생기를 직접 기부하고, 인도 협동조합 조직(IFFCO)과\xa0지속적인 협력 관계를 유지하는 등 적극적인 현지 ESG(환경·사회... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': 'CJ그룹, 2022년 상반기 신입사원 채용',
#   'originallink': 'http://www.psnews.co.kr/news/articleView.html?idxno=2005930',
#   'link': 'http://www.psnews.co.kr/news/articleView.html?idxno=2005930',
#   'description': 'CJ가 2022년 상반기 신입사원을 모집한다@CJ CJ(회장 이재현)가 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '정의선 현대차 회장, 인도네시아 생산공장 준공식 참석 위해 16일 출국',
#   'originallink': 'http://www.consumernews.co.kr/news/articleView.html?idxno=645154',
#   'link': 'http://www.consumernews.co.kr/news/articleView.html?idxno=645154',
#   'description': '애초 1월 준공식이 열릴 예정이었지만 <b>코로나</b>19 문제로 다소 미뤄진 것으로 알려졌다. 준공식에는 위도도 대통령을 포함한 인도네시아 정부 주요 인사가 참석할 것으로 알려져 회동이 성사될 경우 지난해에 이어 두 번째... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': "토스뱅크, '사장님대출' 출시 한 달 1160억원 돌파",
#   'originallink': 'http://www.newsis.com/view/?id=NISX20220314_0001792020&cID=10401&pID=10400',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=003&aid=0011060289',
#   'description': '토스뱅크 관계자는 &quot;일평균 1400명 고객들이 대출을 받기 위해 찾은 건 그만큼 <b>코로나</b>19로 어려움을 겪는 소상공인, 자영업자들이 많다는 반증&quot;이라며 &quot;고객들에게 중도상환수수료 무료 혜택을 이어가는 등 실질적인... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': 'CJ그룹, 상반기 신입사원 채용 시작…&quot;<b>코로나</b> 이후 최대 규모&quot;',
#   'originallink': 'http://yna.kr/AKR20220314053100003?did=1195m',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=001&aid=0013049018',
#   'description': 'CJ그룹이 14일 <b>코로나</b>19 사태 이후 최대 규모의 인재 확보를 목표로 올해 신입사원 채용 절차에 돌입했다. 이날부터 CJ제일제당(식품·바이오), CJ대한통운(물류·건설), CJ ENM(엔터·커머스), CJ올리브영, CJ올리브네트웍스... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '[속보] 대구시청 14일 0시 확진자 12,406명 발생 알려',
#   'originallink': 'http://www.asiaa.co.kr/news/articleView.html?idxno=80054',
#   'link': 'http://www.asiaa.co.kr/news/articleView.html?idxno=80054',
#   'description': '<b>코로나</b>19 의료진 (사진= 뉴스1 제공) \xa0대구시청이 14일 0시 기준 <b>코로나</b>19 확진자 12,406명 발생을 알렸다. 대구광역시 12,406명 확진자는 달서구 2554명, 북구 2338명, 수성구 2012명, 동구 1933명, 달성군... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '담양군, 신규농업인의 안정적인 농촌 정착 돕는다',
#   'originallink': 'https://www.farmnmarket.com/news/article.html?no=16786',
#   'link': 'https://www.farmnmarket.com/news/article.html?no=16786',
#   'description': '이번 교육은 <b>코로나</b>19 방역수칙을 준수해 참석자간 거리 확보, 발열 및 호흡기 증상 점검, 소독 실시 등 충분한 방역 조치를 병행했다. 교육은 지난 8일 개강식을 시작으로 매주 목요일, 총 5회에 걸쳐 진행되며 농촌... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': "'KIMES 2022' 성황리에 4일간의 일정 마쳐",
#   'originallink': 'http://www.babytimes.co.kr/news/articleView.html?idxno=55957',
#   'link': 'http://www.babytimes.co.kr/news/articleView.html?idxno=55957',
#   'description': 'KIMES 2022측은 이에 대해 <b>코로나</b>19로 인해 비대면 의료산업 이슈가 증폭되는 한편\xa0Ai, 로봇기술과 접목된 융복합 의료기기에 대한 관심과 니즈가 증가하고 급변하는 의료환경에 대한 높은 관심이 반영된... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '대구 신규 확진자 1만 2천406명…\xa0중환자 병상 가동률 85.4%',
#   'originallink': 'https://www.idaegu.co.kr/news/articleView.html?idxno=375343',
#   'link': 'https://www.idaegu.co.kr/news/articleView.html?idxno=375343',
#   'description': '대구에서 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 확진자가 하루 새 1만 2천406명 발생했다. 14일 대구시에 따르면 이날 0시 기준 지역 <b>코로나</b>19 신규 확진자 수는 1만 2천406명, 누적 확진자 수는 26만 8천774명이다.... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '온라인 해외직구 열풍에…카드사 직구족 공략',
#   'originallink': 'https://www.ebn.co.kr/news/view/1522912/?sc=Naver',
#   'link': 'https://www.ebn.co.kr/news/view/1522912/?sc=Naver',
#   'description': '<b>코로나</b>19 장기화로 해외로 나가 직접 쇼핑할 수 있는 기회가 줄어들면서 온라인 해외직구 시장이... <b>코로나</b>19가 발발했던 2020년(103억1000만달러)에 비해 18.6% 증가한 수준이다. 한은 관계자는 &quot;<b>코로나</b>19 재확산으로... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '원희룡 &quot;0.73%p로 도취하면 제정신이냐...매일 투표하면 역전될 수도&quot;',
#   'originallink': 'https://www.ajunews.com/view/20220314100153604',
#   'link': 'https://www.ajunews.com/view/20220314100153604',
#   'description': '그는\xa0&quot;다들 걱정하는 것이 지금 민주당이 국회에서 총리 인준을 안 해 줄\xa0것&quot;이라며\xa0&quot;지금 <b>코로나</b>부터 해결해야 할 일이 산적해 있는데 정쟁으로 시작한다는 게 사실 우리 윤석열\xa0당선인으로서도\xa0부담&quot;이라고 설명했다.... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '전남 함평군, 올해 살림 규모 5,019억~전년 比 267억 증가',
#   'originallink': 'https://www.wikitree.co.kr/articles/738592',
#   'link': 'https://www.wikitree.co.kr/articles/738592',
#   'description': '<b>코로나</b>19로 침체한 지역경제 활성화 및 인프라 구축 등을 위해 쓰일 예정이다. 총 예산 중 일반회계가 4... 군 관계자는 “<b>코로나</b>19로 지역사회가 위축된 상황이지만, 세원 발굴과 중앙 재원의 적극적 확보로 경제... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '[Who Is ?] 이석희 SK하이닉스 대표이사 사장',
#   'originallink': 'https://www.businesspost.co.kr/BP?command=article_view&num=274324',
#   'link': 'https://www.businesspost.co.kr/BP?command=article_view&num=274324',
#   'description': 'SK하이닉스는 공급망 차질 등으로 시장환경이 불확실한 상황 속에서도 <b>코로나</b>19로 비대면 IT 기기 수요가 늘어나 반도체 제품 공급을 확대하며 사상 최대 매출을 올렸다고 설명했다. D램 사업에서는 PC와 서버용... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': "'방역패스' 완전 폐지될까? '실외 노마스크' 고려도... 달라지는 윤석열 방역",
#   'originallink': 'http://www.ggilbo.com/news/articleView.html?idxno=900721',
#   'link': 'http://www.ggilbo.com/news/articleView.html?idxno=900721',
#   'description': '나왔다면 <b>코로나</b>19 확진자로 인정되는 등 일부 방역수칙이 변경된 가운데 방역패스 완전 폐지에도 관심이... 실제 윤 당선인은 <b>코로나</b>19 대응체계를 집권 100일 안에 전면 개편하겠다고 공약했다. 윤\xa0당선인은 과학과... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '“AI·미래차·반도체, 차기정부 중점 지원해야”',
#   'originallink': 'http://amenews.kr/news/view.php?idx=48037',
#   'link': 'http://amenews.kr/news/view.php?idx=48037',
#   'description': '이는 차기정부가 <b>코로나</b> 19가 장기화되면서 높아진 경제불확실성을 해소하고 경제재도약을 통한 일자리 창출을 위해 전면에 나서 주기를 바라는 기업의 요구가 반영된 결과로 해석된다. 경제재도약을 통한... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': "LG유플러스, 10대 전용 'U+Z플랜폰' 출시",
#   'originallink': 'http://www.newsbrite.net/news/articleView.html?idxno=164901',
#   'link': 'http://www.newsbrite.net/news/articleView.html?idxno=164901',
#   'description': "LG유플러스는 자체 조사를 통해 <b>코로나</b>19 이후 청소년의 생활 패턴이 원격수업과 등교 상황에 따라 다르다는 것을 확인, 상황에 맞게 스마트폰을 활용할 수 있는 기능을 탑재했다. 청소년은 단말기에 선탑재된 'ZPlan... ",
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '제주 확진자 폭증에 6급도 한계 항공청 직원까지 조사 투입',
#   'originallink': 'http://www.jejusori.net/news/articleView.html?idxno=400386',
#   'link': 'http://www.jejusori.net/news/articleView.html?idxno=400386',
#   'description': '10일(위)과 13일(아래) <b>코로나</b>19 진단검사를 받기 위해 제주보건소에서 대기하고 있는 시민들의 모습. ⓒ제주의소리 제주지역 신종 <b>코로나</b> 바이러스 감염증(<b>코로나</b>19) 확진자가 폭증하면서 항공청 직원까지 역학조사에... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '진매트릭스, <b>코로나</b> 변이 대응 백신물질 특허 출원',
#   'originallink': 'http://www.medisobizanews.com/news/articleView.html?idxno=85770',
#   'link': 'http://www.medisobizanews.com/news/articleView.html?idxno=85770',
#   'description': '진매트릭스(대표이사 김수옥)가 자체 개발한 백신 개발 원천플랫폼을 통해 <b>코로나</b>19 변이 바이러스에 범용적인 백신 후보물질을 개발하고 특허 출원을 완료했다고 14일 밝혔다. 해당 후보물질은 <b>코로나</b> 바이러스의... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': 'CJ그룹, 2022 상반기 신입사원 채용 시작…<b>코로나</b>19 이후 최대 규모',
#   'originallink': 'http://www.m-i.kr/news/articleView.html?idxno=903954',
#   'link': 'http://www.m-i.kr/news/articleView.html?idxno=903954',
#   'description': '사진=CJ그룹 제공 CJ그룹이 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로 하는 2022년 신입사원 채용 절차에... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '베스 르테인 아시아 첫 개인전, 《Trees for the Forest》 개최',
#   'originallink': 'http://www.sctoday.co.kr/news/articleView.html?idxno=37907',
#   'link': 'http://www.sctoday.co.kr/news/articleView.html?idxno=37907',
#   'description': '작가는 <b>코로나</b> 팬데믹을 계기로 자신의 소소한 일상과 주변을 새롭게 바라볼 수 있게 됐고, 전시를 준비하며 예전 작품들과 이번 신작들을 비교하며 본인의 작가 활동의 큰 숲을 볼 수 있는 중요한... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '지방선거 준비 착수한 국민의힘···한기호 사무총장 임명',
#   'originallink': 'https://www.khan.co.kr/politics/politics-general/article/202203141023001',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=032&aid=0003134014',
#   'description': '이 대표는 <b>코로나</b>19 확진으로 자가격리 중이다. 이 대표는 “이제 지방선거가 80일 앞으로 다가왔다”면서 “(대선)출구조사 결과처럼 지방선거에서 민주당과 치열한 경쟁이 예고된다”고 말했다. 그는 이어... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '가족 등 동거인 확진돼도 등교 가능',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722550',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003620013',
#   'description': '가족 등 동거인이 <b>코로나</b>19에 확진돼도 백신접종 여부와 상관없이 수동 감시자로 지정돼 등교가 가능해진 14일 서울 시내 한 초등학교에서 학생들이 등교하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '인천 1만8천239명 확진...사망 8명',
#   'originallink': 'http://www.incheonnews.com/news/articleView.html?idxno=406510',
#   'link': 'http://www.incheonnews.com/news/articleView.html?idxno=406510',
#   'description': '인천시에 따르면 14일 0시 기준 인천시 <b>코로나</b>19 확진자는 전날(0시) 439,407명 대비 18,239명이 증가한 457,645명이다. &lt; 최근 10일 간 <b>코로나</b>19 확진자 발생 추이 &gt; 신규 확진자 18,239명은 국내 발생 18,238명, 해외... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': 'NH농협은행, 인도 노이다지점 예비인가 획득',
#   'originallink': 'http://www.newscape.co.kr/news/articleView.html?idxno=80685',
#   'link': 'http://www.newscape.co.kr/news/articleView.html?idxno=80685',
#   'description': '농협은행은 작년 <b>코로나</b>19의 확산세가 특히 심했던 인도에 현지 적십자사를 통해 산소발생기를 직접 기부하고, 인도 협동조합 조직인 IFFCO사와 지속적인 협력관계를 유지하는 등 적극적인 현지 ESG경영을 통해 이번... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:24:00 +0900'},
#  {'title': '사흘째 신규 확진 30만 명 넘어…5~11세 31일부터 접종',
#   'originallink': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006674310&plink=ORI&cooper=NAVER',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000959978',
#   'description': '국내 <b>코로나</b>19\xa0신규 확진자가 사흘 연속\xa030만 명을 넘었습니다. 정부는\xa0이달 말부터 5세~11세 소아청소년들에 대한 백신 접종을 시작합니다. 박재현 기자입니다. &lt;기자&gt; 어제(13일) 하루 <b>코로나</b>19 신규 확진자는 30만... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': '구지은 아워홈 부회장, 무배당 결정…&quot;성장동력 발굴에 자원 집중&quot;',
#   'originallink': 'http://news.tf.co.kr/read/economy/1924242.htm',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=629&aid=0000137378',
#   'description': '적자 성적표를 받은 지 1년 만에 흑자 전환에 성공했다. <b>코로나</b>19 상황에서 단체급식 및 식자재 업계 불황으로 2020년 적자를 기록했지만, 지난해 매출액 약 1조7200억 원, 영업이익 약 250억 원의 실적을 올린 것으로 추정된다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': '경기, <b>코로나</b>19 신규확진 7만7421명…사망 66명 하루 최다',
#   'originallink': 'https://www.pressian.com/pages/articles/2022031410205270438?utm_source=naver&utm_medium=search',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=002&aid=0002234443',
#   'description': '경기지역 <b>코로나</b>19 신규 확진자가 어제(13일) 하루 동안 7만7421명이 발생했다. 사망자는 66명으로 하루 최다 발생 기록을 경신했다. 경기도는 14일 0시 기준 <b>코로나</b>19 신규 확진자가 7만7421명이 늘어... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': '“사회적 가치 실현” 자생의료재단 ‘2021 사회공헌백서’ 발간',
#   'originallink': 'https://sports.donga.com/article/all/20220314/112317483/2',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=382&aid=0000966135',
#   'description': '백서에는 <b>코로나</b>19 상황 속에서도 국가유공자, 노인, 청소년 등을 대상으로 진행한 사회공헌활동을 정리했다. 우선 방역물품 지원을 통해 <b>코로나</b>19 극복을 위한 국가적 노력에 동참했다. 재단은 지난해 마스크 6만2600장... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': "&quot;애플 한 판 붙자&quot;…중저가 힘주는 삼성, '갤럭시A' 언팩 2년 연속 개최",
#   'originallink': 'http://www.inews24.com/view/1459821',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000659119',
#   'description': "업계 관계자는 &quot;<b>코로나</b>19 여파로 소비 심리는 위축됐지만 5G 상용화 국가가 늘어나면서 중저가 제품 수요가 커지고 있다&quot;며 &quot;이에 맞춰 삼성전자가 '갤럭시A' 시리즈의 사양을 높이고 출시 대상국을 늘리는 쪽으로... ",
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': "CJ그룹, <b>코로나</b> 이후 최대 규모 '상반기 신입사원' 채용",
#   'originallink': 'http://www.newsis.com/view/?id=NISX20220314_0001792010&cID=13001&pID=13000',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=003&aid=0011060284',
#   'description': 'CJ그룹은 경영환경이 불확실한 상황에서도 그룹의 미래인재를 확보하고 침체된 고용시장에 활기를 불어넣기 위해 2022년 연간 신입 채용을 <b>코로나</b>19 이후 최대 규모로 늘렸다. 지원자격은 국내외 대학 학사학위 이상... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': "[오미크론 대혼란] 위중증 1158명 '역대 최다'…사망 200명",
#   'originallink': 'http://www.newspim.com/news/view/20220314000277',
#   'link': 'http://www.newspim.com/news/view/20220314000277',
#   'description': '중앙방역대책본부는 14일 0시 기준 <b>코로나</b>19 신규 확진자가 30만9790명이라고 밝혔다. 이중 국내... 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 대응 중앙재난안전대책본부 회의를 주재하고 있다. 2022.03.14... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': '2022 LCK 스프링 8주차, 16연승 성공한 T1',
#   'originallink': 'https://www.fomos.kr/redirect/news_view?news_cate_id=13&entry_id=109025',
#   'link': 'https://sports.news.naver.com/news.nhn?oid=236&aid=0000222077',
#   'description': '프레딧 브리온이 <b>코로나</b>19 이슈로 인해 1군 선수들이 한 명도 출전하지 못하는 상황에서 T1은 1세트와 2세트 모두 20분 안에 상대 넥서스를 파괴하면서 16경기 연속 승리 기록을 세웠다. 16연승을 달린 T1은 2022 LCK... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:23:00 +0900'},
#  {'title': '&quot;오는 18일 BTS공연 에버랜드서 불꽃쇼와 함께...&quot;',
#   'originallink': 'http://www.newsis.com/view/?id=NISX20220314_0001792002&cID=14001&pID=14000',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=003&aid=0011060282',
#   'description': '에버랜드는 국내 뿐만 아니라 전세계인들에게 <b>코로나</b> 팬데믹 극복을 위한 희망의 메시지를 선물하고자... 경험하면서 <b>코로나</b>19로 힘든 시기에 희망과 위로가 되길 바란다&quot;고 말했다. 한편, 에버랜드는 이번... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': "[현장] 리더십 교체 앞둔 네이버 주총 '긴장감'…세대교체 '주목'",
#   'originallink': 'https://www.dailian.co.kr/news/view/1092774/?sc=Naver',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=105&oid=119&aid=0002584792',
#   'description': '신종 <b>코로나</b> 바이러스 감염증(<b>코로나</b>19) 확산으로 전자투표와 전자위임장 수여 시행 등이 보편화되면서 차분한 분위기 속에 진행됐지만, 온라인 생중계가 진행되지 않은 만큼 다수의 주주들의 발길이 이어졌다. 주총이... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '신생팀 김포의 프로 첫 홈 개막전, 성황리에 치러졌다',
#   'originallink': 'http://www.sportsworldi.com/newsView/20220314504522',
#   'link': 'https://sports.news.naver.com/news.nhn?oid=396&aid=0000607131',
#   'description': '고정운 감독은 경기 후 인터뷰에서 “신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 때문에 모두가 힘들고 지친 상황이다. 김포에는 시민들이 하나로 뭉칠 수 있는 그런 스포츠단이 없었다. 김포FC를 매개로 해서 시민들이... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '신문브리핑 4 &quot;교직원·학생, 동거인 감염돼도 등교 &quot; 외 주요기사',
#   'originallink': 'http://www.mbn.co.kr/pages/news/newsView.php?news_seq_no=4716779',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=057&aid=0001648769',
#   'description': '신문브리핑 4 &quot;교직원·학생, 동거인 감염돼도 등교 &quot; 외 주요기사(0314) #아침앤매일경제 #신문브리핑 #이상훈앵커 #<b>코로나</b> #<b>코로나</b>19 #오미크론 #방역패스 #백신 #백신패스',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '[종합]<b>코로나</b>19 확진자 폭증에 위중증환자 1158명으로 역대 최다',
#   'originallink': 'http://www.fnnews.com/news/202203141006105632',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=014&aid=0004802520',
#   'description': '<b>코로나</b>19 신규확진자가 폭증하는 가운데, 위중증환자는 1158명으로 집계되며 역대 최다치를... 15만2467명이 <b>코로나</b>19 감염으로 확진됐다. 이 밖에 부산 2만7759명, 대구 1만2406명, 광주 8339명, 대전 8290명... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '마스크 ‘이렇게’ 쓰면 안구건조증 생긴다',
#   'originallink': 'https://kormedi.com/?p=1386049',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=296&aid=0000054782',
#   'description': '<b>코로나</b>19로 인해 안구건조증을 호소하는 사람이 늘고 있다. 재택근무와 학생들의 온라인학습으로 스마트폰과 컴퓨터 등 디지털기기 이용시간이 급격하게 늘었기 때문. 이와 함께 마스크를 장시간 착용하는 것도... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': 'CJ그룹, 2022년 상반기 신입사원 채용 시작',
#   'originallink': 'http://www.lawissue.co.kr/view.php?ud=20220314102113246204ead0791_12',
#   'link': 'http://www.lawissue.co.kr/view.php?ud=20220314102113246204ead0791_12',
#   'description': 'CJ(회장 이재현)가 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로 하는 2022년 신입사원 채용 절차에 돌입했다.... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '오늘부터 신속항원검사도 <b>코로나</b> 확진 인정',
#   'originallink': 'http://www.cpbc.co.kr/CMS/news/view_body.php?cid=820153&path=202203',
#   'link': 'http://www.cpbc.co.kr/CMS/news/view_body.php?cid=820153&path=202203',
#   'description': '오늘부터 전문가용 신속항원검사에서 <b>코로나</b>19 양성 판정을 받아도 확진으로 인정됩니다. 이에 따라 동네... 받을 수 있습니다. 해당 기관은 건강보험심사평가원 누리집과 <b>코로나</b>19 누리집에서 확인하면 됩니다.',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '홍성군 1회 추경 361억 편성',
#   'originallink': 'http://www.goodmorningcc.com/news/articleView.html?idxno=265928',
#   'link': 'http://www.goodmorningcc.com/news/articleView.html?idxno=265928',
#   'description': '군은 <b>코로나</b>19 피해 회복과 지역경제 활성화 사업, 미래 성장동력을 위한 기반사업 구축에 중점을 두고 추경안을 편성했다. 구체적으로 ▲소상공인 등 긴급재난지원금 63억 원 ▲홍성사랑상품권 발행 27억 원 ▲감염... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '성남시, 영세 음식점 주방 환경개선 지원',
#   'originallink': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202203140903289680455',
#   'link': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202203140903289680455',
#   'description': '성남시 위생정책과 관계자는 “노후한 주방 시설의 위생 수준을 높여 안전한 먹거리 제공 환경을 조성하고, <b>코로나</b>19 장기화로 침체한 지역경제를 활성화하려는 취지”라고 말했다. 성남= pbc2001@',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': "[<b>코로나</b>19 발생현황] 위중증 환자 1158명 '역대 최다'... 어제 200명 사망, 누...",
#   'originallink': 'http://www.getnews.co.kr/news/articleView.html?idxno=576201',
#   'link': 'http://www.getnews.co.kr/news/articleView.html?idxno=576201',
#   'description': '오미크론 변이가 확산이 이어지면서 유행이 정점에 다다르면서 14일 <b>코로나</b>19 신규 확진자수가 30만명을 넘은 가운데 역대 최다 <b>코로나</b>19 위중증 환자가 나왔다. 중앙방역대책본부에 따르면 이날 0시... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': "방탄소년단, 전 세계 246만 명과 함께한 '3일의 기적'",
#   'originallink': 'http://www.sportsq.co.kr/news/articleView.html?idxno=438114',
#   'link': 'http://www.sportsq.co.kr/news/articleView.html?idxno=438114',
#   'description': '신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 팬데믹으로 공연장 내 수용인원 제한이 불가피했던 상황 속에서 방탄소년단은 다양한 이벤트로 팬들의 아쉬움을 달랬다. 1, 3회차 공연은 온라인 라이브 스트리밍이 동시... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': "[전문] 대구 '<b>코로나</b>19' 확진자 1만2406명...사망자 12명",
#   'originallink': 'http://www.kbsm.net/news/view.php?idx=341830',
#   'link': 'http://www.kbsm.net/news/view.php?idx=341830',
#   'description': '대구에서 <b>코로나</b>19 확진자가 1만2406명이 늘었다. 14일 대구시 재난안전대책본부에 따르면 이날 0시 기준 <b>코로나</b>19 신규 확진자는 전날 대비 1만2406명이 늘어 누적 확진자는 26만8774명(해외유입 598명 포함)이다.... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '[김한수의 시니어 라이프 109] 사회에 진 마음의 빚, 평생을 갚으며 살아가야...',
#   'originallink': 'https://www.christiantoday.co.kr/news/346189',
#   'link': 'https://www.christiantoday.co.kr/news/346189',
#   'description': '그렇게 막연하게 사회에 대한 부채의식 같은 것을 갖고 지내다가 <b>코로나</b>로 시간적인 여유가 생겨서 노후에 자기 삶의 가치를 느끼면서 할 수 있는 일이 무엇이 있을까 하고 알아보던 도중에 인연처럼 사회복지사라는... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': "[<b>코로나</b>19] 동네 병의원 등에서 신속검사 '양성'도 확진…가족 확진돼도 등교...",
#   'originallink': 'https://news.bbsi.co.kr/news/articleView.html?idxno=3061850',
#   'link': 'https://news.bbsi.co.kr/news/articleView.html?idxno=3061850',
#   'description': "오늘부터 동네 병원, 의원 등에서 신속항원검사를 받고 '양성'이 나왔다면 <b>코로나</b>19 확진자로 인정됩니다.... 또 오늘부터는 같이 사는 가족이 <b>코로나</b>19에 확진됐더라도 학생과 교직원은 학교에 갈 수 있습니다.",
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '경기주택도시공사, 공공주택에 개방형발코니‘GH 여유리움’ 도입',
#   'originallink': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202203140859185210453',
#   'link': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202203140859185210453',
#   'description': '또, 세대 내에 적절한 규모의 개방형 발코니를 구성해 <b>코로나</b>19 장기화로 인한 외부 활동 제한에도 실내에서 개방감을 느낄 수 있도록 했다. GH 전형수 부사장(사장 직무대행)은 &quot;실수요자 중심 주거공간 도입을 통해... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': 'FSN, 지난해 영업익 134% 증가…창사 이래 최대 실적',
#   'originallink': 'https://news.mtn.co.kr/news-detail/2022031410044310984',
#   'link': 'https://news.mtn.co.kr/news-detail/2022031410044310984',
#   'description': '또한 애드테크, 플랫폼 등 전반적인 테크 사업 역시 호조를 이뤘고 글로벌 사업도 <b>코로나</b>19 여파에도 불구하고 양호한 실적을 달성했다.서정교 FSN 각자대표이사는 &quot;지난해 계열분리를 통해 독립적인 경영 기반을... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': 'CJ, 2022년 상반기 신입사원 채용',
#   'originallink': 'http://www.thekpm.com/news/articleView.html?idxno=111998',
#   'link': 'http://www.thekpm.com/news/articleView.html?idxno=111998',
#   'description': '사진=CJ그룹 \xa0CJ그룹이 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로 하는 2022년 신입사원 채용 절차에... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를 확보하고... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '‘5~11세’ 백신 접종 이달말 시작…“안전성 검증됐다”',
#   'originallink': 'http://www.g-enews.com/ko-kr/news/article/news_all/202203141009084652f29c535823_1/article.html',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202203141009084652f29c535823_1/article.html',
#   'description': '대한 <b>코로나</b>19 백신 접종을 이달 말부터 시행한다. 14일 전해철 중앙재난안전대책본부(중대본) 2차장은... 전 2차장은 또 “최근 <b>코로나</b>19 백신 안전성위원회는 메신저 리보핵산(mRNA) 백신 접종과 ‘심근염’ 발생 간... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '정의선,印尼공장 준공식 16일 참석…조코위와 전기차 논의',
#   'originallink': 'http://www.seouleconews.com/news/articleView.html?idxno=65208',
#   'link': 'http://www.seouleconews.com/news/articleView.html?idxno=65208',
#   'description': '준공식은 당초 올해 1월 열릴 예정이었지만, <b>코로나</b>19 사태로 미뤄지다가 이번에 개최되게 됐다.\xa0이 공장에서는 연내 현대차의 전기차 아이오닉5 생산도 계획하고 있다. 정 회장은 행사에 참석하기 위해 15일 전용기로... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '[종합] 휴일에도 확진자 30만 명…사망자 5일째 200명대',
#   'originallink': 'https://www.etoday.co.kr/news/view/2113715',
#   'link': 'https://www.etoday.co.kr/news/view/2113715',
#   'description': '확진 <b>코로나</b>19 신규 확진자가 휴일에도 30만 명을 넘어섰다. 사망자는 5일 연속 200명을 기록했다. 질병관리청 중앙방역대책본부는 14일 0시 기준으로 <b>코로나</b>19 확진자가 30만9790명 증가한 686만6222명으로... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '위중증 환자 1158명 ‘역대 최다’…신규확진 30만9790명',
#   'originallink': 'https://www.seoul.co.kr/news/newsView.php?id=20220314500041&wlog_tag3=naver',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=081&aid=0003257943',
#   'description': '8%로 올라 어제 200명 사망, 누적 1만595명 “이번주 오미크론 유행 정점 구간” 오미크론 변이 유행이 정점에 가까워지면서 14일 <b>코로나</b>19 신규 확진자수가 30만명을 넘은 가운데 역대 최다 <b>코로나</b>19 위중증... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '세븐틴 준·조슈아, <b>코로나</b>19 완치[공식]',
#   'originallink': 'http://sports.khan.co.kr/news/sk_index.html?art_id=202203141021003&sec_id=540101&pt=nv',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=144&aid=0000799078',
#   'description': '그룹 세븐틴의 조슈아와 준이 <b>코로나</b>19 완치 판정을 받았다. 세븐틴의 소속사 플레디스 엔터테인먼트는 14일 “세븐틴 멤버 조슈아와 준이 <b>코로나</b>19 완치 판정을 받아 금일부터 격리 해제되었다”고 밝혔다. 이어... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '국세청, 울진·강원 산불피해 복구 지원성금 1천만원 기탁',
#   'originallink': 'http://www.taxtimes.co.kr/news/article.html?no=253980',
#   'link': 'http://www.taxtimes.co.kr/news/article.html?no=253980',
#   'description': '앞서 국세청은 2020년 <b>코로나</b>19 피해 지원을 위해 성금과 물품을 전달했으며, 지난 2019년 강원도 산불과 2017년 포항 지진 등 다양한 재난 및 재해 발생시 복구 지원 및 성금을 기탁해 왔다. 국세청 관계자는 “앞으로도... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': "[급등주] 진매트릭스 17% 강세 '<b>코로나</b> 백신 후보물질 개발'",
#   'originallink': 'https://www.gukjenews.com/news/articleView.html?idxno=2425207',
#   'link': 'https://www.gukjenews.com/news/articleView.html?idxno=2425207',
#   'description': "이날 진매트릭스가 자체 개발한 백신 개발 원천플랫폼을 통해 <b>코로나</b>19 변이 바이러스에 범용적인 백신 후보물질을 개발하고 특허 출원을 완료했다고 밝혔다. 해당 후보물질은 <b>코로나</b> 바이러스의 ▲'스파이크' 표면... ",
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': 'CJ그룹, 2022 상반기 신입사원 채용',
#   'originallink': 'https://www.straightnews.co.kr/news/articleView.html?idxno=206025',
#   'link': 'https://www.straightnews.co.kr/news/articleView.html?idxno=206025',
#   'description': 'CJ그룹(회장 이재현)이 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로 하는 2022년 신입사원 채용 절차에... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를 확보하고... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '전남 <b>코로나</b> 확진자, 결국 1만1천명 돌파',
#   'originallink': 'http://www.mdilbo.com/detail/c3QycN/664813',
#   'link': 'http://www.mdilbo.com/detail/c3QycN/664813',
#   'description': '전남의 <b>코로나</b>19 일일 확진자가 1만1천명을 돌파했다. 지역 첫 환자 발생 25개월만에 만명대를 넘어... 14일 광주시와 전남도 방역당국에 따르면 전날 발생한 <b>코로나</b>19 신규 환자는 광주 8천339명, 전남 1만933명... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': 'CJ그룹, 2022 상반기 신입사원 채용',
#   'originallink': 'https://www.straightnews.co.kr/news/articleView.html?idxno=206025',
#   'link': 'https://www.straightnews.co.kr/news/articleView.html?idxno=206025',
#   'description': 'CJ그룹(회장 이재현)이 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로 하는 2022년 신입사원 채용 절차에... CJ는 <b>코로나</b> 재확산 및 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를 확보하고... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '[종합]<b>코로나</b>19 확진자 폭증에 위중증환자 1158명으로 역대 최다',
#   'originallink': 'http://www.fnnews.com/news/202203141006105632',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=014&aid=0004802520',
#   'description': '<b>코로나</b>19 신규확진자가 폭증하는 가운데, 위중증환자는 1158명으로 집계되며 역대 최다치를... 15만2467명이 <b>코로나</b>19 감염으로 확진됐다. 이 밖에 부산 2만7759명, 대구 1만2406명, 광주 8339명, 대전 8290명... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '창립 2주년 ‘창업인’, 누적사용자 15만…주요 고객 연령층 3040',
#   'originallink': 'https://platum.kr/archives/182291',
#   'link': 'https://platum.kr/archives/182291',
#   'description': '<b>코로나</b>로 인해 비대면 창업 상담 진행을 희망하는 고객의 수가 늘면서 자연스럽게 창업인의 창업톡 서비스... 창업인의 정재훈 부대표는 “AI상권분석, 프랜차이즈-예비창업자 매칭 서비스 뿐만 아니라 <b>코로나</b>19로... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '홍성군 1회 추경 361억 편성',
#   'originallink': 'http://www.goodmorningcc.com/news/articleView.html?idxno=265928',
#   'link': 'http://www.goodmorningcc.com/news/articleView.html?idxno=265928',
#   'description': '군은 <b>코로나</b>19 피해 회복과 지역경제 활성화 사업, 미래 성장동력을 위한 기반사업 구축에 중점을 두고 추경안을 편성했다. 구체적으로 ▲소상공인 등 긴급재난지원금 63억 원 ▲홍성사랑상품권 발행 27억 원 ▲감염... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '‘5~11세’ 백신 접종 이달말 시작…“안전성 검증됐다”',
#   'originallink': 'http://www.g-enews.com/ko-kr/news/article/news_all/202203141009084652f29c535823_1/article.html',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202203141009084652f29c535823_1/article.html',
#   'description': '대한 <b>코로나</b>19 백신 접종을 이달 말부터 시행한다. 14일 전해철 중앙재난안전대책본부(중대본) 2차장은... 전 2차장은 또 “최근 <b>코로나</b>19 백신 안전성위원회는 메신저 리보핵산(mRNA) 백신 접종과 ‘심근염’ 발생 간... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '[종합] 휴일에도 확진자 30만 명…사망자 5일째 200명대',
#   'originallink': 'https://www.etoday.co.kr/news/view/2113715',
#   'link': 'https://www.etoday.co.kr/news/view/2113715',
#   'description': '확진 <b>코로나</b>19 신규 확진자가 휴일에도 30만 명을 넘어섰다. 사망자는 5일 연속 200명을 기록했다. 질병관리청 중앙방역대책본부는 14일 0시 기준으로 <b>코로나</b>19 확진자가 30만9790명 증가한 686만6222명으로... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:22:00 +0900'},
#  {'title': '투자 망설이는 대기업들…&quot;규제완화·세제지원 확대할 때&quot;',
#   'originallink': 'http://www.joseilbo.com/news/news_read.php?uid=448790&class=1&grp=',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=123&aid=0002269324',
#   'description': '기업들은 투자 규모를 늘리기 어려운 이유로 ▲<b>코로나</b>19 확산세 및 원자재 가격 상승 등 국내외 거시경제... 전경련은 &quot;<b>코로나</b>19 기간 글로벌 공급망 불안 심화로 인한 생산차질과 물류비 증가, 미·중 갈등 장기화... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:21:00 +0900'},
#  {'title': '성동구, 재택치료자 격리통지서 집에서도 발급한다',
#   'originallink': 'https://www.news1.kr/articles/?4614435',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005966824',
#   'description': '신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 재택치료자는 온라인에서도 격리통지서를 출력해 발급받을 수 있다. 구는 기존 5~7일 소요된 격리통지서 발급 기간을 대폭 줄였다. 역학조사가 완료된 <b>코로나</b>19 재택치료자라면... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:21:00 +0900'},
#  {'title': '“작년 책 100권이상 구매 9.5% 증가”… <b>코로나</b> 시대 ‘다독가’ 는다',
#   'originallink': 'http://www.munhwa.com/news/view.html?no=2022031401031530119001',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=021&aid=0002506163',
#   'description': '여성 61% · 40代 39%로 최다 교보문고 “자기계발서 등 인기” <b>코로나</b>19 사태가 장기화하면서 책을... 연간 100권 이상 다독가는 <b>코로나</b>19 대유행 첫 해인 2020년에도 전년에 비해 17.9% 늘었는데, 여기서 다시 한 번... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:21:00 +0900'},
#  {'title': "'조선의 4번타자' 이대호, KBO 역대 두 번째 '은퇴 투어' 주인공",
#   'originallink': 'http://yna.kr/AKR20220314052700007?did=1195m',
#   'link': 'https://sports.news.naver.com/news.nhn?oid=001&aid=0013049004',
#   'description': '2020년과 2021년에는 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 여파로 올스타전이 열리지 않았다. KBO는 &quot;올해 올스타전은 KBO리그 출범 40주년을 기념해 지난 40년을 추억하고 앞으로 팬들에게 더 가까이 다가가 새롭게... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:21:00 +0900'},
#  {'title': '얼마만이야 이게…아시아나 나고야행 다시 뜬다',
#   'originallink': 'http://news.mk.co.kr/newsRead.php?no=233228&year=2022',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=009&aid=0004934066',
#   'description': '<b>코로나</b>19 팬데믹으로 인해 지난해 4월 29일 운항을 끝으로 노선 운영을 중단한 지 11개월 만에 다시... 아시아나항공 관계자는 &quot;포스트 <b>코로나</b>를 대비해 일본 노선을 확대했다&quot;며 &quot;한국-일본 간 무사증 입국제도와... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:21:00 +0900'},
#  {'title': '밀양농협-밀양지역자활센터 업무협약…‘이웃사랑 기금 1,200만 원’ 전달',
#   'originallink': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1526379',
#   'link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=1526379',
#   'description': '효도식탁 전달, 지역 어르신 생일상 차려드리기, 사랑의 실버카(보행기), <b>코로나</b>19 방역 사랑의 후원품 전달, 임직원 사랑의 헌혈 등 다양한 후원 사업으로 지역사랑 봉사활동 등을 지속적으로 펼치고 있다. [신아일보]',
#   'pubDate': 'Mon, 14 Mar 2022 10:20:00 +0900'},
#  {'title': '기장군, 전 군민 대상 1인당 50장 마스크 7차 무상 배부',
#   'originallink': 'https://www.ekn.kr/web/view.php?key=20220314010002095',
#   'link': 'https://www.ekn.kr/web/view.php?key=20220314010002095',
#   'description': '기장군(군수 오규석)은 정부의 방역패스 잠정 중단 조치 등에 따른 단계적 일상회복 흐름에 맞춰 <b>코로나</b>19... 오규석 기장군수는 &quot;백신 접종으로 집단면역이 형성되기 전까지 <b>코로나</b>19의 가장 확실한 예방은 마스크... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:20:00 +0900'},
#  {'title': 'JTI코리아, 지역 문화예술 활성화 지원',
#   'originallink': 'https://news.mtn.co.kr/news-detail/2022031410162219519',
#   'link': 'https://news.mtn.co.kr/news-detail/2022031410162219519',
#   'description': '이번 문화예술 지원사업은 <b>코로나</b>19 장기화로 예정된 공연이 취소·연기돼 어려움을 겪는 지역... 김영지 JTI코리아 전무는 &quot;<b>코로나</b>19 장기화로 어려움을 겪는 지역 문화예술계를 지원할 수 있어 기쁘게 생각한다&quot;며... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:20:00 +0900'},
#  {'title': 'CJ그룹, 2022년 상반기 신입 채용…&quot;<b>코로나</b> 이후 최대 규모로 뽑는다&quot;',
#   'originallink': 'http://www.dt.co.kr/contents.html?article_no=2022031402109932102001&ref=naver',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002724545',
#   'description': 'CJ가 <b>코로나</b> 이후 최대 규모 인재 확보를 목표로 2022년 신입사원 채용 절차에 돌입했다. CJ는 상반기... CJ는 <b>코로나</b> 재확산, 국제 원자재가격 불안 등 경영환경이 불확실한 상황에서도 그룹의 미래인재를 확보하고... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:20:00 +0900'},
#  {'title': "안전과 성과 두 마리 토끼 잡은 'KIMES 2022', 국내 의료기술·제품 호평",
#   'originallink': 'http://www.bokuennews.com/news/article.html?no=214156',
#   'link': 'http://www.bokuennews.com/news/article.html?no=214156',
# ...
#   'description': '국내 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 일일 확진자 수가 30만9790명을 기록했다. 사망자는 200명, 위중증 환자는 1158명이다. 중앙방역대책본부는 이날 0시 기준 신규 확진자가 30만9790명 늘어 누적... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:32:00 +0900'},
#  {'title': "대전시교육청, '어린이놀이시설'...민관합동점검",
#   'originallink': 'http://www.newsfreezone.co.kr/news/articleView.html?idxno=367877',
#   'link': 'http://www.newsfreezone.co.kr/news/articleView.html?idxno=367877',
#   'description': '특히, <b>코로나</b>19와 관련해 환기, 소독 및 인원수 제한 등 방역수칙 준수 확인과 안전점검 결과 문제가 있는 놀이시설은 즉시 현장에서 시정조치하고, 위험 시설에 대하여는 정밀 안전진단을 통해 어린이놀이시설의 안전을... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:32:00 +0900'},
#  {'title': '[3보] <b>코로나</b>19 사망자 200명…위중증 환자 1158명',
#   'originallink': 'http://www.newspim.com/news/view/20220314000161',
#   'link': 'http://www.newspim.com/news/view/20220314000161',
#   'description': '자세한 뉴스는 곧 전해드리겠습니다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:32:00 +0900'},
#  {'title': '인천시 의료관광 클러스터 공모 사업 국내 1위',
#   'originallink': 'http://www.incheontoday.com/news/articleView.html?idxno=216074',
#   'link': 'http://www.incheontoday.com/news/articleView.html?idxno=216074',
#   'description': "문체부는 <b>코로나</b>19 상황을 반영해 지난해 인천시\xa0의료관광 클러스터 실적과 올해 사업계획을 1차 평가했다.... 지난해 시는\xa0<b>코로나</b>19 상황 극복을 위해 '인천 대표 4대 프로젝트'를 추진했다. 이 사업은 '중증환자 인천... ",
#   'pubDate': 'Mon, 14 Mar 2022 09:32:00 +0900'},
#  {'title': "[<b>코로나</b>19] 신규확진 30만9790명…위중증 환자 1158명 '역대 최다'",
#   'originallink': 'https://www.joongang.co.kr/article/25055145',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=025&aid=0003179913',
#   'description': '14일 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 신규 확진자는 30만9790명으로 파악됐다. 중앙방역대책본부는 이날 0시 기준 신규 확진자가 30만9790명 늘어 누적 확진자는 686만6222명으로 집계됐다고 밝혔다. 이날... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': "[속보]<b>코로나</b>19 위중증 환자 1158명 '역대 최다'...사망자 200명",
#   'originallink': 'http://news.mt.co.kr/mtview.php?no=2022031409314479907',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=008&aid=0004719304',
#   'description': '질병관리청 중앙방역대책본부 14일 0시 기준 <b>코로나</b>19(COVID-19) 확진자 현황.',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': "안철수, 윤석열 정부 실세 ‘예약’… 초대 국무총리도 '성큼'",
#   'originallink': 'https://hankookilbo.com/News/Read/A2022031317400001463?did=NA',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=469&aid=0000663279',
#   'description': '안 위원장은 인수위에 설치되는 <b>코로나</b>비상대응특별위원회의 위원장도 겸한다. 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 사태에 따른 손실 보상과 방역·의료 대책을 총괄하는 자리로, 국정운영 능력을 평가받는 시험대에... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': 'BTS 서울 콘서트, 전 세계 246만 5천명 봤다',
#   'originallink': 'https://www.nocutnews.co.kr/news/5722484',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=079&aid=0003619968',
#   'description': '이는 <b>코로나</b> 팬데믹 이후 열린 대중음악 공연 관객 중 가장 큰 규모였다. 첫날인 10일과 마지막 날인 13일... <b>코로나</b> 상황이어서 함성은 금지됐지만, 팬덤 아미(ARMY)는 응원용 소도구인 클래퍼로 박수를 보내고 딱딱... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': "[신상품] LG유플러스 10대 청소년 전용 'U+Z플랜폰'",
#   'originallink': 'http://www.seoulfn.com/news/articleView.html?idxno=449034',
#   'link': 'http://www.seoulfn.com/news/articleView.html?idxno=449034',
#   'description': "LG유플러스는 자체 조사를 통해 <b>코로나</b>19 이후 청소년의 생활 패턴이 원격수업과 등교 상황에 따라 다르다는 것을 확인, 상황에 맞게 스마트폰을 활용할 수 있는 기능을 탑재했다. 청소년은 단말기에 선탑재된 'Z플랜... ",
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '아시아나항공, 日 나고야 노선 11개월 만에 운항 재개',
#   'originallink': 'http://news.mt.co.kr/mtview.php?no=2022031409105760931',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=008&aid=0004719302',
#   'description': '아시아나항공 관계자는 &quot;포스트 <b>코로나</b>를 대비하여 일본 노선을 확대했다&quot;며 &quot;대한민국-일본 간 무사증 입국제도 및 자가격리 완화 동향을 면밀히 주시해 추가 증편운항도 검토할 계획&quot;이라고 밝혔다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '하동군, 여성농업인 바우처 지원사업 신청·접수',
#   'originallink': 'http://www.newsis.com/view/?id=NISX20220314_0001791846&cID=10812&pID=10800',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=003&aid=0011060089',
#   'description': '하동군 관계자는 “여성농업인 바우처 지원사업이 <b>코로나</b>19 여파로 농작업에 어려움을 겪고 있는 여성농업인에게 큰 힘이 될 것”이라며 “기한 내에 신청해 주길 바란다”고 말했다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '[속보]확진 30만 9790명, 사흘째 30만명대…사망 200명·위중증 1158명',
#   'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=01731846632263320',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=018&aid=0005165944',
#   'description': '14일 중앙방역대책본부에 따르면 이날 0시 기준 신규 <b>코로나</b>19 확진자는 30만 9790명으로... 7일 오후 서울 중구 서울역 <b>코로나</b>19 임시 선별검사소에서 시민들이 검사를 받기 위해 줄을 서 있다. (사진... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '부산 비수도권 첫 보험자병원 설립 시동…민·관·정 결의 다져',
#   'originallink': 'https://www.sedaily.com/NewsView/263EXNVG7X',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=011&aid=0004029089',
#   'description': '침례병원 공공병원화는 동부산권의 의료서비스 제공은 물론 <b>코로나</b>19 등 신종감염병 대응을 위한 부산의 공공의료벨트 구축을 위한 핵심축의 하나이다. 박형준 부산시장은 “윤석열 대통령 당선인이 침례병원... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '윤석열 측 &quot;김부겸 총리 유임, 테이블 오른 적도 없다&quot;',
#   'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=01728566632263320',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=018&aid=0005165942',
#   'description': '한편 윤 당선인은 이날 낮 <b>코로나</b>19 피해 소상공인을 찾아 고충을 청취할 예정이다. 김 대변인은 “지난해 11월 대통령으로 당선돼도 꼭 다시 찾아뵙겠다는 약속을 지키기 위한 것”이라며 “<b>코로나</b>19위기대응특별위원회를... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '[1보] <b>코로나</b>19 신규 확진 30만9790명…사흘째 30만명대',
#   'originallink': 'http://www.newspim.com/news/view/20220314000156',
#   'link': 'http://www.newspim.com/news/view/20220314000156',
#   'description': '자세한 뉴스는 곧 전해드리겠습니다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '尹당선인 통의동 집무실 첫 출근',
#   'originallink': 'https://news.kbs.co.kr/news/view.do?ncd=5414482&amp;ref=A',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=056&aid=0011228610',
#   'description': '윤 당선인은 이후 첫 공개 외부일정으로는 <b>코로나</b>19로 피해를 본 소상공인들을 만날 계획입니다. 시장 상인들을 직접 만나 어려움등을 들을 예정입니다. [앵커] 인수위원장이 어제 발표됐고, 인수위는 언제쯤 가동이... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:31:00 +0900'},
#  {'title': '까뮤이앤씨, 3거래일 연속 주가 상승세…왜?',
#   'originallink': 'http://www.pinpointnews.co.kr/news/articleView.html?idxno=102009',
#   'link': 'http://www.pinpointnews.co.kr/news/articleView.html?idxno=102009',
#   'description': '국민통합위원회, <b>코로나</b>비상대응특별위원회, 지역균형발전특별위원회로 구성할 예정에 있다. 또한 안철수 국민의 당 대표는 <b>코로나</b>비상대응특별위원장도 겸임하는 것으로 알려졌다. 새 정부 출범 기대감이 커지는... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '김어준 &quot;대선 패하면 아수라장 되는데…민주당, 일사불란&quot;',
#   'originallink': 'https://view.asiae.co.kr/article/2022031409082462735',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=277&aid=0005057537',
#   'description': '내 고(故) 김대중 전 대통령 묘역을 방문한 뒤 이날 오전 국회에서 첫 비대위 회의를 연다. 박지현 공동위원장은 <b>코로나</b>19 확진으로 공식 일정에 참석하지 않지만, 사전에 녹화한 영상으로 모두 발언을 할 계획으로 전해졌다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '[속보] 신규확진 30만 9,790명…이달 말부터 5~11세 <b>코로나</b> 예방접종',
#   'originallink': 'http://mbn.mk.co.kr/pages/news/newsView.php?category=mbn00009&news_seq_no=4716740',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=057&aid=0001648740',
#   'description': '오미크론 변이 바이러스 유행이 지속되면서 3일 연속 30만 명대 <b>코로나</b>19 신규 확진자 수를 기록했습니다. 확산세가 이어지자 당국은 이달 말부터 5~11세의 소아를 대상으로 <b>코로나</b>19 예방접종을 시행하겠다고... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "위중증 1158명 '역대 최다'…30만9790명 확진·사망 닷새째 200명대",
#   'originallink': 'https://www.news1.kr/articles/?4614282',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005966616',
#   'description': '질병관리청 중앙방역대책본부(방대본)는 14일 0시 기준 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 신규 확진자가 30만9790명 발생했다고 밝혔다. 누적 확진자는 오는 15일 700만명을 넘어설... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '대한적십자사 경인의료재활센터병원, 아동 환자 위한 놀이키트 제공',
#   'originallink': 'http://www.sportsseoul.com/news/read/1104650?ref=naver',
#   'link': 'http://www.sportsseoul.com/news/read/1104650?ref=naver',
#   'description': '장용원 경인의료재활센터병원 병원장은 “<b>코로나</b>19 확산으로 원내 집단 프로그램이 중단된 상황이지만, 다양한 놀이키트로 가정에서 아동에게 새로운 감각을 자극시킬 수 있는 기회가 될 수 있어 매우 뜻깊게 생각한다”... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "한국애브비, 건강증진 웰빙 캠페인 '2022 WOW' 실시",
#   'originallink': 'http://www.medisobizanews.com/news/articleView.html?idxno=85766',
#   'link': 'http://www.medisobizanews.com/news/articleView.html?idxno=85766',
#   'description': '한국애브비 강소영 대표는\xa0&quot;<b>코로나</b> 장기화로 삶이 위축되고 에너지가 떨어진 상황에서\xa0건강하고 긍정적인 마인드 세팅을 통한 대처가 중요하다&quot;며\xa0&quot;올 해\xa0WOW 캠페인이\xa0직원들로 하여금 신체적, 정신적... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '정의선 현대차그룹 회장, 인니공장 준공식 참석...조코위 대통령 만나나',
#   'originallink': 'http://www.newsway.co.kr/news/view?tp=1&ud=2022031409262410913',
#   'link': 'http://www.newsway.co.kr/news/view?tp=1&ud=2022031409262410913',
#   'description': '한편 현대차그룹 인도네시아 생산공장 준공식은 당초 올해 1월에 열릴 예정이었지만, <b>코로나</b> 19 영향으로 미뤄지다가 이번에 개최하게 됐다. 이 공장에서는 올해 현대차의 전기차 아이오닉5 생산을 계획하고 있다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "전자랜드, 새 학기 IT가전으로 '태블릿 PC' 인기↑",
#   'originallink': 'http://www.koreastocknews.com/news/articleView.html?idxno=70764',
#   'link': 'http://www.koreastocknews.com/news/articleView.html?idxno=70764',
#   'description': '먼저 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19)의 발생 이후 재택근무나 비대면 수업을 하는 사람들이 늘어났고,\xa0이에 따라\xa0IT\xa0가전제품의 전체적인 인기도 증가했다.\xa0이후 <b>코로나</b>19가 장기화되면서 대면 수업과 비대면... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': 'NH농협은행, 연내 인도 지점 설립… 글로벌 네트워크 구축 박차',
#   'originallink': 'http://www.thekpm.com/news/articleView.html?idxno=111981',
#   'link': 'http://www.thekpm.com/news/articleView.html?idxno=111981',
#   'description': '<b>코로나</b>19 확산세가 강했던 지난해\xa0현지 적십자사를 통해 산소발생기를 기부했다. NH농협은행은\xa0협동조합 조직인 인도비료협동조합(IFFCO)사와 지속적인 협력관계도\xa0유지했다. IFFCO는 NH농협금융의 자회사... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "LGU+, 'U+Z플랜폰' 출시…청소년 맞춤 자기관리기능 제공",
#   'originallink': 'http://www.newsis.com/view/?id=NISX20220314_0001791855&cID=13005&pID=13100',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=105&oid=003&aid=0011060073',
#   'description': "<b>코로나</b>19 이후 청소년의 생활 패턴이 원격수업과 등교 상황에 따라 다르다는 점을 고려해 상황에 맞게 스마트폰을 활용할 수 있는 기능이 탑재됐다. 청소년은 단말기에 선탑재된 'ZPlan(Z플랜)' 앱을 통해 네 가지 모드 중... ",
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '윤석열 당선인, 통의동 집무실 첫 출근',
#   'originallink': 'https://www.ebn.co.kr/news/view/1522885/?sc=Naver',
#   'link': 'https://www.ebn.co.kr/news/view/1522885/?sc=Naver',
#   'description': '윤 당선인은 이날 첫 공개일정으로 <b>코로나</b>19로 피해를 본 소상공인과 만나는 것을 검토 중이다. 김은혜 당선인 대변인은 전날 &quot;<b>코로나</b>로 실의에 빠져 있는 많은 우리 국민 분들과 함께 하는 현장행보와 함께 국민 속으로... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '윤호중 &quot;대장동 특검, 저희가 내놓은 안 중심으로 논의 가능&quot;',
#   'originallink': 'https://www.dailian.co.kr/news/view/1092778/?sc=Naver',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=119&aid=0002584754',
#   'description': '박지현 공동비대위원장과 배재정·권지웅 비대위원 등 세명은 <b>코로나</b>19 감염 혹은 증상 등으로 불참했다. 윤 위원장은 &quot;순국선열과 호국영령을 찾아뵙고 굳은 각오로 반성하고 쇄신해 더 새로워진 민주당이 되겠다는... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': 'NH농협은행 인도 노이다지점 설립 예비인가 획득',
#   'originallink': 'http://yna.kr/AKR20220314038200002?did=1195m',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=001&aid=0013048824',
#   'description': '농협은행은 인도 지역 <b>코로나</b>19 확산세가 심했던 지난해 현지 적십자사에 산소발생기를 기부하고 인도 비료협동조합(IFFCO)과 협력관계를 유지하는 등 현지에서 적극적인 환경·사회책임·지배구조(ESG) 경영 활동을... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '[속보] <b>코로나</b>19 신규확진 30만9790명… 사흘 연속 30만명대',
#   'originallink': 'https://view.asiae.co.kr/article/2022031409304616741',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=277&aid=0005057540',
#   'description': '',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '5~11세 31일부터 <b>코로나</b> 백신 접종… 24일부터 사전예약',
#   'originallink': 'https://health.chosun.com/site/data/html_dir/2022/03/14/2022031400523.html',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=346&aid=0000048978',
#   'description': "정부가 5~11세 소아에 대한 <b>코로나</b>19 백신 접종을 이달 말부터 시작한다. 전해철 중앙재난안전대책본부... 정부는 또 최근 <b>코로나</b>19 백신 안전성위원회 발표에 따라 백신 접종 이상반응의 인과성 인정 기준에 '심근염'을... ",
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': 'NH농협은행, 인도 노이다지점 예비인가 획득',
#   'originallink': 'https://www.etoday.co.kr/news/view/2113661',
#   'link': 'https://www.etoday.co.kr/news/view/2113661',
#   'description': '농협은행은 작년 <b>코로나</b>19의 확산세가 특히 심했던 인도에 현지 적십자사를 통해 산소발생기를 직접 기부하고, 인도 협동조합 조직인 IFFCO사와 지속적인 협력관계를 유지하는 등 적극적인 현지 ESG경영을 펼치며... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '노랑풍선, 미주지역 강화.. 해외 입국자 의무격리 면제로 문의 증가 추제',
#   'originallink': 'http://www.discoverynews.kr/news/articleView.html?idxno=758268',
#   'link': 'http://www.discoverynews.kr/news/articleView.html?idxno=758268',
#   'description': '사진= 미국 뉴욕 ⓒ노랑풍선 제공 \xa0 이제 오는 21일부터 국내외에서 <b>코로나</b> 백신접종을 완료한 해외 입국자들의 의무격리 면제 발표 후, 미국과 하와이, 캐나다 등 미주지역의 여행 문의가 증가 하고 있다. 이에... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "롯데홈쇼핑, 국내 관광명소 랜선여행 '더 힐링 라이브' 론칭",
#   'originallink': 'http://www.koreastocknews.com/news/articleView.html?idxno=70765',
#   'link': 'http://www.koreastocknews.com/news/articleView.html?idxno=70765',
#   'description': '<b>코로나</b>19 장기화로 MZ세대를 중심으로 SNS를 통해 유명 관광지 방문, 맛집 탐방 등의 경험을 공유하고 비대면으로 즐기는 콘텐츠가 주목받고 있다. 이에\xa0롯데홈쇼핑은 국내 유명 여행지를 직접 방문해 현장에서 체험 상품... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "[속보] '역대 최다' <b>코로나</b>19 위중증 환자 1158명",
#   'originallink': 'https://view.asiae.co.kr/article/2022031409305019944',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=277&aid=0005057541',
#   'description': '',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "[속보] 위중증 1158명 '역대 최다'…사흘째 30만명대·내일 700만명 넘는다",
#   'originallink': 'https://www.news1.kr/articles/?4614261',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005966615',
#   'description': '질병관리청 중앙방역대책본부(방대본)은 14일 0시 기준 신종 <b>코로나</b>바이러스 감염증(<b>코로나</b>19) 신규 확진자가 30만9790명 발생했다고 밝혔다. 누적 확진자는 15일 700만명을 넘어설 전망이다. 이날 신규... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '아시아나항공, 일본 입국 완화 발맞춰 나고야 운항 재개',
#   'originallink': 'http://www.pinpointnews.co.kr/news/articleView.html?idxno=102012',
#   'link': 'http://www.pinpointnews.co.kr/news/articleView.html?idxno=102012',
#   'description': '아시아나항공 관계자는 &quot;포스트 <b>코로나</b>를 대비하여 일본 노선을 확대하였으며, 대한민국-일본 간 무사증 입국제도 및 자가격리 완화 동향을 면밀히 주시하여, 추가 증편운항도 검토할 계획&quot;이라고 밝혔다.',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '[속보]<b>코로나</b>19 신규 확진자 30만9790명...사흘째 30만명대',
#   'originallink': 'http://news.mt.co.kr/mtview.php?no=2022031409294285958',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=008&aid=0004719300',
#   'description': '질병관리청 중앙방역대책본부 14일 0시 기준 <b>코로나</b>19(COVID-19) 확진자 현황.',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': '“기적 같은 3일”…방탄소년단, 잠실벌 달군 ‘퍼미션 투 댄스’',
#   'originallink': 'http://www.sportsworldi.com/newsView/20220314503483',
#   'link': 'https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=396&aid=0000607122',
#   'description': "<b>코로나</b>19 팬데믹 상황 탓에 공연장 내 수용인원 제한이 불가피함에 따른 팬들의 아쉬움은 다양한... 'BTS PERMISSION TO DANCE ON STAGE - SEOUL'에서는 <b>코로나</b>19 확산 방지를 위해 함성 대신 클래퍼(응원용 소도구)와... ",
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'},
#  {'title': "[특징주] 씨젠 소폭 하락 '오미크론 정점 언급에 수요 하락 전망'",
#   'originallink': 'https://www.gukjenews.com/news/articleView.html?idxno=2425169',
#   'link': 'https://www.gukjenews.com/news/articleView.html?idxno=2425169',
#   'description': '정점이 확인되면 21일부터는 위드 <b>코로나</b> 수준으로 사회적 거리두기를 대폭 완화할 태세다. 현재 사적모임 6인, 식당·카페 등 밤 11시 영업제한을 골자로 한 거리두기는 20일까지 적용 중이다. 이미 21일부터는 백신을... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:30:00 +0900'}]

# %%
#성인 검색어 판별

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 성인검색어 검색
import urllib.request
import json

client_id = id
client_secret = key
keyword=input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data=[]
url = f"https://openapi.naver.com/v1/search/adult?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body)
    d=json.loads(response_body) #s붙으면 변수..?
    print(d['adult'])
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어>>>사랑
# b'{\n"adult": "0"\n}\n'
# 0

# %%
#오타변환

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 성인검색어 검색
import urllib.request
import json

client_id = id
client_secret = key
keyword=input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data=[]
url = f"https://openapi.naver.com/v1/search/errata?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body)
    d=json.loads(response_body) #s붙으면 변수..?
    print(d['errata'])
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어>>>dkssud
# b'{\n"errata": "\xec\x95\x88\xeb\x85\x95"\n}\n'
# 안녕

# %%
#카카오 주소 검색

# %%
REST_API_KEY='12c60ab21ec33500c86de172cbd60788'

# %% [raw]
# curl -v -X GET
# "https://dapi.kakao.com/v2/local/search/address.json" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}" \
#   --data-urlencode "query=전북 삼성동 100"

# %%
import requests
keyword=input('검색할 주소>>>')
url=f"https://dapi.kakao.com/v2/local/search/address.json?query={keyword}"
headers={'Authorization': f'KakaoAK {REST_API_KEY}'}
res=requests.get(url,headers=headers)
res=res.json()
print(res)
# Out:
# 검색할 주소>>>전북 삼성동 100
# {'documents': [{'address': {'address_name': '전북 익산시 부송동 100', 'b_code': '4514013400', 'h_code': '4514069000', 'main_address_no': '100', 'mountain_yn': 'N', 'region_1depth_name': '전북', 'region_2depth_name': '익산시', 'region_3depth_h_name': '삼성동', 'region_3depth_name': '부송동', 'sub_address_no': '', 'x': '126.99597495347', 'y': '35.9766482774579'}, 'address_name': '전북 익산시 부송동 100', 'address_type': 'REGION_ADDR', 'road_address': None, 'x': '126.99597495347', 'y': '35.9766482774579'}, {'address': {'address_name': '전북 익산시 임상동 100', 'b_code': '4514013200', 'h_code': '4514069000', 'main_address_no': '100', 'mountain_yn': 'N', 'region_1depth_name': '전북', 'region_2depth_name': '익산시', 'region_3depth_h_name': '삼성동', 'region_3depth_name': '임상동', 'sub_address_no': '', 'x': '126.980268573424', 'y': '35.9816612949055'}, 'address_name': '전북 익산시 임상동 100', 'address_type': 'REGION_ADDR', 'road_address': None, 'x': '126.980268573424', 'y': '35.9816612949055'}, {'address': {'address_name': '전북 익산시 정족동 100', 'b_code': '4514013100', 'h_code': '4514069000', 'main_address_no': '100', 'mountain_yn': 'N', 'region_1depth_name': '전북', 'region_2depth_name': '익산시', 'region_3depth_h_name': '삼성동', 'region_3depth_name': '정족동', 'sub_address_no': '', 'x': '127.002020445866', 'y': '35.9829740190924'}, 'address_name': '전북 익산시 정족동 100', 'address_type': 'REGION_ADDR', 'road_address': None, 'x': '127.002020445866', 'y': '35.9829740190924'}], 'meta': {'is_end': True, 'pageable_count': 3, 'total_count': 3}}

# %%
#좌표로 행정구역정보 받기

# %% [raw]
# curl -v -X GET
# "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.1086228&y=37.4012191" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}"

# %%
y=35.1170937325934
x=129.08991873192366
url=f'https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x={x}&y={y}'
headers={'Authorization': f'KakaoAK {REST_API_KEY}'}
res=requests.get(url,headers=headers)
res=res.json()
print(res)
# Out:
# {'meta': {'total_count': 2}, 'documents': [{'region_type': 'B', 'code': '2629010800', 'address_name': '부산광역시 남구 용당동', 'region_1depth_name': '부산광역시', 'region_2depth_name': '남구', 'region_3depth_name': '용당동', 'region_4depth_name': '', 'x': 129.0950407144003, 'y': 35.11764987408262}, {'region_type': 'H', 'code': '2629061000', 'address_name': '부산광역시 남구 용당동', 'region_1depth_name': '부산광역시', 'region_2depth_name': '남구', 'region_3depth_name': '용당동', 'region_4depth_name': '', 'x': 129.0950407144003, 'y': 35.11764987408262}]}

# %%
#현재 위치 기준 반경 1k안 뭐가 몇개 있는지 확인

# %% [raw]
# curl -v -X GET "https://dapi.kakao.com/v2/local/search/keyword.json?y=37.514322572335935&x=127.06283102249932&radius=20000" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}" \
#   --data-urlencode "query=카카오프렌즈"

# %%
y=35.1170937325934
x=129.08991873192366
code='CS2'
radius=20000
query=input('검색>>>')
url=f'''https://dapi.kakao.com/v2/local/search/keyword.json?x={x}&y={y}
&radius={radius}&category_group_code={code}&query={query}'''

headers={'Authorization': f'KakaoAK {REST_API_KEY}'}
res=requests.get(url,headers=headers)
res=res.json()
print(res)
# Out:
# 검색>>>gs25
# {'documents': [{'address_name': '부산 남구 감만동 248-26', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '373', 'id': '17053156', 'phone': '051-633-5546', 'place_name': 'GS25 부경감만점', 'place_url': 'http://place.map.kakao.com/17053156', 'road_address_name': '부산 남구 양지골로 110', 'x': '129.087477616507', 'y': '35.1143884368579'}, {'address_name': '부산 남구 용당동 164-2', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '625', 'id': '12294960', 'phone': '051-624-0812', 'place_name': 'GS25 신선대점', 'place_url': 'http://place.map.kakao.com/12294960', 'road_address_name': '부산 남구 신선로 309-1', 'x': '129.095486170113', 'y': '35.1138032263504'}, {'address_name': '부산 남구 감만동 73-212', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '669', 'id': '17053198', 'phone': '051-632-8599', 'place_name': 'GS25 감만동일스위트점', 'place_url': 'http://place.map.kakao.com/17053198', 'road_address_name': '부산 남구 우암로104번길 29', 'x': '129.08267045784788', 'y': '35.11803976430043'}, {'address_name': '부산 남구 용당동 454-22', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '758', 'id': '18578418', 'phone': '051-628-5008', 'place_name': 'GS25 용당해군점', 'place_url': 'http://place.map.kakao.com/18578418', 'road_address_name': '부산 남구 신선로 393-9', 'x': '129.097233389959', 'y': '35.1203550715089'}, {'address_name': '부산 남구 감만동 160-5', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '747', 'id': '12294813', 'phone': '051-633-1141', 'place_name': 'GS25 감만점', 'place_url': 'http://place.map.kakao.com/12294813', 'road_address_name': '부산 남구 홍곡로 10', 'x': '129.081832609841', 'y': '35.1159742784359'}, {'address_name': '부산 남구 감만동 258-5', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '816', 'id': '12294913', 'phone': '051-634-1384', 'place_name': 'GS25 감만현대점', 'place_url': 'http://place.map.kakao.com/12294913', 'road_address_name': '부산 남구 우암로26번길 8', 'x': '129.082519018485', 'y': '35.1129525972246'}, {'address_name': '부산 남구 용당동 99-10', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '854', 'id': '392506213', 'phone': '', 'place_name': 'GS25 용당현대점', 'place_url': 'http://place.map.kakao.com/392506213', 'road_address_name': '부산 남구 동명로 26', 'x': '129.09925717316557', 'y': '35.11775622469685'}, {'address_name': '부산 남구 대연동 1893', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '993', 'id': '1690767122', 'phone': '1644-5425', 'place_name': 'GS25 파크푸르지오점', 'place_url': 'http://place.map.kakao.com/1690767122', 'road_address_name': '부산 남구 홍곡로 360', 'x': '129.0899358671594', 'y': '35.12604133165618'}, {'address_name': '부산 남구 감만동 500-2', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '1062', 'id': '903247459', 'phone': '051-637-8840', 'place_name': 'GS25 감만판테라', 'place_url': 'http://place.map.kakao.com/903247459', 'road_address_name': '부산 남구 무민사로 13', 'x': '129.080206419792', 'y': '35.1118009818009'}, {'address_name': '부산 남구 우암동 52-3', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '1153', 'id': '23405123', 'phone': '051-633-8467', 'place_name': 'GS25 우암자유점', 'place_url': 'http://place.map.kakao.com/23405123', 'road_address_name': '부산 남구 우암로154번길 8', 'x': '129.080295258603', 'y': '35.1238335925186'}, {'address_name': '부산 남구 우암동 103-11', 'category_group_code': 'CS2', 'category_group_name': '편의점', 'category_name': '가정,생활 > 편의점 > GS25', 'distance': '1328', 'id': '16750543', 'phone': '051-637-0574', 'place_name': 'GS25 부산서현점', 'place_url': 'http://place.map.kakao.com/16750543', 'road_address_name': '부산 남구  ...

# %%
#영화진흥위원회 API
key='5e2bfb56a206e751f18e613686e3b17e'
date='20220313'
url=f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={date}'
res=requests.get(url)
print(res.json())
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스', 'showRange': '20220313~20220313', 'dailyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20190299', 'movieNm': '이상한 나라의 수학자', 'openDt': '2022-03-09', 'salesAmt': '604629280', 'salesShare': '42.6', 'salesInten': '51307650', 'salesChange': '9.3', 'salesAcc': '2345227040', 'audiCnt': '61979', 'audiInten': '5674', 'audiChange': '10.1', 'audiAcc': '246226', 'scrnCnt': '1310', 'showCnt': '5248'}, {'rnum': '2', 'rank': '2', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20212973', 'movieNm': '더 배트맨', 'openDt': '2022-03-01', 'salesAmt': '452014860', 'salesShare': '31.8', 'salesInten': '-63578060', 'salesChange': '-12.3', 'salesAcc': '7623442050', 'audiCnt': '42398', 'audiInten': '-5603', 'audiChange': '-11.7', 'audiAcc': '733821', 'scrnCnt': '1464', 'showCnt': '4029'}, {'rnum': '3', 'rank': '3', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20223278', 'movieNm': '극장판 주술회전 0', 'openDt': '2022-02-17', 'salesAmt': '112230270', 'salesShare': '7.9', 'salesInten': '-10229390', 'salesChange': '-8.4', 'salesAcc': '4459580390', 'audiCnt': '11154', 'audiInten': '-984', 'audiChange': '-8.1', 'audiAcc': '447488', 'scrnCnt': '591', 'showCnt': '1153'}, {'rnum': '4', 'rank': '4', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20211200', 'movieNm': '언차티드', 'openDt': '2022-02-16', 'salesAmt': '56527170', 'salesShare': '4.0', 'salesInten': '-483960', 'salesChange': '-0.8', 'salesAcc': '7015501590', 'audiCnt': '5596', 'audiInten': '41', 'audiChange': '0.7', 'audiAcc': '717126', 'scrnCnt': '514', 'showCnt': '818'}, {'rnum': '5', 'rank': '5', 'rankInten': '-1', 'rankOldAndNew': 'OLD', 'movieCd': '20223828', 'movieNm': '나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션', 'openDt': '2022-03-09', 'salesAmt': '53044150', 'salesShare': '3.7', 'salesInten': '-3868260', 'salesChange': '-6.8', 'salesAcc': '343242720', 'audiCnt': '5396', 'audiInten': '-408', 'audiChange': '-7', 'audiAcc': '35635', 'scrnCnt': '433', 'showCnt': '727'}, {'rnum': '6', 'rank': '6', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20223953', 'movieNm': '블랙라이트', 'openDt': '2022-03-09', 'salesAmt': '39008720', 'salesShare': '2.7', 'salesInten': '5949720', 'salesChange': '18', 'salesAcc': '184002420', 'audiCnt': '4017', 'audiInten': '525', 'audiChange': '15', 'audiAcc': '19859', 'scrnCnt': '491', 'showCnt': '871'}, {'rnum': '7', 'rank': '7', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20212741', 'movieNm': '안테벨룸', 'openDt': '2022-02-23', 'salesAmt': '14650900', 'salesShare': '1.0', 'salesInten': '-2319300', 'salesChange': '-13.7', 'salesAcc': '861641050', 'audiCnt': '1928', 'audiInten': '-195', 'audiChange': '-9.2', 'audiAcc': '90469', 'scrnCnt': '118', 'showCnt': '145'}, {'rnum': '8', 'rank': '8', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20210028', 'movieNm': '스파이더맨: 노 웨이 홈', 'openDt': '2021-12-15', 'salesAmt': '13788400', 'salesShare': '1.0', 'salesInten': '3870200', 'salesChange': '39', 'salesAcc': '75131042040', 'audiCnt': '1557', 'audiInten': '428', 'audiChange': '37.9', 'audiAcc': '7544734', 'scrnCnt': '113', 'showCnt': '137'}, {'rnum': '9', 'rank': '9', 'rankInten': '4', 'rankOldAndNew': 'OLD', 'movieCd': '20223308', 'movieNm': '극장판 바다 탐험대 옥토넛 : 해저동굴 대탈출\t', 'openDt': '2022-02-17', 'salesAmt': '8131000', 'salesShare': '0.6', 'salesInten': '3854000', 'salesChange': '90.1', 'salesAcc': '213119700', 'audiCnt': '957', 'audiInten': '428', 'audiChange': '80.9', 'audiAcc': '25722', 'scrnCnt': '89', 'showCnt': '97'}, {'rnum': '10', 'rank': '10', 'rankInten': '1', 'rankOldAndNew': 'OLD', 'movieCd': '20208006', 'movieNm': '인민을 위해 복무하라', 'openDt': '2022-02-23', 'salesAmt': '7282000', 'salesShare': '0.5', 'salesInten': '2586500', 'salesChange': '55.1', 'salesAcc': '673618650', 'audiCnt': '906', 'audiInten': '330', 'audiChange': '57.3', 'audiAcc': '72733', 'scrnCnt': '82', 'showCnt': '98'}]}}
